# %% [markdown]
# # Natural Language Processing - N-Gram Language Modeling

# %% [markdown]
# ## Gaurav Jain   2K20/MC/49

# %% [markdown]
# ### Importing Libraries

# %%
# text preprocessing
import re

# model creation
from collections import defaultdict

# text prediction
import random

# %% [markdown]
# ### Text Corpus On Olympic Games

# %%
data_text = """The modern Olympic Games or Olympics are the leading international sporting events featuring summer and winter sports competitions in which thousands of athletes from around the world participate in a variety of competitions. The Olympic Games are considered the world's foremost sports competition with more than 200 teams, representing sovereign states and territories participating; by default the Games generally substitute for any World Championships the year in which they take place (however, each class usually maintains their own records).[2] The Olympic Games are normally held every four years, and since 1994, have alternated between the Summer and Winter Olympics every two years during the four-year period.

Their creation was inspired by the ancient Olympic Games, held in Olympia, Greece from the 8th century BC to the 4th century AD. Baron Pierre de Coubertin founded the International Olympic Committee (IOC) in 1894, leading to the first modern Games in Athens in 1896. The IOC is the governing body of the Olympic Movement (which encompasses all entities and individuals involved in the Olympic Games) with the Olympic Charter defining its structure and authority.

The evolution of the Olympic Movement during the 20th and 21st centuries has resulted in several changes to the Olympic Games. Some of these adjustments include the creation of the Winter Olympic Games for snow and ice sports, the Paralympic Games for athletes with disabilities, the Youth Olympic Games for athletes aged 14 to 18, the five Continental games (Pan American, African, Asian, European, and Pacific), and the World Games for sports that are not contested in the Olympic Games. The IOC also endorses the Deaflympics and the Special Olympics. The IOC has needed to adapt to a variety of economic, political, and technological advancements. The abuse of amateur rules by the Eastern Bloc nations prompted the IOC to shift away from pure amateurism, as envisioned by Coubertin, to the acceptance of professional athletes participating at the Games. The growing importance of mass media has created the issue of corporate sponsorship and general commercialisation of the Games. World wars led to the cancellation of the 1916, 1940, and 1944 Olympics; large-scale boycotts during the Cold War limited participation in the 1980 and 1984 Olympics;[3] and the 2020 Olympics were postponed until 2021 as a result of the COVID-19 pandemic.

The Olympic Movement consists of international sports federations (IFs), National Olympic Committees (NOCs), and organising committees for each specific Olympic Games. As the decision-making body, the IOC is responsible for choosing the host city for each Games, and organises and funds the Games according to the Olympic Charter. The IOC also determines the Olympic programme, consisting of the sports to be contested at the Games. There are several Olympic rituals and symbols, such as the Olympic flag and torch, as well as the opening and closing ceremonies. Over 14,000 athletes competed at the 2020 Summer Olympics and 2022 Winter Olympics combined, in 40 different sports and 448 events.[4][5] The first-, second-, and third-place finishers in each event receive Olympic medals: gold, silver, and bronze, respectively.

The Games have grown to the point that nearly every nation is now represented; colonies and overseas territories are often allowed to field their own teams. This growth has created numerous challenges and controversies, including boycotts, doping, bribery, and terrorism. Every two years, the Olympics and its media exposure provide athletes with the chance to attain national and international fame. The Games also provide an opportunity for the host city and country to showcase themselves to the world.

The Ancient Olympic Games were religious and athletic festivals held every four years at the sanctuary of Zeus in Olympia, Greece. Competition was among representatives of several city-states and kingdoms of Ancient Greece. These Games featured mainly athletic but also combat sports such as wrestling and the pankration, horse and chariot racing events. It has been widely written that during the Games, all conflicts among the participating city-states were postponed until the Games were finished. This cessation of hostilities was known as the Olympic peace or truce.[6] This idea is a modern myth because the Greeks never suspended their wars. The truce did allow those religious pilgrims who were travelling to Olympia to pass through warring territories unmolested because they were protected by Zeus.[7]

The origin of the Olympics is shrouded in mystery and legend;[8] one of the most popular myths identifies Heracles and his father Zeus as the progenitors of the Games.[9][10][11] According to legend, it was Heracles who first called the Games "Olympic" and established the custom of holding them every four years.[12] The myth continues that after Heracles completed his twelve labours, he built the Olympic Stadium as an honour to Zeus. Following its completion, he walked in a straight line for 200 steps and called this distance a "stadion" (Ancient Greek: στάδιον, Latin: stadium, "stage"), which later became a unit of distance. The most widely accepted inception date for the Ancient Olympics is 776 BC; this is based on inscriptions, found at Olympia, listing the winners of a footrace held every four years starting in 776 BC.[13] The Ancient Games featured running events, a pentathlon (consisting of a jumping event, discus and javelin throws, a foot race, and wrestling), boxing, wrestling, pankration, and equestrian events.[14][15] Tradition has it that Coroebus, a cook from the city of Elis, was the first Olympic champion.[16]

The Olympics were of fundamental religious importance, featuring sporting events alongside ritual sacrifices honouring both Zeus (whose famous statue by Phidias stood in his temple at Olympia) and Pelops, divine hero and mythical king of Olympia. Pelops was famous for his chariot race with King Oenomaus of Pisatis.[17] The winners of the events were admired and immortalised in poems and statues.[18] The Games were held every four years, and this period, known as an Olympiad, was used by Greeks as one of their units of time measurement. The Games were part of a cycle known as the Panhellenic Games, which included the Pythian Games, the Nemean Games, and the Isthmian Games.[19]

The Olympic Games reached the height of their success in the 6th and 5th centuries BC, but then gradually declined in importance as the Romans gained power and influence in Greece. While there is no scholarly consensus as to when the Games officially ended, the most commonly held date is 393 AD, when the emperor Theodosius I decreed that all pagan cults and practices be eliminated.[b] Another date commonly cited is 426 AD, when his successor, Theodosius II, ordered the destruction of all Greek temples.[21]"""

# %% [markdown]
# ### Cleaning The Text Data

# %%
def text_cleaner(text):
    # tokenizing the text
    t_text = 'stkn ' + text
    t_text = re.sub(r"\."," etkn stkn",t_text)         # 'stkn' is starting token and 'etkn' is ending token
    t_text = t_text[:len(t_text)-9]

    # lower case text
    newString = t_text.lower()
    newString = re.sub(r"'s\b","",newString)
    
    # remove punctuations
    newString = re.sub("[^a-zA-Z]", " ", newString)

    # seperating into words before joining together
    words=[]
    for i in newString.split():
        words.append(i)
    return (" ".join(words)).strip()

# preprocess the text
data_new = text_cleaner(data_text)
data = data_new.split(' ')

# %%
print(data_new)
# Out:
# stkn the modern olympic games or olympics are the leading international sporting events featuring summer and winter sports competitions in which thousands of athletes from around the world participate in a variety of competitions etkn stkn the olympic games are considered the world foremost sports competition with more than teams representing sovereign states and territories participating by default the games generally substitute for any world championships the year in which they take place however each class usually maintains their own records etkn stkn the olympic games are normally held every four years and since have alternated between the summer and winter olympics every two years during the four year period etkn stkn their creation was inspired by the ancient olympic games held in olympia greece from the th century bc to the th century ad etkn stkn baron pierre de coubertin founded the international olympic committee ioc in leading to the first modern games in athens in etkn stkn the ioc is the governing body of the olympic movement which encompasses all entities and individuals involved in the olympic games with the olympic charter defining its structure and authority etkn stkn the evolution of the olympic movement during the th and st centuries has resulted in several changes to the olympic games etkn stkn some of these adjustments include the creation of the winter olympic games for snow and ice sports the paralympic games for athletes with disabilities the youth olympic games for athletes aged to the five continental games pan american african asian european and pacific and the world games for sports that are not contested in the olympic games etkn stkn the ioc also endorses the deaflympics and the special olympics etkn stkn the ioc has needed to adapt to a variety of economic political and technological advancements etkn stkn the abuse of amateur rules by the eastern bloc nations prompted the ioc to shift away from pure amateurism as envisioned by coubertin to the acceptance of professional athletes participating at the games etkn stkn the growing importance of mass media has created the issue of corporate sponsorship and general commercialisation of the games etkn stkn world wars led to the cancellation of the and olympics large scale boycotts during the cold war limited participation in the and olympics and the olympics were postponed until as a result of the covid pandemic etkn stkn the olympic movement consists of international sports federations ifs national olympic committees nocs and organising committees for each specific olympic games etkn stkn as the decision making body the ioc is responsible for choosing the host city for each games and organises and funds the games according to the olympic charter etkn stkn the ioc also determines the olympic programme consisting of the sports to be contested at the games etkn stkn there are several olympic rituals and symbols such as the olympic flag and torch as well as the opening and closing ceremonies etkn stkn over athletes competed at the summer olympics and winter olympics combined in different sports and events etkn stkn the first second and third place finishers in each event receive olympic medals gold silver and bronze respectively etkn stkn the games have grown to the point that nearly every nation is now represented colonies and overseas territories are often allowed to field their own teams etkn stkn this growth has created numerous challenges and controversies including boycotts doping bribery and terrorism etkn stkn every two years the olympics and its media exposure provide athletes with the chance to attain national and international fame etkn stkn the games also provide an opportunity for the host city and country to showcase themselves to the world etkn stkn the ancient olympic games were religious and athletic festivals held every four years at the sanctuary of zeus in olympia greece etkn stkn competition was among representatives of several city s ...

# %% [markdown]
# ### Functions For Each N-Gram

# %% [markdown]
# ### Bigram

# %%
model_bi = defaultdict(lambda: defaultdict(int))

# %%
n_gram = 2
for i in range(n_gram,len(data)+1):
    w1 = data[i-n_gram+0]
    w2 = data[i-n_gram+1]
    model_bi[w1][w2] += 1

# %%
for w1 in model_bi:
    total_count = float(sum(model_bi[w1].values()))
    for w2 in model_bi[w1]:
        model_bi[w1][w2] /= total_count

# %%
model_bi
# Out:
# defaultdict(<function __main__.<lambda>()>,
#             {'stkn': defaultdict(int,
#                          {'the': 0.5555555555555556,
#                           'their': 0.022222222222222223,
#                           'baron': 0.022222222222222223,
#                           'some': 0.022222222222222223,
#                           'world': 0.022222222222222223,
#                           'as': 0.022222222222222223,
#                           'there': 0.022222222222222223,
#                           'over': 0.022222222222222223,
#                           'this': 0.06666666666666667,
#                           'every': 0.022222222222222223,
#                           'competition': 0.022222222222222223,
#                           'these': 0.022222222222222223,
#                           'it': 0.022222222222222223,
#                           'according': 0.022222222222222223,
#                           'following': 0.022222222222222223,
#                           'tradition': 0.022222222222222223,
#                           'pelops': 0.022222222222222223,
#                           'while': 0.022222222222222223,
#                           'b': 0.022222222222222223}),
#              'the': defaultdict(int,
#                          {'modern': 0.009009009009009009,
#                           'leading': 0.009009009009009009,
#                           'world': 0.036036036036036036,
#                           'olympic': 0.13513513513513514,
#                           'games': 0.12612612612612611,
#                           'year': 0.009009009009009009,
#                           'summer': 0.018018018018018018,
#                           'four': 0.009009009009009009,
#                           'ancient': 0.036036036036036036,
#                           'th': 0.036036036036036036,
#                           'international': 0.009009009009009009,
#                           'first': 0.02702702702702703,
#                           'ioc': 0.05405405405405406,
#                           'governing': 0.009009009009009009,
#                           'evolution': 0.009009009009009009,
#                           'creation': 0.009009009009009009,
#                           'winter': 0.009009009009009009,
#                           'paralympic': 0.009009009009009009,
#                           'youth': 0.009009009009009009,
#                           'five': 0.009009009009009009,
#                           'deaflympics': 0.009009009009009009,
#                           'special': 0.009009009009009009,
#                           'abuse': 0.009009009009009009,
#                           'eastern': 0.009009009009009009,
#                           'acceptance': 0.009009009009009009,
#                           'growing': 0.009009009009009009,
#                           'issue': 0.009009009009009009,
#                           'cancellation': 0.009009009009009009,
#                           'and': 0.018018018018018018,
#                           'cold': 0.009009009009009009,
#                           'olympics': 0.036036036036036036,
#                           'covid': 0.009009009009009009,
#                           'decision': 0.009009009009009009,
#                           'host': 0.018018018018018018,
#                           'sports': 0.009009009009009009,
#                           'opening': 0.009009009009009009,
#                           'point': 0.009009009009009009,
#                           'chance': 0.009009009009009009,
#                           'sanctuary': 0.009009009009009009,
#                           'pankration': 0.009009009009009009,
#                           'participating': 0.009009009009009009,
#                           'greeks': 0.009009009009009009,
#                           'truce': 0.009009009009009009,
#                           'origin': 0.009009009009009009,
#                           'most': 0.02702702702702703,
#                           'progenitors': 0.009009009009009009,
#                           'custom': 0.009009009009009009,
#                           'myth': 0.009009009009009009,
#                           'winners': 0.018018018018018018,
#                           'city': 0.009009009009009009,
#                           'events': 0.009009009009009009,
#                           'panhellenic': 0.009009009009009009,
#                           'pythian': 0.009009009009009009,
#                           'nemean': 0.009009009009009009,
#                           'isthmian': 0.009009009009009009,
#                           'height': 0.009009009009009009,
#                           'romans': 0.009009009009009009,
#                           'emperor': 0.009009009009009009,
#                           'destruction': 0.009009009009009009}),
#              'modern': defaultdict(int,
#                          {'olympic': 0.3333333333333333,
#                           'games': 0.3333333333333333,
#                           'myth': 0.3333333333333333}),
#              'olympic': defaultdict(int,
#                          {'games': 0.4444444444444444,
#                           'committee': 0.037037037037037035,
#                           'movement': 0.1111111111111111,
#                           'charter': 0.07407407407407407,
#                           'committees': 0.037037037037037035,
#                           'programme': 0.037037037037037035,
#                           'rituals': 0.037037037037037035,
#                           'flag': 0.037037037037037035,
#                           'medals': 0.037037037037037035,
#                           'peace': 0.037037037037037035,
#                           'and': 0.037037037037037035,
#                           'stadium': 0.037037037037037035,
#                           'champion': 0.037037037037037035}),
#              'games': defaultdict(int,
#                          {'or': 0.02702702702702703,
#                           'are': 0.05405405405405406,
#                           'generally': 0.02702702702702703,
#                           'held': 0.02702702702702703,
#                           'in': 0.02702702702702703,
#                           'with': 0.02702702702702703,
#                           'etkn': 0.21621621621621623,
#                           'for': 0.10810810810810811,
#                           'pan': 0.02702702702702703,
#                           'and': 0.05405405405405406,
#                           'according': 0.02702702702702703,
#                           'have': 0.02702702702702703,
#                           'also': 0.02702702702702703,
#                           'were': 0.10810810810810811,
#                           'featured': 0.05405405405405406,
#                           'all': 0.02702702702702703,
#                           'olympic': 0.02702702702702703,
#                           'which': 0.02702702702702703,
#                           'the': 0.02702702702702703,
#                           'reached': 0.02702702702702703,
#                           'officially': 0.02702702702702703}),
#              'or': defaultdict(int, {'olympics': 0.5, 'truce': 0.5}),
#              'olympics': defaultdict(int,
#                          {'are': 0.08333333333333333,
#                           'every': 0.08333333333333333,
#                           'etkn': 0.08333333333333333,
#                           'large': 0.08333333333333333,
#                           'and': 0.25,
#                           'were': 0.16666666666666666,
#                           'combined': 0.08333333333333333,
#                           'is': 0.16666666666666666}),
#              'are': defaultdict(int,
#                          {'the': 0.16666666666666666,
#                           'considered': 0.16666666666666666,
#                           'normally': 0.16666666666666666,
#                           'not': 0.16666666666666666,
#                           'several': 0.16666666666666666,
#                           'often': 0.16666666666666666}),
#              'leading': defaultdict(int, {'international': 0.5, 'to': 0.5}),
#              'international': defaultdict(int,
#                          {'sporting': 0.25,
#                           'olympic': 0.25,
#                           'sports': 0.25,
#                           'fame': 0.25}),
#              'sporting': defaultdict(int, {'events': 1.0}),
#              'events': defaultdict(int,
#                          {'featuring': 0.14285714285714285,
#                           'etkn': 0.42857142857142855,
#                           'a': 0.14285714285714285,
#                           'alongside': 0.14285714285714285,
#                           'were': 0.14285714285714285}),
#              'featuring': defaultdict(int, {'summer': 0.5, 'sporting': 0.5}),
#              'summer': defaultdict(int,
#                          {'and': 0.6666666666666666,
#                           'olympics': 0.3333333333333333}),
#              'and': defaultdict(int,
#                          {'winter': 0.057692307692307696,
#                           'territories': 0.019230769230769232,
#                           'since': 0.019230769230769232,
#                           'individuals': 0.019230769230769232,
#                           'authority': 0.019230769230769232,
#                           'st': 0.019230769230769232,
#                           'ice': 0.019230769230769232,
#                           'pacific': 0.019230769230769232,
#                           'the': 0.09615384615384616,
#                           'technological': 0.019230769230769232,
#                           'general': 0.019230769230769232,
#                           'olympics': 0.038461538461538464,
#                           'organising': 0.019230769230769232,
#                           'organises': 0.019230769230769232,
#                           'funds': 0.019230769230769232,
#                           'symbols': 0.019230769230769232,
#                           'torch': 0.019230769230769232,
#                           'closing': 0.019230769230769232,
#                           'events': 0.019230769230769232,
#                           'third': 0.019230769230769232,
#                           'bronze': 0.019230769230769232,
#                           'overseas': 0.019230769230769232,
#                           'controversies': 0.019230769230769232,
#                           'terrorism': 0.019230769230769232,
#                           'its': 0.019230769230769232,
#                           'international': 0.019230769230769232,
#                           'country': 0.019230769230769232,
#                           'athletic': 0.019230769230769232,
#                           'kingdoms': 0.019230769230769232,
#                           'chariot': 0.019230769230769232,
#                           'legend': 0.019230769230769232,
#                           'his': 0.019230769230769232,
#                           'established': 0.019230769230769232,
#                           'called': 0.019230769230769232,
#                           'javelin': 0.019230769230769232,
#                           'wrestling': 0.019230769230769232,
#                           'equestrian': 0.019230769230769232,
#                           'pelops': 0.019230769230769232,
#                           'mythical': 0.019230769230769232,
#                           'immortalised': 0.019230769230769232,
#                           'statues': 0.019230769230769232,
#                           'this': 0.019230769230769232,
#                           'th': 0.019230769230769232,
#                           'influence': 0.019230769230769232,
#                           'practices': 0.019230769230769232}),
#              'winter': defaultdict(int,
#                          {'sports': 0.25, 'olympics': 0.5, 'olympic': 0.25}),
#              'sports': defaultdict(int,
#                          {'competitions': 0.125,
#                           'competition': 0.125,
#                           'the': 0.125,
#                           'that': 0.125,
#                           'federations': 0.125,
#                           'to': 0.125,
#                           'and': 0.125,
#                           'such': 0.125}),
#              'competitions': defaultdict(int, {'in': 0.5, 'etkn': 0.5}),
#              'in': defaultdict(int,
#                          {'which': 0.09090909090909091,
#                           'a': 0.09090909090909091,
#                           'olympia': 0.09090909090909091,
#                           'leading': 0.045454545454545456,
#                           'athens': 0.045454545454545456,
#                           'etkn': 0.045454545454545456,
#                           'the': 0.18181818181818182,
#                           'several': 0.045454545454545456,
#                           'different': 0.045454545454545456,
#                           'each': 0.045454545454545456,
#                           'mystery': 0.045454545454545456,
#                           'bc': 0.045454545454545456,
#                           'his': 0.045454545454545456,
#                           'poems': 0.045454545454545456,
#                           'importance': 0.045454545454545456,
#                           'greece': 0.045454545454545456}),
#              'which': defaultdict(int,
#                          {'thousands': 0.2,
#                           'they': 0.2,
#                           'encompasses': 0.2,
#                           'later': 0.2,
#                           'included': 0.2}),
#              'thousands': defaultdict(int, {'of': 1.0}),
#              'of': defaultdict(int,
#                          {'athletes': 0.02702702702702703,
#                           'competitions': 0.02702702702702703,
#                           'the': 0.2972972972972973,
#                           'these': 0.02702702702702703,
#                           'economic': 0.02702702702702703,
#                           'amateur': 0.02702702702702703,
#                           'professional': 0.02702702702702703,
#                           'mass': 0.02702702702702703,
#                           'corporate': 0.02702702702702703,
#                           'international': 0.02702702702702703,
#                           'zeus': 0.02702702702702703,
#                           'several': 0.02702702702702703,
#                           'ancient': 0.02702702702702703,
#                           'hostilities': 0.02702702702702703,
#                           'holding': 0.02702702702702703,
#                           'distance': 0.02702702702702703,
#                           'a': 0.08108108108108109,
#                           'elis': 0.02702702702702703,
#                           'fundamental': 0.02702702702702703,
#                           'olympia': 0.02702702702702703,
#                           'pisatis': 0.02702702702702703,
#                           'their': 0.05405405405405406,
#                           'time': 0.02702702702702703,
#                           'all': 0.02702702702702703}),
#              'athletes': defaultdict(int,
#                          {'from': 0.16666666666666666,
#                           'with': 0.3333333333333333,
#                           'aged': 0.16666666666666666,
#                           'participating': 0.16666666666666666,
#                           'competed': 0.16666666666666666}),
#              'from': defaultdict(int,
#                          {'around': 0.25, 'the': 0.5, 'pure': 0.25}),
#              'around': defaultdict(int, {'the': 1.0}),
#              'world': defaultdict(int,
#                          {'participate': 0.16666666666666666,
#                           'foremost': 0.16666666666666666,
#                           'championships': 0.16666666666666666,
#                           'games': 0.16666666666666666,
#                           'wars': 0.16666666666666666,
#                           'etkn': 0.16666666666666666}),
#              'participate': defaultdict(int, {'in': 1.0}),
#              'a': defaultdict(int,
#                          {'variety': 0.15384615384615385,
#                           'result': 0.07692307692307693,
#                           'modern': 0.07692307692307693,
#                           'straight': 0.07692307692307693,
#                           'stadion': 0.07692307692307693,
#                           'unit': 0.07692307692307693,
#                           'footrace': 0.07692307692307693,
#                           'pentathlon': 0.07692307692307693,
#                           'jumping': 0.07692307692307693,
#                           'foot': 0.07692307692307693,
#                           'cook': 0.07692307692307693,
#                           'cycle': 0.07692307692307693}),
#              'variety': defaultdict(int, {'of': 1.0}),
#              'etkn': defaultdict(int, {'stkn': 1.0}),
#              'considered': defaultdict(int, {'the': 1.0}),
#              'foremost': defaultdict(int, {'sports': 1.0}),
#              'competition': defaultdict(int, {'with': 0.5, 'was': 0.5}),
#              'with': defaultdict(int,
#                          {'more': 0.2,
#                           'the': 0.4,
#                           'disabilities': 0.2,
#                           'king': 0.2}),
#              'more': defaultdict(int, {'than': 1.0}),
#              'than': defaultdict(int, {'teams': 1.0}),
#              'teams': defaultdict(int, {'representing': 0.5, 'etkn': 0.5}),
#              'representing': defaultdict(int, {'sovereign': 1.0}),
#              'sovereign': defaultdict(int, {'states': 1.0}),
#              'states': defaultdict(int,
#                          {'and': 0.6666666666666666,
#                           'were': 0.3333333333333333}),
#              'territories': defaultdict(int,
#                          {'participating': 0.3333333333333333,
#                           'are': 0.3333333333333333,
#                           'unmolested': 0.3333333333333333}),
#              'participating': defaultdict(int,
#                          {'by': 0.3333333333333333,
#                           'at': 0.3333333333333333,
#                           'city': 0.3333333333333333}),
#              'by': defaultdict(int,
#                          {'default': 0.14285714285714285,
#                           'the': 0.2857142857142857,
#                           'coubertin': 0.14285714285714285,
#                           'zeus': 0.14285714285714285,
#                           'phidias': 0.14285714285714285,
#                           'greeks': 0.14285714285714285}),
#              'default': defaultdict(int, {'the': 1.0}),
#              'generally': defaultdict(int, {'substitute': 1.0}),
#              'substitute': defaultdict(int, {'for': 1.0}),
#              'for': defaultdict(int,
#                          {'any': 0.08333333333333333,
#                           'snow': 0.08333333333333333,
#                           'athletes': 0.16666666666666666,
#                           'sports': 0.08333333333333333,
#                           'each': 0.16666666666666666,
#                           'choosing': 0.08333333333333333,
#                           'the': 0.16666666666666666,
#                           'steps': 0.08333333333333333,
#                           'his': 0.08333333333333333}),
#              'any': defaultdict(int, {'world': 1.0}),
#              'championships': defaultdict(int, {'the': 1.0}),
#              'year': defaultdict(int, {'in': 0.5, 'period': 0.5}),
#              'they': defaultdict(int, {'take': 0.5, 'were': 0.5}),
#              'take': defaultdict(int, {'place': 1.0}),
#              'place': defaultdict(int, {'however': 0.5, 'finishers': 0.5}),
#              'however': defaultdict(int, {'each': 1.0}),
#              'each': defaultdict(int,
#                          {'class': 0.25,
#                           'specific': 0.25,
#                           'games': 0.25,
#                           'event': 0.25}),
#              'class': defaultdict(int, {'usually': 1.0}),
#              'usually': defaultdict(int, {'maintains': 1.0}),
#              'maintains': defaultdict(int, {'their': 1.0}),
#              'their': defaultdict(int,
#                          {'own': 0.3333333333333333,
#                           'creation': 0.16666666666666666,
#                           'wars': 0.16666666666666666,
#                           'units': 0.16666666666666666,
#                           'success': 0.16666666666666666}),
#              'own': defaultdict(int, {'records': 0.5, 'teams': 0.5}),
#              'records': defaultdict(int, {'etkn': 1.0}),
#              'normally': defaultdict(int, {'held': 1.0}),
#              'held': defaultdict(int,
#                          {'every': 0.6666666666666666,
#                           'in': 0.16666666666666666,
#                           'date': 0.16666666666666666}),
#              'every': defaultdict(int,
#                          {'four': 0.625, 'two': 0.25, 'nation': 0.125}),
#              'four': defaultdict(int,
#                          {'years': 0.8333333333333334,
#                           'year': 0.16666666666666666}),
#              'years': defaultdict(int,
#                          {'and': 0.2857142857142857,
#                           'during': 0.14285714285714285,
#                           'the': 0.14285714285714285,
#                           'at': 0.14285714285714285,
#                           'etkn': 0.14285714285714285,
#                           'starting': 0.14285714285714285}),
#              'since': defaultdict(int, {'have': 1.0}),
#              'have': defaultdict(int, {'alternated': 0.5, 'grown': 0.5}),
#              'alternated': defaultdict(int, {'between': 1.0}),
#              'between': defaultdict(int, {'the': 1.0}),
#              'two': defaultdict(int, {'years': 1.0}),
#              'during': defaultdict(int, {'the': 1.0}),
#              'period': defaultdict(int, {'etkn': 0.5, 'known': 0.5}),
#              'creation': defaultdict(int, {'was': 0.5, 'of': 0.5}),
#              'was': defaultdict(int,
#                          {'inspired': 0.14285714285714285,
#                           'among': 0.14285714285714285,
#                           'known': 0.14285714285714285,
#                           'heracles': 0.14285714285714285,
#                           'the': 0.14285714285714285,
#                           'famous': 0.14285714285714285,
#                           'used': 0.14285714285714285}),
#              'inspired': defaultdict(int, {'by': 1.0}),
#              'ancient': defaultdict(int,
#                          {'olympic': 0.3333333333333333,
#                           'greece': 0.16666666666666666,
#                           'greek': 0.16666666666666666,
#                           'olympics': 0.16666666666666666,
#                           'games': 0.16666666666666666}),
#              'olympia': defaultdict(int,
#                          {'greece': 0.3333333333333333,
#                           'to': 0.16666666666666666,
#                           'listing': 0.16666666666666666,
#                           'and': 0.16666666666666666,
#                           'etkn': 0.16666666666666666}),
#              'greece': defaultdict(int, {'from': 0.25, 'etkn': 0.75}),
#              'th': defaultdict(int,
#                          {'century': 0.4, 'and': 0.4, 'centuries': 0.2}),
#              'century': defaultdict(int, {'bc': 0.5, 'ad': 0.5}),
#              'bc': defaultdict(int,
#                          {'to': 0.25,
#                           'this': 0.25,
#                           'etkn': 0.25,
#                           'but': 0.25}),
#              'to': defaultdict(int,
#                          {'the': 0.42857142857142855,
#                           'adapt': 0.047619047619047616,
#                           'a': 0.047619047619047616,
#                           'shift': 0.047619047619047616,
#                           'be': 0.047619047619047616,
#                           'field': 0.047619047619047616,
#                           'attain': 0.047619047619047616,
#                           'showcase': 0.047619047619047616,
#                           'olympia': 0.047619047619047616,
#                           'pass': 0.047619047619047616,
#                           'legend': 0.047619047619047616,
#                           'zeus': 0.047619047619047616,
#                           'when': 0.047619047619047616}),
#              'ad': defaultdict(int,
#                          {'etkn': 0.3333333333333333,
#                           'when': 0.6666666666666666}),
#              'baron': defaultdict(int, {'pierre': 1.0}),
#              'pierre': defaultdict(int, {'de': 1.0}),
#              'de': defaultdict(int, {'coubertin': 1.0}),
#              'coubertin': defaultdict(int, {'founded': 0.5, 'to': 0.5}),
#              'founded': defaultdict(int, {'the': 1.0}),
#              'committee': defaultdict(int, {'ioc': 1.0}),
#              'ioc': defaultdict(int,
#                          {'in': 0.14285714285714285,
#                           'is': 0.2857142857142857,
#                           'also': 0.2857142857142857,
#                           'has': 0.14285714285714285,
#                           'to': 0.14285714285714285}),
#              'first': defaultdict(int,
#                          {'modern': 0.25,
#                           'second': 0.25,
#                           'called': 0.25,
#                           'olympic': 0.25}),
#              'athens': defaultdict(int, {'in': 1.0}),
#              'is': defaultdict(int,
#                          {'the': 0.1,
#                           'responsible': 0.1,
#                           'now': 0.1,
#                           'a': 0.1,
#                           'shrouded': 0.1,
#                           'bc': 0.1,
#                           'based': 0.1,
#                           'no': 0.1,
#                           'ad': 0.2}),
#              'governing': defaultdict(int, {'body': 1.0}),
#              'body': defaultdict(int, {'of': 0.5, 'the': 0.5}),
#              'movement': defaultdict(int,
#                          {'which': 0.3333333333333333,
#                           'during': 0.3333333333333333,
#                           'consists': 0.3333333333333333}),
#              'encompasses': defaultdict(int, {'all': 1.0}),
#              'all': defaultdict(int,
#                          {'entities': 0.25,
#                           'conflicts': 0.25,
#                           'pagan': 0.25,
#                           'greek': 0.25}),
#              'entities': defaultdict(int, {'and': 1.0}),
#              'individuals': defaultdict(int, {'involved': 1.0}),
#              'involved': defaultdict(int, {'in': 1.0}),
#              'charter': defaultdict(int, {'defining': 0.5, 'etkn': 0.5}),
#              'defining': defaultdict(int, {'its': 1.0}),
#              'its': defaultdict(int,
#                          {'structure': 0.3333333333333333,
#                           'media': 0.3333333333333333,
#                           'completion': 0.3333333333333333}),
#              'structure': defaultdict(int, {'and': 1.0}),
#              'authority': defaultdict(int, {'etkn': 1.0}),
#              'evolution': defaultdict(int, {'of': 1.0}),
#              'st': defaultdict(int, {'centuries': 1.0}),
#              'centuries': defaultdict(int, {'has': 0.5, 'bc': 0.5}),
#              'has': defaultdict(int,
#                          {'resulted': 0.16666666666666666,
#                           'needed': 0.16666666666666666,
#                           'created': 0.3333333333333333,
#                           'been': 0.16666666666666666,
#                           'it': 0.16666666666666666}),
#              'resulted': defaultdict(int, {'in': 1.0}),
#              'several': defaultdict(int,
#                          {'changes': 0.3333333333333333,
#                           'olympic': 0.3333333333333333,
#                           'city': 0.3333333333333333}),
#              'changes': defaultdict(int, {'to': 1.0}),
#              'some': defaultdict(int, {'of': 1.0}),
#              'these': defaultdict(int, {'adjustments': 0.5, 'games': 0.5}),
#              'adjustments': defaultdict(int, {'include': 1.0}),
#              'include': defaultdict(int, {'the': 1.0}),
#              'snow': defaultdict(int, {'and': 1.0}),
#              'ice': defaultdict(int, {'sports': 1.0}),
#              'paralympic': defaultdict(int, {'games': 1.0}),
#              'disabilities': defaultdict(int, {'the': 1.0}),
#              'youth': defaultdict(int, {'olympic': 1.0}),
#              'aged': defaultdict(int, {'to': 1.0}),
#              'five': defaultdict(int, {'continental': 1.0}),
#              'continental': defaultdict(int, {'games': 1.0}),
#              'pan': defaultdict(int, {'american': 1.0}),
#              'american': defaultdict(int, {'african': 1.0}),
#              'african': defaultdict(int, {'asian': 1.0}),
#              'asian': defaultdict(int, {'european': 1.0}),
#              'european': defaultdict(int, {'and': 1.0}),
#              'pacific': defaultdict(int, {'and': 1.0}),
#              'that': defaultdict(int,
#                          {'are': 0.16666666666666666,
#                           'nearly': 0.16666666666666666,
#                           'during': 0.16666666666666666,
#                           'after': 0.16666666666666666,
#                           'coroebus': 0.16666666666666666,
#                           'all': 0.16666666666666666}),
#              'not': defaultdict(int, {'contested': 1.0}),
#              'contested': defaultdict(int, {'in': 0.5, 'at': 0.5}),
#              'also': defaultdict(int,
#                          {'endorses': 0.25,
#                           'determines': 0.25,
#                           'provide': 0.25,
#                           'combat': 0.25}),
#              'endorses': defaultdict(int, {'the': 1.0}),
#              'deaflympics': defaultdict(int, {'and': 1.0}),
#              'special': defaultdict(int, {'olympics': 1.0}),
#              'needed': defaultdict(int, {'to': 1.0}),
#              'adapt': defaultdict(int, {'to': 1.0}),
#              'economic': defaultdict(int, {'political': 1.0}),
#              'political': defaultdict(int, {'and': 1.0}),
#              'technological': defaultdict(int, {'advancements': 1.0}),
#              'advancements': defaultdict(int, {'etkn': 1.0}),
#              'abuse': defaultdict(int, {'of': 1.0}),
#              'amateur': defaultdict(int, {'rules': 1.0}),
#              'rules': defaultdict(int, {'by': 1.0}),
#              'eastern': defaultdict(int, {'bloc': 1.0}),
#              'bloc': defaultdict(int, {'nations': 1.0}),
#              'nations': defaultdict(int, {'prompted': 1.0}),
#              'prompted': defaultdict(int, {'the': 1.0}),
#              'shift': defaultdict(int, {'away': 1.0}),
#              'away': defaultdict(int, {'from': 1.0}),
#              'pure': defaultdict(int, {'amateurism': 1.0}),
#              'amateurism': defaultdict(int, {'as': 1.0}),
#              'as': defaultdict(int,
#                          {'envisioned': 0.06666666666666667,
#                           'a': 0.06666666666666667,
#                           'the': 0.4666666666666667,
#                           'well': 0.06666666666666667,
#                           'wrestling': 0.06666666666666667,
#                           'an': 0.13333333333333333,
#                           'one': 0.06666666666666667,
#                           'to': 0.06666666666666667}),
#              'envisioned': defaultdict(int, {'by': 1.0}),
#              'acceptance': defaultdict(int, {'of': 1.0}),
#              'professional': defaultdict(int, {'athletes': 1.0}),
#              'at': defaultdict(int,
#                          {'the': 0.6666666666666666,
#                           'olympia': 0.3333333333333333}),
#              'growing': defaultdict(int, {'importance': 1.0}),
#              'importance': defaultdict(int,
#                          {'of': 0.3333333333333333,
#                           'featuring': 0.3333333333333333,
#                           'as': 0.3333333333333333}),
#              'mass': defaultdict(int, {'media': 1.0}),
#              'media': defaultdict(int, {'has': 0.5, 'exposure': 0.5}),
#              'created': defaultdict(int, {'the': 0.5, 'numerous': 0.5}),
#              'issue': defaultdict(int, {'of': 1.0}),
#              'corporate': defaultdict(int, {'sponsorship': 1.0}),
#              'sponsorship': defaultdict(int, {'and': 1.0}),
#              'general': defaultdict(int, {'commercialisation': 1.0}),
#              'commercialisation': defaultdict(int, {'of': 1.0}),
#              'wars': defaultdict(int, {'led': 0.5, 'etkn': 0.5}),
#              'led': defaultdict(int, {'to': 1.0}),
#              'cancellation': defaultdict(int, {'of': 1.0}),
#              'large': defaultdict(int, {'scale': 1.0}),
#              'scale': defaultdict(int, {'boycotts': 1.0}),
#              'boycotts': defaultdict(int, {'during': 0.5, 'doping': 0.5}),
#              'cold': defaultdict(int, {'war': 1.0}),
#              'war': defaultdict(int, {'limited': 1.0}),
#              'limited': defaultdict(int, {'participation': 1.0}),
#              'participation': defaultdict(int, {'in': 1.0}),
#              'were': defaultdict(int,
#                          {'postponed': 0.2,
#                           'religious': 0.1,
#                           'finished': 0.1,
#                           'travelling': 0.1,
#                           'protected': 0.1,
#                           'of': 0.1,
#                           'admired': 0.1,
#                           'held': 0.1,
#                           'part': 0.1}),
#              'postponed': defaultdict(int, {'until': 1.0}),
#              'until': defaultdict(int, {'as': 0.5, 'the': 0.5}),
#              'result': defaultdict(int, {'of': 1.0}),
#              'covid': defaultdict(int, {'pandemic': 1.0}),
#              'pandemic': defaultdict(int, {'etkn': 1.0}),
#              'consists': defaultdict(int, {'of': 1.0}),
#              'federations': defaultdict(int, {'ifs': 1.0}),
#              'ifs': defaultdict(int, {'national': 1.0}),
#              'national': defaultdict(int, {'olympic': 0.5, 'and': 0.5}),
#              'committees': defaultdict(int, {'nocs': 0.5, 'for': 0.5}),
#              'nocs': defaultdict(int, {'and': 1.0}),
#              'organising': defaultdict(int, {'committees': 1.0}),
#              'specific': defaultdict(int, {'olympic': 1.0}),
#              'decision': defaultdict(int, {'making': 1.0}),
#              'making': defaultdict(int, {'body': 1.0}),
#              'responsible': defaultdict(int, {'for': 1.0}),
#              'choosing': defaultdict(int, {'the': 1.0}),
#              'host': defaultdict(int, {'city': 1.0}),
#              'city': defaultdict(int,
#                          {'for': 0.2, 'and': 0.2, 'states': 0.4, 'of': 0.2}),
#              'organises': defaultdict(int, {'and': 1.0}),
#              'funds': defaultdict(int, {'the': 1.0}),
#              'according': defaultdict(int, {'to': 1.0}),
#              'determines': defaultdict(int, {'the': 1.0}),
#              'programme': defaultdict(int, {'consisting': 1.0}),
#              'consisting': defaultdict(int, {'of': 1.0}),
#              'be': defaultdict(int, {'contested': 0.5, 'eliminated': 0.5}),
#              'there': defaultdict(int, {'are': 0.5, 'is': 0.5}),
#              'rituals': defaultdict(int, {'and': 1.0}),
#              'symbols': defaultdict(int, {'such': 1.0}),
#              'such': defaultdict(int, {'as': 1.0}),
#              'flag': defaultdict(int, {'and': 1.0}),
#              'torch': defaultdict(int, {'as': 1.0}),
#              'well': defaultdict(int, {'as': 1.0}),
#              'opening': defaultdict(int, {'and': 1.0}),
#              'closing': defaultdict(int, {'ceremonies': 1.0}),
#              'ceremonies': defaultdict(int, {'etkn': 1.0}),
#              'over': defaultdict(int, {'athletes': 1.0}),
#              'competed': defaultdict(int, {'at': 1.0}),
#              'combined': defaultdict(int, {'in': 1.0}),
#              'different': defaultdict(int, {'sports': 1.0}),
#              'second': defaultdict(int, {'and': 1.0}),
#              'third': defaultdict(int, {'place': 1.0}),
#              'finishers': defaultdict(int, {'in': 1.0}),
#              'event': defaultdict(int, {'receive': 0.5, 'discus': 0.5}),
#              'receive': defaultdict(int, {'olympic': 1.0}),
#              'medals': defaultdict(int, {'gold': 1.0}),
#              'gold': defaultdict(int, {'silver': 1.0}),
#              'silver': defaultdict(int, {'and': 1.0}),
#              'bronze': defaultdict(int, {'respectively': 1.0}),
#              'respectively': defaultdict(int, {'etkn': 1.0}),
#              'grown': defaultdict(int, {'to': 1.0}),
#              'point': defaultdict(int, {'that': 1.0}),
#              'nearly': defaultdict(int, {'every': 1.0}),
#              'nation': defaultdict(int, {'is': 1.0}),
#              'now': defaultdict(int, {'represented': 1.0}),
#              'represented': defaultdict(int, {'colonies': 1.0}),
#              'colonies': defaultdict(int, {'and': 1.0}),
#              'overseas': defaultdict(int, {'territories': 1.0}),
#              'often': defaultdict(int, {'allowed': 1.0}),
#              'allowed': defaultdict(int, {'to': 1.0}),
#              'field': defaultdict(int, {'their': 1.0}),
#              'this': defaultdict(int,
#                          {'growth': 0.16666666666666666,
#                           'cessation': 0.16666666666666666,
#                           'idea': 0.16666666666666666,
#                           'distance': 0.16666666666666666,
#                           'is': 0.16666666666666666,
#                           'period': 0.16666666666666666}),
#              'growth': defaultdict(int, {'has': 1.0}),
#              'numerous': defaultdict(int, {'challenges': 1.0}),
#              'challenges': defaultdict(int, {'and': 1.0}),
#              'controversies': defaultdict(int, {'including': 1.0}),
#              'including': defaultdict(int, {'boycotts': 1.0}),
#              'doping': defaultdict(int, {'bribery': 1.0}),
#              'bribery': defaultdict(int, {'and': 1.0}),
#              'terrorism': defaultdict(int, {'etkn': 1.0}),
#              'exposure': defaultdict(int, {'provide': 1.0}),
#              'provide': defaultdict(int, {'athletes': 0.5, 'an': 0.5}),
#              'chance': defaultdict(int, {'to': 1.0}),
#              'attain': defaultdict(int, {'national': 1.0}),
#              'fame': defaultdict(int, {'etkn': 1.0}),
#              'an': defaultdict(int,
#                          {'opportunity': 0.3333333333333333,
#                           'honour': 0.3333333333333333,
#                           'olympiad': 0.3333333333333333}),
#              'opportunity': defaultdict(int, {'for': 1.0}),
#              'country': defaultdict(int, {'to': 1.0}),
#              'showcase': defaultdict(int, {'themselves': 1.0}),
#              'themselves': defaultdict(int, {'to': 1.0}),
#              'religious': defaultdict(int,
#                          {'and': 0.3333333333333333,
#                           'pilgrims': 0.3333333333333333,
#                           'importance': 0.3333333333333333}),
#              'athletic': defaultdict(int, {'festivals': 0.5, 'but': 0.5}),
#              'festivals': defaultdict(int, {'held': 1.0}),
#              'sanctuary': defaultdict(int, {'of': 1.0}),
#              'zeus': defaultdict(int,
#                          {'in': 0.2, 'etkn': 0.4, 'as': 0.2, 'whose': 0.2}),
#              'among': defaultdict(int, {'representatives': 0.5, 'the': 0.5}),
#              'representatives': defaultdict(int, {'of': 1.0}),
#              'kingdoms': defaultdict(int, {'of': 1.0}),
#              'featured': defaultdict(int, {'mainly': 0.5, 'running': 0.5}),
#              'mainly': defaultdict(int, {'athletic': 1.0}),
#              'but': defaultdict(int, {'also': 0.5, 'then': 0.5}),
#              'combat': defaultdict(int, {'sports': 1.0}),
#              'wrestling': defaultdict(int,
#                          {'and': 0.3333333333333333,
#                           'boxing': 0.3333333333333333,
#                           'pankration': 0.3333333333333333}),
#              'pankration': defaultdict(int, {'horse': 0.5, 'and': 0.5}),
#              'horse': defaultdict(int, {'and': 1.0}),
#              'chariot': defaultdict(int, {'racing': 0.5, 'race': 0.5}),
#              'racing': defaultdict(int, {'events': 1.0}),
#              'it': defaultdict(int,
#                          {'has': 0.3333333333333333,
#                           'was': 0.3333333333333333,
#                           'that': 0.3333333333333333}),
#              'been': defaultdict(int, {'widely': 1.0}),
#              'widely': defaultdict(int, {'written': 0.5, 'accepted': 0.5}),
#              'written': defaultdict(int, {'that': 1.0}),
#              'conflicts': defaultdict(int, {'among': 1.0}),
#              'finished': defaultdict(int, {'etkn': 1.0}),
#              'cessation': defaultdict(int, {'of': 1.0}),
#              'hostilities': defaultdict(int, {'was': 1.0}),
#              'known': defaultdict(int, {'as': 1.0}),
#              'peace': defaultdict(int, {'or': 1.0}),
#              'truce': defaultdict(int, {'etkn': 0.5, 'did': 0.5}),
#              'idea': defaultdict(int, {'is': 1.0}),
#              'myth': defaultdict(int, {'because': 0.5, 'continues': 0.5}),
#              'because': defaultdict(int, {'the': 0.5, 'they': 0.5}),
#              'greeks': defaultdict(int, {'never': 0.5, 'as': 0.5}),
#              'never': defaultdict(int, {'suspended': 1.0}),
#              'suspended': defaultdict(int, {'their': 1.0}),
#              'did': defaultdict(int, {'allow': 1.0}),
#              'allow': defaultdict(int, {'those': 1.0}),
#              'those': defaultdict(int, {'religious': 1.0}),
#              'pilgrims': defaultdict(int, {'who': 1.0}),
#              'who': defaultdict(int, {'were': 0.5, 'first': 0.5}),
#              'travelling': defaultdict(int, {'to': 1.0}),
#              'pass': defaultdict(int, {'through': 1.0}),
#              'through': defaultdict(int, {'warring': 1.0}),
#              'warring': defaultdict(int, {'territories': 1.0}),
#              'unmolested': defaultdict(int, {'because': 1.0}),
#              'protected': defaultdict(int, {'by': 1.0}),
#              'origin': defaultdict(int, {'of': 1.0}),
#              'shrouded': defaultdict(int, {'in': 1.0}),
#              'mystery': defaultdict(int, {'and': 1.0}),
#              'legend': defaultdict(int, {'one': 0.5, 'it': 0.5}),
#              'one': defaultdict(int, {'of': 1.0}),
#              'most': defaultdict(int,
#                          {'popular': 0.3333333333333333,
#                           'widely': 0.3333333333333333,
#                           'commonly': 0.3333333333333333}),
#              'popular': defaultdict(int, {'myths': 1.0}),
#              'myths': defaultdict(int, {'identifies': 1.0}),
#              'identifies': defaultdict(int, {'heracles': 1.0}),
#              'heracles': defaultdict(int,
#                          {'and': 0.3333333333333333,
#                           'who': 0.3333333333333333,
#                           'completed': 0.3333333333333333}),
#              'his': defaultdict(int,
#                          {'father': 0.2,
#                           'twelve': 0.2,
#                           'temple': 0.2,
#                           'chariot': 0.2,
#                           'successor': 0.2}),
#              'father': defaultdict(int, {'zeus': 1.0}),
#              'progenitors': defaultdict(int, {'of': 1.0}),
#              'called': defaultdict(int, {'the': 0.5, 'this': 0.5}),
#              'established': defaultdict(int, {'the': 1.0}),
#              'custom': defaultdict(int, {'of': 1.0}),
#              'holding': defaultdict(int, {'them': 1.0}),
#              'them': defaultdict(int, {'every': 1.0}),
#              'continues': defaultdict(int, {'that': 1.0}),
#              'after': defaultdict(int, {'heracles': 1.0}),
#              'completed': defaultdict(int, {'his': 1.0}),
#              'twelve': defaultdict(int, {'labours': 1.0}),
#              'labours': defaultdict(int, {'he': 1.0}),
#              'he': defaultdict(int, {'built': 0.5, 'walked': 0.5}),
#              'built': defaultdict(int, {'the': 1.0}),
#              'stadium': defaultdict(int, {'as': 0.5, 'stage': 0.5}),
#              'honour': defaultdict(int, {'to': 1.0}),
#              'following': defaultdict(int, {'its': 1.0}),
#              'completion': defaultdict(int, {'he': 1.0}),
#              'walked': defaultdict(int, {'in': 1.0}),
#              'straight': defaultdict(int, {'line': 1.0}),
#              'line': defaultdict(int, {'for': 1.0}),
#              'steps': defaultdict(int, {'and': 1.0}),
#              'distance': defaultdict(int, {'a': 0.5, 'etkn': 0.5}),
#              'stadion': defaultdict(int, {'ancient': 1.0}),
#              'greek': defaultdict(int, {'latin': 0.5, 'temples': 0.5}),
#              'latin': defaultdict(int, {'stadium': 1.0}),
#              'stage': defaultdict(int, {'which': 1.0}),
#              'later': defaultdict(int, {'became': 1.0}),
#              'became': defaultdict(int, {'a': 1.0}),
#              'unit': defaultdict(int, {'of': 1.0}),
#              'accepted': defaultdict(int, {'inception': 1.0}),
#              'inception': defaultdict(int, {'date': 1.0}),
#              'date': defaultdict(int,
#                          {'for': 0.3333333333333333,
#                           'is': 0.3333333333333333,
#                           'commonly': 0.3333333333333333}),
#              'based': defaultdict(int, {'on': 1.0}),
#              'on': defaultdict(int, {'inscriptions': 1.0}),
#              'inscriptions': defaultdict(int, {'found': 1.0}),
#              'found': defaultdict(int, {'at': 1.0}),
#              'listing': defaultdict(int, {'the': 1.0}),
#              'winners': defaultdict(int, {'of': 1.0}),
#              'footrace': defaultdict(int, {'held': 1.0}),
#              'starting': defaultdict(int, {'in': 1.0}),
#              'running': defaultdict(int, {'events': 1.0}),
#              'pentathlon': defaultdict(int, {'consisting': 1.0}),
#              'jumping': defaultdict(int, {'event': 1.0}),
#              'discus': defaultdict(int, {'and': 1.0}),
#              'javelin': defaultdict(int, {'throws': 1.0}),
#              'throws': defaultdict(int, {'a': 1.0}),
#              'foot': defaultdict(int, {'race': 1.0}),
#              'race': defaultdict(int, {'and': 0.5, 'with': 0.5}),
#              'boxing': defaultdict(int, {'wrestling': 1.0}),
#              'equestrian': defaultdict(int, {'events': 1.0}),
#              'tradition': defaultdict(int, {'has': 1.0}),
#              'coroebus': defaultdict(int, {'a': 1.0}),
#              'cook': defaultdict(int, {'from': 1.0}),
#              'elis': defaultdict(int, {'was': 1.0}),
#              'champion': defaultdict(int, {'etkn': 1.0}),
#              'fundamental': defaultdict(int, {'religious': 1.0}),
#              'alongside': defaultdict(int, {'ritual': 1.0}),
#              'ritual': defaultdict(int, {'sacrifices': 1.0}),
#              'sacrifices': defaultdict(int, {'honouring': 1.0}),
#              'honouring': defaultdict(int, {'both': 1.0}),
#              'both': defaultdict(int, {'zeus': 1.0}),
#              'whose': defaultdict(int, {'famous': 1.0}),
#              'famous': defaultdict(int, {'statue': 0.5, 'for': 0.5}),
#              'statue': defaultdict(int, {'by': 1.0}),
#              'phidias': defaultdict(int, {'stood': 1.0}),
#              'stood': defaultdict(int, {'in': 1.0}),
#              'temple': defaultdict(int, {'at': 1.0}),
#              'pelops': defaultdict(int, {'divine': 0.5, 'was': 0.5}),
#              'divine': defaultdict(int, {'hero': 1.0}),
#              'hero': defaultdict(int, {'and': 1.0}),
#              'mythical': defaultdict(int, {'king': 1.0}),
#              'king': defaultdict(int, {'of': 0.5, 'oenomaus': 0.5}),
#              'oenomaus': defaultdict(int, {'of': 1.0}),
#              'pisatis': defaultdict(int, {'etkn': 1.0}),
#              'admired': defaultdict(int, {'and': 1.0}),
#              'immortalised': defaultdict(int, {'in': 1.0}),
#              'poems': defaultdict(int, {'and': 1.0}),
#              'statues': defaultdict(int, {'etkn': 1.0}),
#              'olympiad': defaultdict(int, {'was': 1.0}),
#              'used': defaultdict(int, {'by': 1.0}),
#              'units': defaultdict(int, {'of': 1.0}),
#              'time': defaultdict(int, {'measurement': 1.0}),
#              'measurement': defaultdict(int, {'etkn': 1.0}),
#              'part': defaultdict(int, {'of': 1.0}),
#              'cycle': defaultdict(int, {'known': 1.0}),
#              'panhellenic': defaultdict(int, {'games': 1.0}),
#              'included': defaultdict(int, {'the': 1.0}),
#              'pythian': defaultdict(int, {'games': 1.0}),
#              'nemean': defaultdict(int, {'games': 1.0}),
#              'isthmian': defaultdict(int, {'games': 1.0}),
#              'reached': defaultdict(int, {'the': 1.0}),
#              'height': defaultdict(int, {'of': 1.0}),
#              'success': defaultdict(int, {'in': 1.0}),
#              'then': defaultdict(int, {'gradually': 1.0}),
#              'gradually': defaultdict(int, {'declined': 1.0}),
#              'declined': defaultdict(int, {'in': 1.0}),
#              'romans': defaultdict(int, {'gained': 1.0}),
#              'gained': defaultdict(int, {'power': 1.0}),
#              'power': defaultdict(int, {'and': 1.0}),
#              'influence': defaultdict(int, {'in': 1.0}),
#              'while': defaultdict(int, {'there': 1.0}),
#              'no': defaultdict(int, {'scholarly': 1.0}),
#              'scholarly': defaultdict(int, {'consensus': 1.0}),
#              'consensus': defaultdict(int, {'as': 1.0}),
#              'when': defaultdict(int,
#                          {'the': 0.6666666666666666,
#                           'his': 0.3333333333333333}),
#              'officially': defaultdict(int, {'ended': 1.0}),
#              'ended': defaultdict(int, {'the': 1.0}),
#              'commonly': defaultdict(int, {'held': 0.5, 'cited': 0.5}),
#              'emperor': defaultdict(int, {'theodosius': 1.0}),
#              'theodosius': defaultdict(int, {'i': 0.5, 'ii': 0.5}),
#              'i': defaultdict(int, {'decreed': 1.0}),
#              'decreed': defaultdict(int, {'that': 1.0}),
#              'pagan': defaultdict(int, {'cults': 1.0}),
#              'cults': defaultdict(int, {'and': 1.0}),
#              'practices': defaultdict(int, {'be': 1.0}),
#              'eliminated': defaultdict(int, {'etkn': 1.0}),
#              'b': defaultdict(int, {'another': 1.0}),
#              'another': defaultdict(int, {'date': 1.0}),
#              'cited': defaultdict(int, {'is': 1.0}),
#              'successor': defaultdict(int, {'theodosius': 1.0}),
#              'ii': defaultdict(int, {'ordered': 1.0}),
#              'ordered': defaultdict(int, {'the': 1.0}),
#              'destruction': defaultdict(int, {'of': 1.0}),
#              'temples': defaultdict(int, {'etkn': 1.0})})

# %%
def bigram_gen(input_text):
    
    starting_words = input_text.split(' ')
    sentence = list(starting_words)
    next_word = ''

    while next_word != 'etkn':
        w1 = sentence[-1]
        if w1 in model_bi:
            # calls the next word given on the probability of that word itself
            next_word = random.choices(list(model_bi[w1].keys()), weights=model_bi[w1].values())[0]
            sentence.append(next_word)
        else:
            break
        
        if len(sentence) < 30:
            next_word = ''

    return ' '.join(sentence)

# %% [markdown]
# ### Trigram

# %%
model_tri = defaultdict(lambda: defaultdict(lambda: 0))

# %%
n_gram = 3
for i in range(n_gram,len(data)+1):
    w1 = data[i-n_gram+0]
    w2 = data[i-n_gram+1]
    w3 = data[i-n_gram+2]
    model_tri[(w1,w2)][w3] += 1

# %%
for w1_w2 in model_tri:
    total_count = float(sum(model_tri[w1_w2].values()))
    for w3 in model_tri[w1_w2]:
        model_tri[w1_w2][w3] /= total_count

# %%
model_tri
# Out:
# defaultdict(<function __main__.<lambda>()>,
#             {('stkn',
#               'the'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'modern': 0.04,
#                           'olympic': 0.16,
#                           'ioc': 0.16,
#                           'evolution': 0.04,
#                           'abuse': 0.04,
#                           'growing': 0.04,
#                           'first': 0.04,
#                           'games': 0.16,
#                           'ancient': 0.08,
#                           'truce': 0.04,
#                           'origin': 0.04,
#                           'myth': 0.04,
#                           'most': 0.04,
#                           'olympics': 0.04,
#                           'winners': 0.04}),
#              ('the',
#               'modern'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'olympic': 1.0}),
#              ('modern',
#               'olympic'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'games': 1.0}),
#              ('olympic',
#               'games'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'or': 0.08333333333333333,
#                           'are': 0.16666666666666666,
#                           'held': 0.08333333333333333,
#                           'with': 0.08333333333333333,
#                           'etkn': 0.25,
#                           'for': 0.16666666666666666,
#                           'were': 0.08333333333333333,
#                           'reached': 0.08333333333333333}),
#              ('games',
#               'or'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'olympics': 1.0}),
#              ('or',
#               'olympics'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'are': 1.0}),
#              ('olympics',
#               'are'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'the': 1.0}),
#              ('are',
#               'the'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'leading': 1.0}),
#              ('the',
#               'leading'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'international': 1.0}),
#              ('leading',
#               'international'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'sporting': 1.0}),
#              ('international',
#               'sporting'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'events': 1.0}),
#              ('sporting',
#               'events'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'featuring': 0.5, 'alongside': 0.5}),
#              ('events',
#               'featuring'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'summer': 1.0}),
#              ('featuring',
#               'summer'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'and': 1.0}),
#              ('summer',
#               'and'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'winter': 1.0}),
#              ('and',
#               'winter'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'sports': 0.3333333333333333,
#                           'olympics': 0.6666666666666666}),
#              ('winter',
#               'sports'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'competitions': 1.0}),
#              ('sports',
#               'competitions'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'in': 1.0}),
#              ('competitions',
#               'in'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'which': 1.0}),
#              ('in',
#               'which'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'thousands': 0.5, 'they': 0.5}),
#              ('which',
#               'thousands'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'of': 1.0}),
#              ('thousands',
#               'of'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'athletes': 1.0}),
#              ('of',
#               'athletes'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'from': 1.0}),
#              ('athletes',
#               'from'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'around': 1.0}),
#              ('from',
#               'around'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'the': 1.0}),
#              ('around',
#               'the'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'world': 1.0}),
#              ('the',
#               'world'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'participate': 0.25,
#                           'foremost': 0.25,
#                           'games': 0.25,
#                           'etkn': 0.25}),
#              ('world',
#               'participate'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'in': 1.0}),
#              ('participate',
#               'in'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'a': 1.0}),
#              ('in',
#               'a'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'variety': 0.5, 'straight': 0.5}),
#              ('a',
#               'variety'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'of': 1.0}),
#              ('variety',
#               'of'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'competitions': 0.5, 'economic': 0.5}),
#              ('of',
#               'competitions'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'etkn': 1.0}),
#              ('competitions',
#               'etkn'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'stkn': 1.0}),
#              ('etkn',
#               'stkn'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'the': 0.5454545454545454,
#                           'their': 0.022727272727272728,
#                           'baron': 0.022727272727272728,
#                           'some': 0.022727272727272728,
#                           'world': 0.022727272727272728,
#                           'as': 0.022727272727272728,
#                           'there': 0.022727272727272728,
#                           'over': 0.022727272727272728,
#                           'this': 0.06818181818181818,
#                           'every': 0.022727272727272728,
#                           'competition': 0.022727272727272728,
#                           'these': 0.022727272727272728,
#                           'it': 0.022727272727272728,
#                           'according': 0.022727272727272728,
#                           'following': 0.022727272727272728,
#                           'tradition': 0.022727272727272728,
#                           'pelops': 0.022727272727272728,
#                           'while': 0.022727272727272728,
#                           'b': 0.022727272727272728}),
#              ('the',
#               'olympic'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'games': 0.4,
#                           'movement': 0.2,
#                           'charter': 0.13333333333333333,
#                           'programme': 0.06666666666666667,
#                           'flag': 0.06666666666666667,
#                           'peace': 0.06666666666666667,
#                           'stadium': 0.06666666666666667}),
#              ('games',
#               'are'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'considered': 0.5, 'normally': 0.5}),
#              ('are',
#               'considered'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'the': 1.0}),
#              ('considered',
#               'the'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'world': 1.0}),
#              ('world',
#               'foremost'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'sports': 1.0}),
#              ('foremost',
#               'sports'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'competition': 1.0}),
#              ('sports',
#               'competition'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'with': 1.0}),
#              ('competition',
#               'with'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'more': 1.0}),
#              ('with',
#               'more'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'than': 1.0}),
#              ('more',
#               'than'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'teams': 1.0}),
#              ('than',
#               'teams'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'representing': 1.0}),
#              ('teams',
#               'representing'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'sovereign': 1.0}),
#              ('representing',
#               'sovereign'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'states': 1.0}),
#              ('sovereign',
#               'states'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'and': 1.0}),
#              ('states',
#               'and'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'territories': 0.5, 'kingdoms': 0.5}),
#              ('and',
#               'territories'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'participating': 1.0}),
#              ('territories',
#               'participating'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'by': 1.0}),
#              ('participating',
#               'by'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'default': 1.0}),
#              ('by',
#               'default'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'the': 1.0}),
#              ('default',
#               'the'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'games': 1.0}),
#              ('the',
#               'games'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'generally': 0.07142857142857142,
#                           'etkn': 0.2857142857142857,
#                           'according': 0.07142857142857142,
#                           'have': 0.07142857142857142,
#                           'also': 0.07142857142857142,
#                           'all': 0.07142857142857142,
#                           'were': 0.21428571428571427,
#                           'olympic': 0.07142857142857142,
#                           'officially': 0.07142857142857142}),
#              ('games',
#               'generally'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'substitute': 1.0}),
#              ('generally',
#               'substitute'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'for': 1.0}),
#              ('substitute',
#               'for'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'any': 1.0}),
#              ('for',
#               'any'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'world': 1.0}),
#              ('any',
#               'world'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'championships': 1.0}),
#              ('world',
#               'championships'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'the': 1.0}),
#              ('championships',
#               'the'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'year': 1.0}),
#              ('the',
#               'year'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'in': 1.0}),
#              ('year',
#               'in'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'which': 1.0}),
#              ('which',
#               'they'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'take': 1.0}),
#              ('they',
#               'take'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'place': 1.0}),
#              ('take',
#               'place'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'however': 1.0}),
#              ('place',
#               'however'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'each': 1.0}),
#              ('however',
#               'each'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'class': 1.0}),
#              ('each',
#               'class'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'usually': 1.0}),
#              ('class',
#               'usually'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'maintains': 1.0}),
#              ('usually',
#               'maintains'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'their': 1.0}),
#              ('maintains',
#               'their'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'own': 1.0}),
#              ('their',
#               'own'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'records': 0.5, 'teams': 0.5}),
#              ('own',
#               'records'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'etkn': 1.0}),
#              ('records',
#               'etkn'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'stkn': 1.0}),
#              ('are',
#               'normally'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'held': 1.0}),
#              ('normally',
#               'held'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'every': 1.0}),
#              ('held',
#               'every'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'four': 1.0}),
#              ('every',
#               'four'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'years': 1.0}),
#              ('four',
#               'years'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'and': 0.4,
#                           'at': 0.2,
#                           'etkn': 0.2,
#                           'starting': 0.2}),
#              ('years',
#               'and'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'since': 0.5, 'this': 0.5}),
#              ('and',
#               'since'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'have': 1.0}),
#              ('since',
#               'have'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'alternated': 1.0}),
#              ('have',
#               'alternated'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'between': 1.0}),
#              ('alternated',
#               'between'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'the': 1.0}),
#              ('between',
#               'the'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'summer': 1.0}),
#              ('the',
#               'summer'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'and': 0.5, 'olympics': 0.5}),
#              ('winter',
#               'olympics'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'every': 0.5, 'combined': 0.5}),
#              ('olympics',
#               'every'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'two': 1.0}),
#              ('every',
#               'two'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'years': 1.0}),
#              ('two',
#               'years'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'during': 0.5, 'the': 0.5}),
#              ('years',
#               'during'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'the': 1.0}),
#              ('during',
#               'the'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'four': 0.25,
#                           'th': 0.25,
#                           'cold': 0.25,
#                           'games': 0.25}),
#              ('the',
#               'four'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'year': 1.0}),
#              ('four',
#               'year'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'period': 1.0}),
#              ('year',
#               'period'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'etkn': 1.0}),
#              ('period',
#               'etkn'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'stkn': 1.0}),
#              ('stkn',
#               'their'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'creation': 1.0}),
#              ('their',
#               'creation'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'was': 1.0}),
#              ('creation',
#               'was'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'inspired': 1.0}),
#              ('was',
#               'inspired'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'by': 1.0}),
#              ('inspired',
#               'by'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'the': 1.0}),
#              ('by',
#               'the'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'ancient': 0.5, 'eastern': 0.5}),
#              ('the',
#               'ancient'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'olympic': 0.5, 'olympics': 0.25, 'games': 0.25}),
#              ('ancient',
#               'olympic'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'games': 1.0}),
#              ('games',
#               'held'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'in': 1.0}),
#              ('held',
#               'in'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'olympia': 1.0}),
#              ('in',
#               'olympia'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'greece': 1.0}),
#              ('olympia',
#               'greece'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'from': 0.5, 'etkn': 0.5}),
#              ('greece',
#               'from'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'the': 1.0}),
#              ('from',
#               'the'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'th': 0.5, 'city': 0.5}),
#              ('the',
#               'th'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'century': 0.5, 'and': 0.5}),
#              ('th',
#               'century'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'bc': 0.5, 'ad': 0.5}),
#              ('century',
#               'bc'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'to': 1.0}),
#              ('bc',
#               'to'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'the': 1.0}),
#              ('to',
#               'the'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'th': 0.1111111111111111,
#                           'first': 0.1111111111111111,
#                           'olympic': 0.2222222222222222,
#                           'five': 0.1111111111111111,
#                           'acceptance': 0.1111111111111111,
#                           'cancellation': 0.1111111111111111,
#                           'point': 0.1111111111111111,
#                           'world': 0.1111111111111111}),
#              ('century',
#               'ad'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'etkn': 1.0}),
#              ('ad',
#               'etkn'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'stkn': 1.0}),
#              ('stkn',
#               'baron'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'pierre': 1.0}),
#              ('baron',
#               'pierre'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'de': 1.0}),
#              ('pierre',
#               'de'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'coubertin': 1.0}),
#              ('de',
#               'coubertin'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'founded': 1.0}),
#              ('coubertin',
#               'founded'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'the': 1.0}),
#              ('founded',
#               'the'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'international': 1.0}),
#              ('the',
#               'international'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'olympic': 1.0}),
#              ('international',
#               'olympic'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'committee': 1.0}),
#              ('olympic',
#               'committee'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'ioc': 1.0}),
#              ('committee',
#               'ioc'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'in': 1.0}),
#              ('ioc',
#               'in'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'leading': 1.0}),
#              ('in',
#               'leading'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'to': 1.0}),
#              ('leading',
#               'to'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'the': 1.0}),
#              ('the',
#               'first'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'modern': 0.3333333333333333,
#                           'second': 0.3333333333333333,
#                           'olympic': 0.3333333333333333}),
#              ('first',
#               'modern'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'games': 1.0}),
#              ('modern',
#               'games'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'in': 1.0}),
#              ('games',
#               'in'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'athens': 1.0}),
#              ('in',
#               'athens'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'in': 1.0}),
#              ('athens',
#               'in'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'etkn': 1.0}),
#              ('in',
#               'etkn'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'stkn': 1.0}),
#              ('the',
#               'ioc'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'is': 0.3333333333333333,
#                           'also': 0.3333333333333333,
#                           'has': 0.16666666666666666,
#                           'to': 0.16666666666666666}),
#              ('ioc',
#               'is'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'the': 0.5, 'responsible': 0.5}),
#              ('is',
#               'the'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'governing': 1.0}),
#              ('the',
#               'governing'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'body': 1.0}),
#              ('governing',
#               'body'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'of': 1.0}),
#              ('body',
#               'of'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'the': 1.0}),
#              ('of',
#               'the'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'olympic': 0.18181818181818182,
#                           'winter': 0.09090909090909091,
#                           'games': 0.18181818181818182,
#                           'and': 0.09090909090909091,
#                           'covid': 0.09090909090909091,
#                           'sports': 0.09090909090909091,
#                           'olympics': 0.09090909090909091,
#                           'most': 0.09090909090909091,
#                           'events': 0.09090909090909091}),
#              ('olympic',
#               'movement'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'which': 0.3333333333333333,
#                           'during': 0.3333333333333333,
#                           'consists': 0.3333333333333333}),
#              ('movement',
#               'which'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'encompasses': 1.0}),
#              ('which',
#               'encompasses'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'all': 1.0}),
#              ('encompasses',
#               'all'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'entities': 1.0}),
#              ('all',
#               'entities'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'and': 1.0}),
#              ('entities',
#               'and'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'individuals': 1.0}),
#              ('and',
#               'individuals'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'involved': 1.0}),
#              ('individuals',
#               'involved'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'in': 1.0}),
#              ('involved',
#               'in'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'the': 1.0}),
#              ('in',
#               'the'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'olympic': 0.5, 'and': 0.25, 'th': 0.25}),
#              ('games',
#               'with'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'the': 1.0}),
#              ('with',
#               'the'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'olympic': 0.5, 'chance': 0.5}),
#              ('olympic',
#               'charter'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'defining': 0.5, 'etkn': 0.5}),
#              ('charter',
#               'defining'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'its': 1.0}),
#              ('defining',
#               'its'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'structure': 1.0}),
#              ('its',
#               'structure'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'and': 1.0}),
#              ('structure',
#               'and'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'authority': 1.0}),
#              ('and',
#               'authority'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'etkn': 1.0}),
#              ('authority',
#               'etkn'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'stkn': 1.0}),
#              ('the',
#               'evolution'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'of': 1.0}),
#              ('evolution',
#               'of'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'the': 1.0}),
#              ('movement',
#               'during'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'the': 1.0}),
#              ('th',
#               'and'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'st': 0.5, 'th': 0.5}),
#              ('and',
#               'st'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'centuries': 1.0}),
#              ('st',
#               'centuries'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'has': 1.0}),
#              ('centuries',
#               'has'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'resulted': 1.0}),
#              ('has',
#               'resulted'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'in': 1.0}),
#              ('resulted',
#               'in'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'several': 1.0}),
#              ('in',
#               'several'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'changes': 1.0}),
#              ('several',
#               'changes'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'to': 1.0}),
#              ('changes',
#               'to'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'the': 1.0}),
#              ('games',
#               'etkn'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'stkn': 1.0}),
#              ('stkn',
#               'some'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'of': 1.0}),
#              ('some',
#               'of'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'these': 1.0}),
#              ('of',
#               'these'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'adjustments': 1.0}),
#              ('these',
#               'adjustments'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'include': 1.0}),
#              ('adjustments',
#               'include'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'the': 1.0}),
#              ('include',
#               'the'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'creation': 1.0}),
#              ('the',
#               'creation'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'of': 1.0}),
#              ('creation',
#               'of'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'the': 1.0}),
#              ('the',
#               'winter'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'olympic': 1.0}),
#              ('winter',
#               'olympic'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'games': 1.0}),
#              ('games',
#               'for'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'snow': 0.25, 'athletes': 0.5, 'sports': 0.25}),
#              ('for',
#               'snow'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'and': 1.0}),
#              ('snow',
#               'and'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'ice': 1.0}),
#              ('and',
#               'ice'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'sports': 1.0}),
#              ('ice',
#               'sports'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'the': 1.0}),
#              ('sports',
#               'the'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'paralympic': 1.0}),
#              ('the',
#               'paralympic'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'games': 1.0}),
#              ('paralympic',
#               'games'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'for': 1.0}),
#              ('for',
#               'athletes'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'with': 0.5, 'aged': 0.5}),
#              ('athletes',
#               'with'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'disabilities': 0.5, 'the': 0.5}),
#              ('with',
#               'disabilities'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'the': 1.0}),
#              ('disabilities',
#               'the'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'youth': 1.0}),
#              ('the',
#               'youth'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'olympic': 1.0}),
#              ('youth',
#               'olympic'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'games': 1.0}),
#              ('athletes',
#               'aged'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'to': 1.0}),
#              ('aged',
#               'to'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'the': 1.0}),
#              ('the',
#               'five'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'continental': 1.0}),
#              ('five',
#               'continental'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'games': 1.0}),
#              ('continental',
#               'games'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'pan': 1.0}),
#              ('games',
#               'pan'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'american': 1.0}),
#              ('pan',
#               'american'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'african': 1.0}),
#              ('american',
#               'african'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'asian': 1.0}),
#              ('african',
#               'asian'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'european': 1.0}),
#              ('asian',
#               'european'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'and': 1.0}),
#              ('european',
#               'and'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'pacific': 1.0}),
#              ('and',
#               'pacific'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'and': 1.0}),
#              ('pacific',
#               'and'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'the': 1.0}),
#              ('and',
#               'the'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'world': 0.2,
#                           'special': 0.2,
#                           'olympics': 0.2,
#                           'pankration': 0.2,
#                           'isthmian': 0.2}),
#              ('world',
#               'games'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'for': 1.0}),
#              ('for',
#               'sports'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'that': 1.0}),
#              ('sports',
#               'that'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'are': 1.0}),
#              ('that',
#               'are'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'not': 1.0}),
#              ('are',
#               'not'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'contested': 1.0}),
#              ('not',
#               'contested'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'in': 1.0}),
#              ('contested',
#               'in'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'the': 1.0}),
#              ('ioc',
#               'also'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'endorses': 0.5, 'determines': 0.5}),
#              ('also',
#               'endorses'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'the': 1.0}),
#              ('endorses',
#               'the'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'deaflympics': 1.0}),
#              ('the',
#               'deaflympics'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'and': 1.0}),
#              ('deaflympics',
#               'and'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'the': 1.0}),
#              ('the',
#               'special'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'olympics': 1.0}),
#              ('special',
#               'olympics'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'etkn': 1.0}),
#              ('olympics',
#               'etkn'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'stkn': 1.0}),
#              ('ioc',
#               'has'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'needed': 1.0}),
#              ('has',
#               'needed'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'to': 1.0}),
#              ('needed',
#               'to'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'adapt': 1.0}),
#              ('to',
#               'adapt'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'to': 1.0}),
#              ('adapt',
#               'to'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'a': 1.0}),
#              ('to',
#               'a'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'variety': 1.0}),
#              ('of',
#               'economic'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'political': 1.0}),
#              ('economic',
#               'political'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'and': 1.0}),
#              ('political',
#               'and'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'technological': 1.0}),
#              ('and',
#               'technological'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'advancements': 1.0}),
#              ('technological',
#               'advancements'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'etkn': 1.0}),
#              ('advancements',
#               'etkn'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'stkn': 1.0}),
#              ('the',
#               'abuse'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'of': 1.0}),
#              ('abuse',
#               'of'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'amateur': 1.0}),
#              ('of',
#               'amateur'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'rules': 1.0}),
#              ('amateur',
#               'rules'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'by': 1.0}),
#              ('rules',
#               'by'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'the': 1.0}),
#              ('the',
#               'eastern'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'bloc': 1.0}),
#              ('eastern',
#               'bloc'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'nations': 1.0}),
#              ('bloc',
#               'nations'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'prompted': 1.0}),
#              ('nations',
#               'prompted'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'the': 1.0}),
#              ('prompted',
#               'the'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'ioc': 1.0}),
#              ('ioc',
#               'to'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'shift': 1.0}),
#              ('to',
#               'shift'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'away': 1.0}),
#              ('shift',
#               'away'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'from': 1.0}),
#              ('away',
#               'from'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'pure': 1.0}),
#              ('from',
#               'pure'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'amateurism': 1.0}),
#              ('pure',
#               'amateurism'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'as': 1.0}),
#              ('amateurism',
#               'as'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'envisioned': 1.0}),
#              ('as',
#               'envisioned'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'by': 1.0}),
#              ('envisioned',
#               'by'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'coubertin': 1.0}),
#              ('by',
#               'coubertin'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'to': 1.0}),
#              ('coubertin',
#               'to'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'the': 1.0}),
#              ('the',
#               'acceptance'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'of': 1.0}),
#              ('acceptance',
#               'of'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'professional': 1.0}),
#              ('of',
#               'professional'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'athletes': 1.0}),
#              ('professional',
#               'athletes'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'participating': 1.0}),
#              ('athletes',
#               'participating'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'at': 1.0}),
#              ('participating',
#               'at'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'the': 1.0}),
#              ('at',
#               'the'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'games': 0.5, 'summer': 0.25, 'sanctuary': 0.25}),
#              ('the',
#               'growing'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'importance': 1.0}),
#              ('growing',
#               'importance'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'of': 1.0}),
#              ('importance',
#               'of'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'mass': 1.0}),
#              ('of',
#               'mass'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'media': 1.0}),
#              ('mass',
#               'media'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'has': 1.0}),
#              ('media',
#               'has'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'created': 1.0}),
#              ('has',
#               'created'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'the': 0.5, 'numerous': 0.5}),
#              ('created',
#               'the'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'issue': 1.0}),
#              ('the',
#               'issue'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'of': 1.0}),
# ...
#              ('statues',
#               'etkn'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'stkn': 1.0}),
#              ('were',
#               'held'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'every': 1.0}),
#              ('and',
#               'this'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'period': 1.0}),
#              ('this',
#               'period'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'known': 1.0}),
#              ('period',
#               'known'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'as': 1.0}),
#              ('an',
#               'olympiad'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'was': 1.0}),
#              ('olympiad',
#               'was'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'used': 1.0}),
#              ('was',
#               'used'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'by': 1.0}),
#              ('used',
#               'by'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'greeks': 1.0}),
#              ('by',
#               'greeks'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'as': 1.0}),
#              ('greeks',
#               'as'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'one': 1.0}),
#              ('as',
#               'one'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'of': 1.0}),
#              ('of',
#               'their'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'units': 0.5, 'success': 0.5}),
#              ('their',
#               'units'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'of': 1.0}),
#              ('units',
#               'of'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'time': 1.0}),
#              ('of',
#               'time'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'measurement': 1.0}),
#              ('time',
#               'measurement'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'etkn': 1.0}),
#              ('measurement',
#               'etkn'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'stkn': 1.0}),
#              ('were',
#               'part'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'of': 1.0}),
#              ('part',
#               'of'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'a': 1.0}),
#              ('a',
#               'cycle'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'known': 1.0}),
#              ('cycle',
#               'known'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'as': 1.0}),
#              ('the',
#               'panhellenic'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'games': 1.0}),
#              ('panhellenic',
#               'games'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'which': 1.0}),
#              ('games',
#               'which'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'included': 1.0}),
#              ('which',
#               'included'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'the': 1.0}),
#              ('included',
#               'the'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'pythian': 1.0}),
#              ('the',
#               'pythian'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'games': 1.0}),
#              ('pythian',
#               'games'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'the': 1.0}),
#              ('games',
#               'the'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'nemean': 1.0}),
#              ('the',
#               'nemean'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'games': 1.0}),
#              ('nemean',
#               'games'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'and': 1.0}),
#              ('the',
#               'isthmian'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'games': 1.0}),
#              ('isthmian',
#               'games'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'etkn': 1.0}),
#              ('games',
#               'reached'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'the': 1.0}),
#              ('reached',
#               'the'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'height': 1.0}),
#              ('the',
#               'height'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'of': 1.0}),
#              ('height',
#               'of'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'their': 1.0}),
#              ('their',
#               'success'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'in': 1.0}),
#              ('success',
#               'in'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'the': 1.0}),
#              ('and',
#               'th'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'centuries': 1.0}),
#              ('th',
#               'centuries'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'bc': 1.0}),
#              ('centuries',
#               'bc'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'but': 1.0}),
#              ('bc',
#               'but'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'then': 1.0}),
#              ('but',
#               'then'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'gradually': 1.0}),
#              ('then',
#               'gradually'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'declined': 1.0}),
#              ('gradually',
#               'declined'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'in': 1.0}),
#              ('declined',
#               'in'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'importance': 1.0}),
#              ('in',
#               'importance'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'as': 1.0}),
#              ('importance',
#               'as'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'the': 1.0}),
#              ('the',
#               'romans'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'gained': 1.0}),
#              ('romans',
#               'gained'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'power': 1.0}),
#              ('gained',
#               'power'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'and': 1.0}),
#              ('power',
#               'and'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'influence': 1.0}),
#              ('and',
#               'influence'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'in': 1.0}),
#              ('influence',
#               'in'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'greece': 1.0}),
#              ('in',
#               'greece'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'etkn': 1.0}),
#              ('stkn',
#               'while'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'there': 1.0}),
#              ('while',
#               'there'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'is': 1.0}),
#              ('there',
#               'is'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'no': 1.0}),
#              ('is',
#               'no'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'scholarly': 1.0}),
#              ('no',
#               'scholarly'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'consensus': 1.0}),
#              ('scholarly',
#               'consensus'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'as': 1.0}),
#              ('consensus',
#               'as'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'to': 1.0}),
#              ('as',
#               'to'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'when': 1.0}),
#              ('to',
#               'when'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'the': 1.0}),
#              ('when',
#               'the'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'games': 0.5, 'emperor': 0.5}),
#              ('games',
#               'officially'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'ended': 1.0}),
#              ('officially',
#               'ended'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'the': 1.0}),
#              ('ended',
#               'the'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'most': 1.0}),
#              ('most',
#               'commonly'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'held': 1.0}),
#              ('commonly',
#               'held'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'date': 1.0}),
#              ('held',
#               'date'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'is': 1.0}),
#              ('date',
#               'is'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'ad': 1.0}),
#              ('is',
#               'ad'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'when': 1.0}),
#              ('ad',
#               'when'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'the': 0.5, 'his': 0.5}),
#              ('the',
#               'emperor'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'theodosius': 1.0}),
#              ('emperor',
#               'theodosius'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'i': 1.0}),
#              ('theodosius',
#               'i'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'decreed': 1.0}),
#              ('i',
#               'decreed'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'that': 1.0}),
#              ('decreed',
#               'that'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'all': 1.0}),
#              ('that',
#               'all'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'pagan': 1.0}),
#              ('all',
#               'pagan'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'cults': 1.0}),
#              ('pagan',
#               'cults'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'and': 1.0}),
#              ('cults',
#               'and'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'practices': 1.0}),
#              ('and',
#               'practices'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'be': 1.0}),
#              ('practices',
#               'be'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'eliminated': 1.0}),
#              ('be',
#               'eliminated'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'etkn': 1.0}),
#              ('eliminated',
#               'etkn'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'stkn': 1.0}),
#              ('stkn',
#               'b'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'another': 1.0}),
#              ('b',
#               'another'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'date': 1.0}),
#              ('another',
#               'date'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'commonly': 1.0}),
#              ('date',
#               'commonly'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'cited': 1.0}),
#              ('commonly',
#               'cited'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'is': 1.0}),
#              ('cited',
#               'is'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'ad': 1.0}),
#              ('when',
#               'his'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'successor': 1.0}),
#              ('his',
#               'successor'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'theodosius': 1.0}),
#              ('successor',
#               'theodosius'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'ii': 1.0}),
#              ('theodosius',
#               'ii'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'ordered': 1.0}),
#              ('ii',
#               'ordered'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'the': 1.0}),
#              ('ordered',
#               'the'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'destruction': 1.0}),
#              ('the',
#               'destruction'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'of': 1.0}),
#              ('destruction',
#               'of'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'all': 1.0}),
#              ('of',
#               'all'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'greek': 1.0}),
#              ('all',
#               'greek'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'temples': 1.0}),
#              ('greek',
#               'temples'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'etkn': 1.0})})

# %%
def trigram_gen(input_text):
    
    starting_words = input_text.split(' ')
    sentence = list(starting_words)
    next_word = ''
    
    while next_word != 'etkn':
        w1, w2 = sentence[-2], sentence[-1]
        if (w1, w2) in model_tri:
            # calls the next word given on the probability of that word itself
            next_word = random.choices(list(model_tri[(w1, w2)].keys()), weights=model_tri[(w1, w2)].values())[0]
            sentence.append(next_word)
        else:
            break
        
        if len(sentence) < 30:
            next_word = ''
            
    return ' '.join(sentence)

# %% [markdown]
# ### Four-gram

# %%
model_four = defaultdict(lambda: defaultdict(int))

# %%
n_gram = 4
for i in range(n_gram,len(data)+1):
    w1 = data[i-n_gram+0]
    w2 = data[i-n_gram+1]
    w3 = data[i-n_gram+2]
    w4 = data[i-n_gram+3]
    model_four[(w1, w2, w3)][w4] += 1

# %%
for w1_w2_w3 in model_four:
    total_count = float(sum(model_four[w1_w2_w3].values()))
    for w4 in model_four[w1_w2_w3]:
        model_four[w1_w2_w3][w4] /= total_count

# %%
model_four
# Out:
# defaultdict(<function __main__.<lambda>()>,
#             {('stkn', 'the', 'modern'): defaultdict(int, {'olympic': 1.0}),
#              ('the', 'modern', 'olympic'): defaultdict(int, {'games': 1.0}),
#              ('modern', 'olympic', 'games'): defaultdict(int, {'or': 1.0}),
#              ('olympic', 'games', 'or'): defaultdict(int, {'olympics': 1.0}),
#              ('games', 'or', 'olympics'): defaultdict(int, {'are': 1.0}),
#              ('or', 'olympics', 'are'): defaultdict(int, {'the': 1.0}),
#              ('olympics', 'are', 'the'): defaultdict(int, {'leading': 1.0}),
#              ('are',
#               'the',
#               'leading'): defaultdict(int, {'international': 1.0}),
#              ('the',
#               'leading',
#               'international'): defaultdict(int, {'sporting': 1.0}),
#              ('leading',
#               'international',
#               'sporting'): defaultdict(int, {'events': 1.0}),
#              ('international',
#               'sporting',
#               'events'): defaultdict(int, {'featuring': 1.0}),
#              ('sporting',
#               'events',
#               'featuring'): defaultdict(int, {'summer': 1.0}),
#              ('events', 'featuring', 'summer'): defaultdict(int, {'and': 1.0}),
#              ('featuring', 'summer', 'and'): defaultdict(int, {'winter': 1.0}),
#              ('summer',
#               'and',
#               'winter'): defaultdict(int, {'sports': 0.5, 'olympics': 0.5}),
#              ('and',
#               'winter',
#               'sports'): defaultdict(int, {'competitions': 1.0}),
#              ('winter',
#               'sports',
#               'competitions'): defaultdict(int, {'in': 1.0}),
#              ('sports',
#               'competitions',
#               'in'): defaultdict(int, {'which': 1.0}),
#              ('competitions',
#               'in',
#               'which'): defaultdict(int, {'thousands': 1.0}),
#              ('in', 'which', 'thousands'): defaultdict(int, {'of': 1.0}),
#              ('which', 'thousands', 'of'): defaultdict(int, {'athletes': 1.0}),
#              ('thousands', 'of', 'athletes'): defaultdict(int, {'from': 1.0}),
#              ('of', 'athletes', 'from'): defaultdict(int, {'around': 1.0}),
#              ('athletes', 'from', 'around'): defaultdict(int, {'the': 1.0}),
#              ('from', 'around', 'the'): defaultdict(int, {'world': 1.0}),
#              ('around',
#               'the',
#               'world'): defaultdict(int, {'participate': 1.0}),
#              ('the', 'world', 'participate'): defaultdict(int, {'in': 1.0}),
#              ('world', 'participate', 'in'): defaultdict(int, {'a': 1.0}),
#              ('participate', 'in', 'a'): defaultdict(int, {'variety': 1.0}),
#              ('in', 'a', 'variety'): defaultdict(int, {'of': 1.0}),
#              ('a',
#               'variety',
#               'of'): defaultdict(int, {'competitions': 0.5, 'economic': 0.5}),
#              ('variety',
#               'of',
#               'competitions'): defaultdict(int, {'etkn': 1.0}),
#              ('of', 'competitions', 'etkn'): defaultdict(int, {'stkn': 1.0}),
#              ('competitions', 'etkn', 'stkn'): defaultdict(int, {'the': 1.0}),
#              ('etkn',
#               'stkn',
#               'the'): defaultdict(int,
#                          {'olympic': 0.16666666666666666,
#                           'ioc': 0.16666666666666666,
#                           'evolution': 0.041666666666666664,
#                           'abuse': 0.041666666666666664,
#                           'growing': 0.041666666666666664,
#                           'first': 0.041666666666666664,
#                           'games': 0.16666666666666666,
#                           'ancient': 0.08333333333333333,
#                           'truce': 0.041666666666666664,
#                           'origin': 0.041666666666666664,
#                           'myth': 0.041666666666666664,
#                           'most': 0.041666666666666664,
#                           'olympics': 0.041666666666666664,
#                           'winners': 0.041666666666666664}),
#              ('stkn',
#               'the',
#               'olympic'): defaultdict(int, {'games': 0.75, 'movement': 0.25}),
#              ('the',
#               'olympic',
#               'games'): defaultdict(int,
#                          {'are': 0.3333333333333333,
#                           'with': 0.16666666666666666,
#                           'etkn': 0.3333333333333333,
#                           'reached': 0.16666666666666666}),
#              ('olympic',
#               'games',
#               'are'): defaultdict(int, {'considered': 0.5, 'normally': 0.5}),
#              ('games', 'are', 'considered'): defaultdict(int, {'the': 1.0}),
#              ('are', 'considered', 'the'): defaultdict(int, {'world': 1.0}),
#              ('considered',
#               'the',
#               'world'): defaultdict(int, {'foremost': 1.0}),
#              ('the', 'world', 'foremost'): defaultdict(int, {'sports': 1.0}),
#              ('world',
#               'foremost',
#               'sports'): defaultdict(int, {'competition': 1.0}),
#              ('foremost',
#               'sports',
#               'competition'): defaultdict(int, {'with': 1.0}),
#              ('sports',
#               'competition',
#               'with'): defaultdict(int, {'more': 1.0}),
#              ('competition', 'with', 'more'): defaultdict(int, {'than': 1.0}),
#              ('with', 'more', 'than'): defaultdict(int, {'teams': 1.0}),
#              ('more',
#               'than',
#               'teams'): defaultdict(int, {'representing': 1.0}),
#              ('than',
#               'teams',
#               'representing'): defaultdict(int, {'sovereign': 1.0}),
#              ('teams',
#               'representing',
#               'sovereign'): defaultdict(int, {'states': 1.0}),
#              ('representing',
#               'sovereign',
#               'states'): defaultdict(int, {'and': 1.0}),
#              ('sovereign',
#               'states',
#               'and'): defaultdict(int, {'territories': 1.0}),
#              ('states',
#               'and',
#               'territories'): defaultdict(int, {'participating': 1.0}),
#              ('and',
#               'territories',
#               'participating'): defaultdict(int, {'by': 1.0}),
#              ('territories',
#               'participating',
#               'by'): defaultdict(int, {'default': 1.0}),
#              ('participating',
#               'by',
#               'default'): defaultdict(int, {'the': 1.0}),
#              ('by', 'default', 'the'): defaultdict(int, {'games': 1.0}),
#              ('default', 'the', 'games'): defaultdict(int, {'generally': 1.0}),
#              ('the',
#               'games',
#               'generally'): defaultdict(int, {'substitute': 1.0}),
#              ('games',
#               'generally',
#               'substitute'): defaultdict(int, {'for': 1.0}),
#              ('generally',
#               'substitute',
#               'for'): defaultdict(int, {'any': 1.0}),
#              ('substitute', 'for', 'any'): defaultdict(int, {'world': 1.0}),
#              ('for', 'any', 'world'): defaultdict(int, {'championships': 1.0}),
#              ('any', 'world', 'championships'): defaultdict(int, {'the': 1.0}),
#              ('world',
#               'championships',
#               'the'): defaultdict(int, {'year': 1.0}),
#              ('championships', 'the', 'year'): defaultdict(int, {'in': 1.0}),
#              ('the', 'year', 'in'): defaultdict(int, {'which': 1.0}),
#              ('year', 'in', 'which'): defaultdict(int, {'they': 1.0}),
#              ('in', 'which', 'they'): defaultdict(int, {'take': 1.0}),
#              ('which', 'they', 'take'): defaultdict(int, {'place': 1.0}),
#              ('they', 'take', 'place'): defaultdict(int, {'however': 1.0}),
#              ('take', 'place', 'however'): defaultdict(int, {'each': 1.0}),
#              ('place', 'however', 'each'): defaultdict(int, {'class': 1.0}),
#              ('however', 'each', 'class'): defaultdict(int, {'usually': 1.0}),
#              ('each',
#               'class',
#               'usually'): defaultdict(int, {'maintains': 1.0}),
#              ('class',
#               'usually',
#               'maintains'): defaultdict(int, {'their': 1.0}),
#              ('usually', 'maintains', 'their'): defaultdict(int, {'own': 1.0}),
#              ('maintains', 'their', 'own'): defaultdict(int, {'records': 1.0}),
#              ('their', 'own', 'records'): defaultdict(int, {'etkn': 1.0}),
#              ('own', 'records', 'etkn'): defaultdict(int, {'stkn': 1.0}),
#              ('records', 'etkn', 'stkn'): defaultdict(int, {'the': 1.0}),
#              ('games', 'are', 'normally'): defaultdict(int, {'held': 1.0}),
#              ('are', 'normally', 'held'): defaultdict(int, {'every': 1.0}),
#              ('normally', 'held', 'every'): defaultdict(int, {'four': 1.0}),
#              ('held', 'every', 'four'): defaultdict(int, {'years': 1.0}),
#              ('every',
#               'four',
#               'years'): defaultdict(int,
#                          {'and': 0.4,
#                           'at': 0.2,
#                           'etkn': 0.2,
#                           'starting': 0.2}),
#              ('four',
#               'years',
#               'and'): defaultdict(int, {'since': 0.5, 'this': 0.5}),
#              ('years', 'and', 'since'): defaultdict(int, {'have': 1.0}),
#              ('and', 'since', 'have'): defaultdict(int, {'alternated': 1.0}),
#              ('since',
#               'have',
#               'alternated'): defaultdict(int, {'between': 1.0}),
#              ('have', 'alternated', 'between'): defaultdict(int, {'the': 1.0}),
#              ('alternated',
#               'between',
#               'the'): defaultdict(int, {'summer': 1.0}),
#              ('between', 'the', 'summer'): defaultdict(int, {'and': 1.0}),
#              ('the', 'summer', 'and'): defaultdict(int, {'winter': 1.0}),
#              ('and',
#               'winter',
#               'olympics'): defaultdict(int, {'every': 0.5, 'combined': 0.5}),
#              ('winter', 'olympics', 'every'): defaultdict(int, {'two': 1.0}),
#              ('olympics', 'every', 'two'): defaultdict(int, {'years': 1.0}),
#              ('every',
#               'two',
#               'years'): defaultdict(int, {'during': 0.5, 'the': 0.5}),
#              ('two', 'years', 'during'): defaultdict(int, {'the': 1.0}),
#              ('years', 'during', 'the'): defaultdict(int, {'four': 1.0}),
#              ('during', 'the', 'four'): defaultdict(int, {'year': 1.0}),
#              ('the', 'four', 'year'): defaultdict(int, {'period': 1.0}),
#              ('four', 'year', 'period'): defaultdict(int, {'etkn': 1.0}),
#              ('year', 'period', 'etkn'): defaultdict(int, {'stkn': 1.0}),
#              ('period', 'etkn', 'stkn'): defaultdict(int, {'their': 1.0}),
#              ('etkn', 'stkn', 'their'): defaultdict(int, {'creation': 1.0}),
#              ('stkn', 'their', 'creation'): defaultdict(int, {'was': 1.0}),
#              ('their', 'creation', 'was'): defaultdict(int, {'inspired': 1.0}),
#              ('creation', 'was', 'inspired'): defaultdict(int, {'by': 1.0}),
#              ('was', 'inspired', 'by'): defaultdict(int, {'the': 1.0}),
#              ('inspired', 'by', 'the'): defaultdict(int, {'ancient': 1.0}),
#              ('by', 'the', 'ancient'): defaultdict(int, {'olympic': 1.0}),
#              ('the', 'ancient', 'olympic'): defaultdict(int, {'games': 1.0}),
#              ('ancient',
#               'olympic',
#               'games'): defaultdict(int, {'held': 0.5, 'were': 0.5}),
#              ('olympic', 'games', 'held'): defaultdict(int, {'in': 1.0}),
#              ('games', 'held', 'in'): defaultdict(int, {'olympia': 1.0}),
#              ('held', 'in', 'olympia'): defaultdict(int, {'greece': 1.0}),
#              ('in',
#               'olympia',
#               'greece'): defaultdict(int, {'from': 0.5, 'etkn': 0.5}),
#              ('olympia', 'greece', 'from'): defaultdict(int, {'the': 1.0}),
#              ('greece', 'from', 'the'): defaultdict(int, {'th': 1.0}),
#              ('from', 'the', 'th'): defaultdict(int, {'century': 1.0}),
#              ('the',
#               'th',
#               'century'): defaultdict(int, {'bc': 0.5, 'ad': 0.5}),
#              ('th', 'century', 'bc'): defaultdict(int, {'to': 1.0}),
#              ('century', 'bc', 'to'): defaultdict(int, {'the': 1.0}),
#              ('bc', 'to', 'the'): defaultdict(int, {'th': 1.0}),
#              ('to', 'the', 'th'): defaultdict(int, {'century': 1.0}),
#              ('th', 'century', 'ad'): defaultdict(int, {'etkn': 1.0}),
#              ('century', 'ad', 'etkn'): defaultdict(int, {'stkn': 1.0}),
#              ('ad', 'etkn', 'stkn'): defaultdict(int, {'baron': 1.0}),
#              ('etkn', 'stkn', 'baron'): defaultdict(int, {'pierre': 1.0}),
#              ('stkn', 'baron', 'pierre'): defaultdict(int, {'de': 1.0}),
#              ('baron', 'pierre', 'de'): defaultdict(int, {'coubertin': 1.0}),
#              ('pierre', 'de', 'coubertin'): defaultdict(int, {'founded': 1.0}),
#              ('de', 'coubertin', 'founded'): defaultdict(int, {'the': 1.0}),
#              ('coubertin',
#               'founded',
#               'the'): defaultdict(int, {'international': 1.0}),
#              ('founded',
#               'the',
#               'international'): defaultdict(int, {'olympic': 1.0}),
#              ('the',
#               'international',
#               'olympic'): defaultdict(int, {'committee': 1.0}),
#              ('international',
#               'olympic',
#               'committee'): defaultdict(int, {'ioc': 1.0}),
#              ('olympic', 'committee', 'ioc'): defaultdict(int, {'in': 1.0}),
#              ('committee', 'ioc', 'in'): defaultdict(int, {'leading': 1.0}),
#              ('ioc', 'in', 'leading'): defaultdict(int, {'to': 1.0}),
#              ('in', 'leading', 'to'): defaultdict(int, {'the': 1.0}),
#              ('leading', 'to', 'the'): defaultdict(int, {'first': 1.0}),
#              ('to', 'the', 'first'): defaultdict(int, {'modern': 1.0}),
#              ('the', 'first', 'modern'): defaultdict(int, {'games': 1.0}),
#              ('first', 'modern', 'games'): defaultdict(int, {'in': 1.0}),
#              ('modern', 'games', 'in'): defaultdict(int, {'athens': 1.0}),
#              ('games', 'in', 'athens'): defaultdict(int, {'in': 1.0}),
#              ('in', 'athens', 'in'): defaultdict(int, {'etkn': 1.0}),
#              ('athens', 'in', 'etkn'): defaultdict(int, {'stkn': 1.0}),
#              ('in', 'etkn', 'stkn'): defaultdict(int, {'the': 1.0}),
#              ('stkn',
#               'the',
#               'ioc'): defaultdict(int, {'is': 0.25, 'also': 0.5, 'has': 0.25}),
#              ('the',
#               'ioc',
#               'is'): defaultdict(int, {'the': 0.5, 'responsible': 0.5}),
#              ('ioc', 'is', 'the'): defaultdict(int, {'governing': 1.0}),
#              ('is', 'the', 'governing'): defaultdict(int, {'body': 1.0}),
#              ('the', 'governing', 'body'): defaultdict(int, {'of': 1.0}),
#              ('governing', 'body', 'of'): defaultdict(int, {'the': 1.0}),
#              ('body', 'of', 'the'): defaultdict(int, {'olympic': 1.0}),
#              ('of', 'the', 'olympic'): defaultdict(int, {'movement': 1.0}),
#              ('the',
#               'olympic',
#               'movement'): defaultdict(int,
#                          {'which': 0.3333333333333333,
#                           'during': 0.3333333333333333,
#                           'consists': 0.3333333333333333}),
#              ('olympic',
#               'movement',
#               'which'): defaultdict(int, {'encompasses': 1.0}),
#              ('movement',
#               'which',
#               'encompasses'): defaultdict(int, {'all': 1.0}),
#              ('which',
#               'encompasses',
#               'all'): defaultdict(int, {'entities': 1.0}),
#              ('encompasses',
#               'all',
#               'entities'): defaultdict(int, {'and': 1.0}),
#              ('all',
#               'entities',
#               'and'): defaultdict(int, {'individuals': 1.0}),
#              ('entities',
#               'and',
#               'individuals'): defaultdict(int, {'involved': 1.0}),
#              ('and', 'individuals', 'involved'): defaultdict(int, {'in': 1.0}),
#              ('individuals', 'involved', 'in'): defaultdict(int, {'the': 1.0}),
#              ('involved', 'in', 'the'): defaultdict(int, {'olympic': 1.0}),
#              ('in', 'the', 'olympic'): defaultdict(int, {'games': 1.0}),
#              ('olympic', 'games', 'with'): defaultdict(int, {'the': 1.0}),
#              ('games', 'with', 'the'): defaultdict(int, {'olympic': 1.0}),
#              ('with', 'the', 'olympic'): defaultdict(int, {'charter': 1.0}),
#              ('the',
#               'olympic',
#               'charter'): defaultdict(int, {'defining': 0.5, 'etkn': 0.5}),
#              ('olympic',
#               'charter',
#               'defining'): defaultdict(int, {'its': 1.0}),
#              ('charter',
#               'defining',
#               'its'): defaultdict(int, {'structure': 1.0}),
#              ('defining', 'its', 'structure'): defaultdict(int, {'and': 1.0}),
#              ('its', 'structure', 'and'): defaultdict(int, {'authority': 1.0}),
#              ('structure',
#               'and',
#               'authority'): defaultdict(int, {'etkn': 1.0}),
#              ('and', 'authority', 'etkn'): defaultdict(int, {'stkn': 1.0}),
#              ('authority', 'etkn', 'stkn'): defaultdict(int, {'the': 1.0}),
#              ('stkn', 'the', 'evolution'): defaultdict(int, {'of': 1.0}),
#              ('the', 'evolution', 'of'): defaultdict(int, {'the': 1.0}),
#              ('evolution', 'of', 'the'): defaultdict(int, {'olympic': 1.0}),
#              ('olympic', 'movement', 'during'): defaultdict(int, {'the': 1.0}),
#              ('movement', 'during', 'the'): defaultdict(int, {'th': 1.0}),
#              ('during', 'the', 'th'): defaultdict(int, {'and': 1.0}),
#              ('the', 'th', 'and'): defaultdict(int, {'st': 0.5, 'th': 0.5}),
#              ('th', 'and', 'st'): defaultdict(int, {'centuries': 1.0}),
#              ('and', 'st', 'centuries'): defaultdict(int, {'has': 1.0}),
#              ('st', 'centuries', 'has'): defaultdict(int, {'resulted': 1.0}),
#              ('centuries', 'has', 'resulted'): defaultdict(int, {'in': 1.0}),
#              ('has', 'resulted', 'in'): defaultdict(int, {'several': 1.0}),
#              ('resulted', 'in', 'several'): defaultdict(int, {'changes': 1.0}),
#              ('in', 'several', 'changes'): defaultdict(int, {'to': 1.0}),
#              ('several', 'changes', 'to'): defaultdict(int, {'the': 1.0}),
#              ('changes', 'to', 'the'): defaultdict(int, {'olympic': 1.0}),
#              ('to',
#               'the',
#               'olympic'): defaultdict(int, {'games': 0.5, 'charter': 0.5}),
#              ('olympic', 'games', 'etkn'): defaultdict(int, {'stkn': 1.0}),
#              ('games',
#               'etkn',
#               'stkn'): defaultdict(int,
#                          {'some': 0.125,
#                           'the': 0.375,
#                           'world': 0.125,
#                           'as': 0.125,
#                           'there': 0.125,
#                           'according': 0.125}),
#              ('etkn', 'stkn', 'some'): defaultdict(int, {'of': 1.0}),
#              ('stkn', 'some', 'of'): defaultdict(int, {'these': 1.0}),
#              ('some', 'of', 'these'): defaultdict(int, {'adjustments': 1.0}),
#              ('of',
#               'these',
#               'adjustments'): defaultdict(int, {'include': 1.0}),
#              ('these',
#               'adjustments',
#               'include'): defaultdict(int, {'the': 1.0}),
#              ('adjustments',
#               'include',
#               'the'): defaultdict(int, {'creation': 1.0}),
#              ('include', 'the', 'creation'): defaultdict(int, {'of': 1.0}),
#              ('the', 'creation', 'of'): defaultdict(int, {'the': 1.0}),
#              ('creation', 'of', 'the'): defaultdict(int, {'winter': 1.0}),
#              ('of', 'the', 'winter'): defaultdict(int, {'olympic': 1.0}),
#              ('the', 'winter', 'olympic'): defaultdict(int, {'games': 1.0}),
#              ('winter', 'olympic', 'games'): defaultdict(int, {'for': 1.0}),
#              ('olympic',
#               'games',
#               'for'): defaultdict(int, {'snow': 0.5, 'athletes': 0.5}),
#              ('games', 'for', 'snow'): defaultdict(int, {'and': 1.0}),
#              ('for', 'snow', 'and'): defaultdict(int, {'ice': 1.0}),
#              ('snow', 'and', 'ice'): defaultdict(int, {'sports': 1.0}),
#              ('and', 'ice', 'sports'): defaultdict(int, {'the': 1.0}),
#              ('ice', 'sports', 'the'): defaultdict(int, {'paralympic': 1.0}),
#              ('sports', 'the', 'paralympic'): defaultdict(int, {'games': 1.0}),
#              ('the', 'paralympic', 'games'): defaultdict(int, {'for': 1.0}),
#              ('paralympic',
#               'games',
#               'for'): defaultdict(int, {'athletes': 1.0}),
#              ('games',
#               'for',
#               'athletes'): defaultdict(int, {'with': 0.5, 'aged': 0.5}),
#              ('for',
#               'athletes',
#               'with'): defaultdict(int, {'disabilities': 1.0}),
#              ('athletes',
#               'with',
#               'disabilities'): defaultdict(int, {'the': 1.0}),
#              ('with', 'disabilities', 'the'): defaultdict(int, {'youth': 1.0}),
#              ('disabilities',
#               'the',
#               'youth'): defaultdict(int, {'olympic': 1.0}),
#              ('the', 'youth', 'olympic'): defaultdict(int, {'games': 1.0}),
#              ('youth', 'olympic', 'games'): defaultdict(int, {'for': 1.0}),
#              ('for', 'athletes', 'aged'): defaultdict(int, {'to': 1.0}),
#              ('athletes', 'aged', 'to'): defaultdict(int, {'the': 1.0}),
#              ('aged', 'to', 'the'): defaultdict(int, {'five': 1.0}),
#              ('to', 'the', 'five'): defaultdict(int, {'continental': 1.0}),
#              ('the', 'five', 'continental'): defaultdict(int, {'games': 1.0}),
#              ('five', 'continental', 'games'): defaultdict(int, {'pan': 1.0}),
#              ('continental',
#               'games',
#               'pan'): defaultdict(int, {'american': 1.0}),
#              ('games', 'pan', 'american'): defaultdict(int, {'african': 1.0}),
#              ('pan', 'american', 'african'): defaultdict(int, {'asian': 1.0}),
#              ('american',
#               'african',
#               'asian'): defaultdict(int, {'european': 1.0}),
#              ('african', 'asian', 'european'): defaultdict(int, {'and': 1.0}),
#              ('asian', 'european', 'and'): defaultdict(int, {'pacific': 1.0}),
#              ('european', 'and', 'pacific'): defaultdict(int, {'and': 1.0}),
#              ('and', 'pacific', 'and'): defaultdict(int, {'the': 1.0}),
#              ('pacific', 'and', 'the'): defaultdict(int, {'world': 1.0}),
#              ('and', 'the', 'world'): defaultdict(int, {'games': 1.0}),
#              ('the', 'world', 'games'): defaultdict(int, {'for': 1.0}),
#              ('world', 'games', 'for'): defaultdict(int, {'sports': 1.0}),
#              ('games', 'for', 'sports'): defaultdict(int, {'that': 1.0}),
#              ('for', 'sports', 'that'): defaultdict(int, {'are': 1.0}),
#              ('sports', 'that', 'are'): defaultdict(int, {'not': 1.0}),
#              ('that', 'are', 'not'): defaultdict(int, {'contested': 1.0}),
#              ('are', 'not', 'contested'): defaultdict(int, {'in': 1.0}),
#              ('not', 'contested', 'in'): defaultdict(int, {'the': 1.0}),
#              ('contested', 'in', 'the'): defaultdict(int, {'olympic': 1.0}),
#              ('the',
#               'ioc',
#               'also'): defaultdict(int, {'endorses': 0.5, 'determines': 0.5}),
#              ('ioc', 'also', 'endorses'): defaultdict(int, {'the': 1.0}),
#              ('also',
#               'endorses',
#               'the'): defaultdict(int, {'deaflympics': 1.0}),
#              ('endorses',
#               'the',
#               'deaflympics'): defaultdict(int, {'and': 1.0}),
#              ('the', 'deaflympics', 'and'): defaultdict(int, {'the': 1.0}),
#              ('deaflympics', 'and', 'the'): defaultdict(int, {'special': 1.0}),
#              ('and', 'the', 'special'): defaultdict(int, {'olympics': 1.0}),
#              ('the', 'special', 'olympics'): defaultdict(int, {'etkn': 1.0}),
#              ('special', 'olympics', 'etkn'): defaultdict(int, {'stkn': 1.0}),
#              ('olympics', 'etkn', 'stkn'): defaultdict(int, {'the': 1.0}),
#              ('the', 'ioc', 'has'): defaultdict(int, {'needed': 1.0}),
#              ('ioc', 'has', 'needed'): defaultdict(int, {'to': 1.0}),
#              ('has', 'needed', 'to'): defaultdict(int, {'adapt': 1.0}),
#              ('needed', 'to', 'adapt'): defaultdict(int, {'to': 1.0}),
#              ('to', 'adapt', 'to'): defaultdict(int, {'a': 1.0}),
#              ('adapt', 'to', 'a'): defaultdict(int, {'variety': 1.0}),
#              ('to', 'a', 'variety'): defaultdict(int, {'of': 1.0}),
#              ('variety',
#               'of',
#               'economic'): defaultdict(int, {'political': 1.0}),
#              ('of', 'economic', 'political'): defaultdict(int, {'and': 1.0}),
#              ('economic',
#               'political',
#               'and'): defaultdict(int, {'technological': 1.0}),
#              ('political',
#               'and',
#               'technological'): defaultdict(int, {'advancements': 1.0}),
#              ('and',
#               'technological',
#               'advancements'): defaultdict(int, {'etkn': 1.0}),
#              ('technological',
#               'advancements',
#               'etkn'): defaultdict(int, {'stkn': 1.0}),
#              ('advancements', 'etkn', 'stkn'): defaultdict(int, {'the': 1.0}),
#              ('stkn', 'the', 'abuse'): defaultdict(int, {'of': 1.0}),
#              ('the', 'abuse', 'of'): defaultdict(int, {'amateur': 1.0}),
#              ('abuse', 'of', 'amateur'): defaultdict(int, {'rules': 1.0}),
#              ('of', 'amateur', 'rules'): defaultdict(int, {'by': 1.0}),
#              ('amateur', 'rules', 'by'): defaultdict(int, {'the': 1.0}),
#              ('rules', 'by', 'the'): defaultdict(int, {'eastern': 1.0}),
#              ('by', 'the', 'eastern'): defaultdict(int, {'bloc': 1.0}),
#              ('the', 'eastern', 'bloc'): defaultdict(int, {'nations': 1.0}),
#              ('eastern',
#               'bloc',
#               'nations'): defaultdict(int, {'prompted': 1.0}),
#              ('bloc', 'nations', 'prompted'): defaultdict(int, {'the': 1.0}),
#              ('nations', 'prompted', 'the'): defaultdict(int, {'ioc': 1.0}),
#              ('prompted', 'the', 'ioc'): defaultdict(int, {'to': 1.0}),
#              ('the', 'ioc', 'to'): defaultdict(int, {'shift': 1.0}),
#              ('ioc', 'to', 'shift'): defaultdict(int, {'away': 1.0}),
#              ('to', 'shift', 'away'): defaultdict(int, {'from': 1.0}),
#              ('shift', 'away', 'from'): defaultdict(int, {'pure': 1.0}),
#              ('away', 'from', 'pure'): defaultdict(int, {'amateurism': 1.0}),
#              ('from', 'pure', 'amateurism'): defaultdict(int, {'as': 1.0}),
#              ('pure',
#               'amateurism',
#               'as'): defaultdict(int, {'envisioned': 1.0}),
#              ('amateurism', 'as', 'envisioned'): defaultdict(int, {'by': 1.0}),
#              ('as', 'envisioned', 'by'): defaultdict(int, {'coubertin': 1.0}),
#              ('envisioned', 'by', 'coubertin'): defaultdict(int, {'to': 1.0}),
#              ('by', 'coubertin', 'to'): defaultdict(int, {'the': 1.0}),
#              ('coubertin', 'to', 'the'): defaultdict(int, {'acceptance': 1.0}),
#              ('to', 'the', 'acceptance'): defaultdict(int, {'of': 1.0}),
#              ('the',
#               'acceptance',
#               'of'): defaultdict(int, {'professional': 1.0}),
#              ('acceptance',
#               'of',
#               'professional'): defaultdict(int, {'athletes': 1.0}),
#              ('of',
#               'professional',
#               'athletes'): defaultdict(int, {'participating': 1.0}),
#              ('professional',
#               'athletes',
#               'participating'): defaultdict(int, {'at': 1.0}),
#              ('athletes',
#               'participating',
#               'at'): defaultdict(int, {'the': 1.0}),
#              ('participating', 'at', 'the'): defaultdict(int, {'games': 1.0}),
#              ('at', 'the', 'games'): defaultdict(int, {'etkn': 1.0}),
#              ('the', 'games', 'etkn'): defaultdict(int, {'stkn': 1.0}),
#              ('stkn', 'the', 'growing'): defaultdict(int, {'importance': 1.0}),
#              ('the', 'growing', 'importance'): defaultdict(int, {'of': 1.0}),
#              ('growing', 'importance', 'of'): defaultdict(int, {'mass': 1.0}),
#              ('importance', 'of', 'mass'): defaultdict(int, {'media': 1.0}),
#              ('of', 'mass', 'media'): defaultdict(int, {'has': 1.0}),
#              ('mass', 'media', 'has'): defaultdict(int, {'created': 1.0}),
#              ('media', 'has', 'created'): defaultdict(int, {'the': 1.0}),
#              ('has', 'created', 'the'): defaultdict(int, {'issue': 1.0}),
#              ('created', 'the', 'issue'): defaultdict(int, {'of': 1.0}),
#              ('the', 'issue', 'of'): defaultdict(int, {'corporate': 1.0}),
#              ('issue',
#               'of',
#               'corporate'): defaultdict(int, {'sponsorship': 1.0}),
#              ('of',
#               'corporate',
#               'sponsorship'): defaultdict(int, {'and': 1.0}),
#              ('corporate',
#               'sponsorship',
#               'and'): defaultdict(int, {'general': 1.0}),
#              ('sponsorship',
#               'and',
#               'general'): defaultdict(int, {'commercialisation': 1.0}),
#              ('and',
#               'general',
#               'commercialisation'): defaultdict(int, {'of': 1.0}),
#              ('general',
#               'commercialisation',
#               'of'): defaultdict(int, {'the': 1.0}),
#              ('commercialisation',
#               'of',
#               'the'): defaultdict(int, {'games': 1.0}),
#              ('of', 'the', 'games'): defaultdict(int, {'etkn': 1.0}),
#              ('etkn', 'stkn', 'world'): defaultdict(int, {'wars': 1.0}),
#              ('stkn', 'world', 'wars'): defaultdict(int, {'led': 1.0}),
#              ('world', 'wars', 'led'): defaultdict(int, {'to': 1.0}),
#              ('wars', 'led', 'to'): defaultdict(int, {'the': 1.0}),
#              ('led', 'to', 'the'): defaultdict(int, {'cancellation': 1.0}),
#              ('to', 'the', 'cancellation'): defaultdict(int, {'of': 1.0}),
#              ('the', 'cancellation', 'of'): defaultdict(int, {'the': 1.0}),
#              ('cancellation', 'of', 'the'): defaultdict(int, {'and': 1.0}),
#              ('of', 'the', 'and'): defaultdict(int, {'olympics': 1.0}),
#              ('the',
#               'and',
#               'olympics'): defaultdict(int, {'large': 0.5, 'and': 0.5}),
#              ('and', 'olympics', 'large'): defaultdict(int, {'scale': 1.0}),
#              ('olympics',
#               'large',
#               'scale'): defaultdict(int, {'boycotts': 1.0}),
#              ('large', 'scale', 'boycotts'): defaultdict(int, {'during': 1.0}),
#              ('scale', 'boycotts', 'during'): defaultdict(int, {'the': 1.0}),
#              ('boycotts', 'during', 'the'): defaultdict(int, {'cold': 1.0}),
#              ('during', 'the', 'cold'): defaultdict(int, {'war': 1.0}),
#              ('the', 'cold', 'war'): defaultdict(int, {'limited': 1.0}),
#              ('cold',
#               'war',
#               'limited'): defaultdict(int, {'participation': 1.0}),
#              ('war',
#               'limited',
#               'participation'): defaultdict(int, {'in': 1.0}),
#              ('limited',
#               'participation',
#               'in'): defaultdict(int, {'the': 1.0}),
#              ('participation', 'in', 'the'): defaultdict(int, {'and': 1.0}),
#              ('in', 'the', 'and'): defaultdict(int, {'olympics': 1.0}),
#              ('and', 'olympics', 'and'): defaultdict(int, {'the': 1.0}),
#              ('olympics', 'and', 'the'): defaultdict(int, {'olympics': 1.0}),
#              ('and', 'the', 'olympics'): defaultdict(int, {'were': 1.0}),
#              ('the',
#               'olympics',
#               'were'): defaultdict(int, {'postponed': 0.5, 'of': 0.5}),
#              ('olympics',
#               'were',
#               'postponed'): defaultdict(int, {'until': 1.0}),
#              ('were',
#               'postponed',
#               'until'): defaultdict(int, {'as': 0.5, 'the': 0.5}),
#              ('postponed', 'until', 'as'): defaultdict(int, {'a': 1.0}),
#              ('until', 'as', 'a'): defaultdict(int, {'result': 1.0}),
#              ('as', 'a', 'result'): defaultdict(int, {'of': 1.0}),
#              ('a', 'result', 'of'): defaultdict(int, {'the': 1.0}),
#              ('result', 'of', 'the'): defaultdict(int, {'covid': 1.0}),
#              ('of', 'the', 'covid'): defaultdict(int, {'pandemic': 1.0}),
#              ('the', 'covid', 'pandemic'): defaultdict(int, {'etkn': 1.0}),
#              ('covid', 'pandemic', 'etkn'): defaultdict(int, {'stkn': 1.0}),
#              ('pandemic', 'etkn', 'stkn'): defaultdict(int, {'the': 1.0}),
#              ('olympic',
#               'movement',
#               'consists'): defaultdict(int, {'of': 1.0}),
#              ('movement',
#               'consists',
#               'of'): defaultdict(int, {'international': 1.0}),
#              ('consists',
#               'of',
#               'international'): defaultdict(int, {'sports': 1.0}),
#              ('of',
#               'international',
#               'sports'): defaultdict(int, {'federations': 1.0}),
#              ('international',
#               'sports',
#               'federations'): defaultdict(int, {'ifs': 1.0}),
#              ('sports',
#               'federations',
#               'ifs'): defaultdict(int, {'national': 1.0}),
#              ('federations',
#               'ifs',
#               'national'): defaultdict(int, {'olympic': 1.0}),
#              ('ifs',
#               'national',
#               'olympic'): defaultdict(int, {'committees': 1.0}),
#              ('national',
#               'olympic',
#               'committees'): defaultdict(int, {'nocs': 1.0}),
#              ('olympic', 'committees', 'nocs'): defaultdict(int, {'and': 1.0}),
#              ('committees',
#               'nocs',
#               'and'): defaultdict(int, {'organising': 1.0}),
#              ('nocs',
#               'and',
#               'organising'): defaultdict(int, {'committees': 1.0}),
#              ('and',
#               'organising',
#               'committees'): defaultdict(int, {'for': 1.0}),
#              ('organising',
#               'committees',
#               'for'): defaultdict(int, {'each': 1.0}),
#              ('committees',
#               'for',
#               'each'): defaultdict(int, {'specific': 1.0}),
#              ('for', 'each', 'specific'): defaultdict(int, {'olympic': 1.0}),
#              ('each', 'specific', 'olympic'): defaultdict(int, {'games': 1.0}),
#              ('specific', 'olympic', 'games'): defaultdict(int, {'etkn': 1.0}),
#              ('etkn', 'stkn', 'as'): defaultdict(int, {'the': 1.0}),
#              ('stkn', 'as', 'the'): defaultdict(int, {'decision': 1.0}),
#              ('as', 'the', 'decision'): defaultdict(int, {'making': 1.0}),
#              ('the', 'decision', 'making'): defaultdict(int, {'body': 1.0}),
#              ('decision', 'making', 'body'): defaultdict(int, {'the': 1.0}),
#              ('making', 'body', 'the'): defaultdict(int, {'ioc': 1.0}),
#              ('body', 'the', 'ioc'): defaultdict(int, {'is': 1.0}),
#              ('ioc', 'is', 'responsible'): defaultdict(int, {'for': 1.0}),
#              ('is', 'responsible', 'for'): defaultdict(int, {'choosing': 1.0}),
#              ('responsible',
#               'for',
#               'choosing'): defaultdict(int, {'the': 1.0}),
#              ('for', 'choosing', 'the'): defaultdict(int, {'host': 1.0}),
#              ('choosing', 'the', 'host'): defaultdict(int, {'city': 1.0}),
#              ('the',
#               'host',
#               'city'): defaultdict(int, {'for': 0.5, 'and': 0.5}),
#              ('host', 'city', 'for'): defaultdict(int, {'each': 1.0}),
#              ('city', 'for', 'each'): defaultdict(int, {'games': 1.0}),
#              ('for', 'each', 'games'): defaultdict(int, {'and': 1.0}),
#              ('each', 'games', 'and'): defaultdict(int, {'organises': 1.0}),
#              ('games', 'and', 'organises'): defaultdict(int, {'and': 1.0}),
#              ('and', 'organises', 'and'): defaultdict(int, {'funds': 1.0}),
#              ('organises', 'and', 'funds'): defaultdict(int, {'the': 1.0}),
#              ('and', 'funds', 'the'): defaultdict(int, {'games': 1.0}),
#              ('funds', 'the', 'games'): defaultdict(int, {'according': 1.0}),
#              ('the', 'games', 'according'): defaultdict(int, {'to': 1.0}),
#              ('games', 'according', 'to'): defaultdict(int, {'the': 1.0}),
#              ('according', 'to', 'the'): defaultdict(int, {'olympic': 1.0}),
#              ('olympic', 'charter', 'etkn'): defaultdict(int, {'stkn': 1.0}),
#              ('charter', 'etkn', 'stkn'): defaultdict(int, {'the': 1.0}),
#              ('ioc', 'also', 'determines'): defaultdict(int, {'the': 1.0}),
#              ('also', 'determines', 'the'): defaultdict(int, {'olympic': 1.0}),
#              ('determines',
#               'the',
#               'olympic'): defaultdict(int, {'programme': 1.0}),
#              ('the',
#               'olympic',
#               'programme'): defaultdict(int, {'consisting': 1.0}),
#              ('olympic',
#               'programme',
#               'consisting'): defaultdict(int, {'of': 1.0}),
#              ('programme', 'consisting', 'of'): defaultdict(int, {'the': 1.0}),
#              ('consisting', 'of', 'the'): defaultdict(int, {'sports': 1.0}),
#              ('of', 'the', 'sports'): defaultdict(int, {'to': 1.0}),
#              ('the', 'sports', 'to'): defaultdict(int, {'be': 1.0}),
#              ('sports', 'to', 'be'): defaultdict(int, {'contested': 1.0}),
#              ('to', 'be', 'contested'): defaultdict(int, {'at': 1.0}),
#              ('be', 'contested', 'at'): defaultdict(int, {'the': 1.0}),
#              ('contested', 'at', 'the'): defaultdict(int, {'games': 1.0}),
#              ('etkn', 'stkn', 'there'): defaultdict(int, {'are': 1.0}),
#              ('stkn', 'there', 'are'): defaultdict(int, {'several': 1.0}),
#              ('there', 'are', 'several'): defaultdict(int, {'olympic': 1.0}),
#              ('are', 'several', 'olympic'): defaultdict(int, {'rituals': 1.0}),
#              ('several', 'olympic', 'rituals'): defaultdict(int, {'and': 1.0}),
#              ('olympic', 'rituals', 'and'): defaultdict(int, {'symbols': 1.0}),
#              ('rituals', 'and', 'symbols'): defaultdict(int, {'such': 1.0}),
#              ('and', 'symbols', 'such'): defaultdict(int, {'as': 1.0}),
#              ('symbols', 'such', 'as'): defaultdict(int, {'the': 1.0}),
#              ('such', 'as', 'the'): defaultdict(int, {'olympic': 1.0}),
#              ('as',
#               'the',
#               'olympic'): defaultdict(int, {'flag': 0.5, 'peace': 0.5}),
#              ('the', 'olympic', 'flag'): defaultdict(int, {'and': 1.0}),
#              ('olympic', 'flag', 'and'): defaultdict(int, {'torch': 1.0}),
#              ('flag', 'and', 'torch'): defaultdict(int, {'as': 1.0}),
#              ('and', 'torch', 'as'): defaultdict(int, {'well': 1.0}),
#              ('torch', 'as', 'well'): defaultdict(int, {'as': 1.0}),
#              ('as', 'well', 'as'): defaultdict(int, {'the': 1.0}),
#              ('well', 'as', 'the'): defaultdict(int, {'opening': 1.0}),
#              ('as', 'the', 'opening'): defaultdict(int, {'and': 1.0}),
#              ('the', 'opening', 'and'): defaultdict(int, {'closing': 1.0}),
#              ('opening',
#               'and',
#               'closing'): defaultdict(int, {'ceremonies': 1.0}),
#              ('and', 'closing', 'ceremonies'): defaultdict(int, {'etkn': 1.0}),
#              ('closing',
#               'ceremonies',
#               'etkn'): defaultdict(int, {'stkn': 1.0}),
#              ('ceremonies', 'etkn', 'stkn'): defaultdict(int, {'over': 1.0}),
#              ('etkn', 'stkn', 'over'): defaultdict(int, {'athletes': 1.0}),
#              ('stkn', 'over', 'athletes'): defaultdict(int, {'competed': 1.0}),
#              ('over', 'athletes', 'competed'): defaultdict(int, {'at': 1.0}),
#              ('athletes', 'competed', 'at'): defaultdict(int, {'the': 1.0}),
#              ('competed', 'at', 'the'): defaultdict(int, {'summer': 1.0}),
#              ('at', 'the', 'summer'): defaultdict(int, {'olympics': 1.0}),
#              ('the', 'summer', 'olympics'): defaultdict(int, {'and': 1.0}),
#              ('summer', 'olympics', 'and'): defaultdict(int, {'winter': 1.0}),
#              ('olympics',
#               'and',
#               'winter'): defaultdict(int, {'olympics': 1.0}),
#              ('winter', 'olympics', 'combined'): defaultdict(int, {'in': 1.0}),
#              ('olympics',
#               'combined',
#               'in'): defaultdict(int, {'different': 1.0}),
#              ('combined',
#               'in',
#               'different'): defaultdict(int, {'sports': 1.0}),
#              ('in', 'different', 'sports'): defaultdict(int, {'and': 1.0}),
#              ('different', 'sports', 'and'): defaultdict(int, {'events': 1.0}),
#              ('sports', 'and', 'events'): defaultdict(int, {'etkn': 1.0}),
#              ('and', 'events', 'etkn'): defaultdict(int, {'stkn': 1.0}),
#              ('events',
#               'etkn',
#               'stkn'): defaultdict(int,
#                          {'the': 0.3333333333333333,
#                           'it': 0.3333333333333333,
#                           'tradition': 0.3333333333333333}),
#              ('stkn', 'the', 'first'): defaultdict(int, {'second': 1.0}),
#              ('the', 'first', 'second'): defaultdict(int, {'and': 1.0}),
#              ('first', 'second', 'and'): defaultdict(int, {'third': 1.0}),
#              ('second', 'and', 'third'): defaultdict(int, {'place': 1.0}),
#              ('and', 'third', 'place'): defaultdict(int, {'finishers': 1.0}),
#              ('third', 'place', 'finishers'): defaultdict(int, {'in': 1.0}),
#              ('place', 'finishers', 'in'): defaultdict(int, {'each': 1.0}),
#              ('finishers', 'in', 'each'): defaultdict(int, {'event': 1.0}),
#              ('in', 'each', 'event'): defaultdict(int, {'receive': 1.0}),
#              ('each', 'event', 'receive'): defaultdict(int, {'olympic': 1.0}),
#              ('event',
#               'receive',
#               'olympic'): defaultdict(int, {'medals': 1.0}),
#              ('receive', 'olympic', 'medals'): defaultdict(int, {'gold': 1.0}),
#              ('olympic', 'medals', 'gold'): defaultdict(int, {'silver': 1.0}),
#              ('medals', 'gold', 'silver'): defaultdict(int, {'and': 1.0}),
#              ('gold', 'silver', 'and'): defaultdict(int, {'bronze': 1.0}),
#              ('silver',
#               'and',
#               'bronze'): defaultdict(int, {'respectively': 1.0}),
#              ('and',
#               'bronze',
#               'respectively'): defaultdict(int, {'etkn': 1.0}),
#              ('bronze',
#               'respectively',
#               'etkn'): defaultdict(int, {'stkn': 1.0}),
#              ('respectively', 'etkn', 'stkn'): defaultdict(int, {'the': 1.0}),
#              ('stkn',
#               'the',
#               'games'): defaultdict(int,
#                          {'have': 0.25, 'also': 0.25, 'were': 0.5}),
#              ('the', 'games', 'have'): defaultdict(int, {'grown': 1.0}),
#              ('games', 'have', 'grown'): defaultdict(int, {'to': 1.0}),
#              ('have', 'grown', 'to'): defaultdict(int, {'the': 1.0}),
#              ('grown', 'to', 'the'): defaultdict(int, {'point': 1.0}),
#              ('to', 'the', 'point'): defaultdict(int, {'that': 1.0}),
#              ('the', 'point', 'that'): defaultdict(int, {'nearly': 1.0}),
#              ('point', 'that', 'nearly'): defaultdict(int, {'every': 1.0}),
#              ('that', 'nearly', 'every'): defaultdict(int, {'nation': 1.0}),
#              ('nearly', 'every', 'nation'): defaultdict(int, {'is': 1.0}),
#              ('every', 'nation', 'is'): defaultdict(int, {'now': 1.0}),
#              ('nation', 'is', 'now'): defaultdict(int, {'represented': 1.0}),
#              ('is', 'now', 'represented'): defaultdict(int, {'colonies': 1.0}),
#              ('now',
#               'represented',
#               'colonies'): defaultdict(int, {'and': 1.0}),
#              ('represented',
#               'colonies',
#               'and'): defaultdict(int, {'overseas': 1.0}),
#              ('colonies',
#               'and',
#               'overseas'): defaultdict(int, {'territories': 1.0}),
#              ('and',
#               'overseas',
#               'territories'): defaultdict(int, {'are': 1.0}),
#              ('overseas',
#               'territories',
#               'are'): defaultdict(int, {'often': 1.0}),
#              ('territories',
#               'are',
#               'often'): defaultdict(int, {'allowed': 1.0}),
#              ('are', 'often', 'allowed'): defaultdict(int, {'to': 1.0}),
#              ('often', 'allowed', 'to'): defaultdict(int, {'field': 1.0}),
#              ('allowed', 'to', 'field'): defaultdict(int, {'their': 1.0}),
#              ('to', 'field', 'their'): defaultdict(int, {'own': 1.0}),
#              ('field', 'their', 'own'): defaultdict(int, {'teams': 1.0}),
#              ('their', 'own', 'teams'): defaultdict(int, {'etkn': 1.0}),
#              ('own', 'teams', 'etkn'): defaultdict(int, {'stkn': 1.0}),
#              ('teams', 'etkn', 'stkn'): defaultdict(int, {'this': 1.0}),
#              ('etkn',
#               'stkn',
#               'this'): defaultdict(int,
#                          {'growth': 0.3333333333333333,
#                           'cessation': 0.3333333333333333,
#                           'idea': 0.3333333333333333}),
#              ('stkn', 'this', 'growth'): defaultdict(int, {'has': 1.0}),
#              ('this', 'growth', 'has'): defaultdict(int, {'created': 1.0}),
#              ('growth', 'has', 'created'): defaultdict(int, {'numerous': 1.0}),
#              ('has',
#               'created',
#               'numerous'): defaultdict(int, {'challenges': 1.0}),
#              ('created',
#               'numerous',
#               'challenges'): defaultdict(int, {'and': 1.0}),
#              ('numerous',
#               'challenges',
#               'and'): defaultdict(int, {'controversies': 1.0}),
#              ('challenges',
#               'and',
#               'controversies'): defaultdict(int, {'including': 1.0}),
#              ('and',
#               'controversies',
#               'including'): defaultdict(int, {'boycotts': 1.0}),
#              ('controversies',
#               'including',
#               'boycotts'): defaultdict(int, {'doping': 1.0}),
#              ('including',
#               'boycotts',
#               'doping'): defaultdict(int, {'bribery': 1.0}),
#              ('boycotts', 'doping', 'bribery'): defaultdict(int, {'and': 1.0}),
#              ('doping',
#               'bribery',
#               'and'): defaultdict(int, {'terrorism': 1.0}),
#              ('bribery', 'and', 'terrorism'): defaultdict(int, {'etkn': 1.0}),
#              ('and', 'terrorism', 'etkn'): defaultdict(int, {'stkn': 1.0}),
#              ('terrorism', 'etkn', 'stkn'): defaultdict(int, {'every': 1.0}),
#              ('etkn', 'stkn', 'every'): defaultdict(int, {'two': 1.0}),
#              ('stkn', 'every', 'two'): defaultdict(int, {'years': 1.0}),
#              ('two', 'years', 'the'): defaultdict(int, {'olympics': 1.0}),
#              ('years', 'the', 'olympics'): defaultdict(int, {'and': 1.0}),
#              ('the', 'olympics', 'and'): defaultdict(int, {'its': 1.0}),
#              ('olympics', 'and', 'its'): defaultdict(int, {'media': 1.0}),
#              ('and', 'its', 'media'): defaultdict(int, {'exposure': 1.0}),
#              ('its', 'media', 'exposure'): defaultdict(int, {'provide': 1.0}),
#              ('media',
#               'exposure',
#               'provide'): defaultdict(int, {'athletes': 1.0}),
#              ('exposure',
#               'provide',
#               'athletes'): defaultdict(int, {'with': 1.0}),
#              ('provide', 'athletes', 'with'): defaultdict(int, {'the': 1.0}),
#              ('athletes', 'with', 'the'): defaultdict(int, {'chance': 1.0}),
# ...
#              ('date', 'for', 'the'): defaultdict(int, {'ancient': 1.0}),
#              ('for', 'the', 'ancient'): defaultdict(int, {'olympics': 1.0}),
#              ('the', 'ancient', 'olympics'): defaultdict(int, {'is': 1.0}),
#              ('ancient', 'olympics', 'is'): defaultdict(int, {'bc': 1.0}),
#              ('olympics', 'is', 'bc'): defaultdict(int, {'this': 1.0}),
#              ('is', 'bc', 'this'): defaultdict(int, {'is': 1.0}),
#              ('bc', 'this', 'is'): defaultdict(int, {'based': 1.0}),
#              ('this', 'is', 'based'): defaultdict(int, {'on': 1.0}),
#              ('is', 'based', 'on'): defaultdict(int, {'inscriptions': 1.0}),
#              ('based', 'on', 'inscriptions'): defaultdict(int, {'found': 1.0}),
#              ('on', 'inscriptions', 'found'): defaultdict(int, {'at': 1.0}),
#              ('inscriptions',
#               'found',
#               'at'): defaultdict(int, {'olympia': 1.0}),
#              ('found', 'at', 'olympia'): defaultdict(int, {'listing': 1.0}),
#              ('at', 'olympia', 'listing'): defaultdict(int, {'the': 1.0}),
#              ('olympia', 'listing', 'the'): defaultdict(int, {'winners': 1.0}),
#              ('listing', 'the', 'winners'): defaultdict(int, {'of': 1.0}),
#              ('the',
#               'winners',
#               'of'): defaultdict(int, {'a': 0.5, 'the': 0.5}),
#              ('winners', 'of', 'a'): defaultdict(int, {'footrace': 1.0}),
#              ('of', 'a', 'footrace'): defaultdict(int, {'held': 1.0}),
#              ('a', 'footrace', 'held'): defaultdict(int, {'every': 1.0}),
#              ('footrace', 'held', 'every'): defaultdict(int, {'four': 1.0}),
#              ('four', 'years', 'starting'): defaultdict(int, {'in': 1.0}),
#              ('years', 'starting', 'in'): defaultdict(int, {'bc': 1.0}),
#              ('starting', 'in', 'bc'): defaultdict(int, {'etkn': 1.0}),
#              ('in', 'bc', 'etkn'): defaultdict(int, {'stkn': 1.0}),
#              ('bc', 'etkn', 'stkn'): defaultdict(int, {'the': 1.0}),
#              ('the', 'ancient', 'games'): defaultdict(int, {'featured': 1.0}),
#              ('ancient',
#               'games',
#               'featured'): defaultdict(int, {'running': 1.0}),
#              ('games',
#               'featured',
#               'running'): defaultdict(int, {'events': 1.0}),
#              ('featured', 'running', 'events'): defaultdict(int, {'a': 1.0}),
#              ('running', 'events', 'a'): defaultdict(int, {'pentathlon': 1.0}),
#              ('events',
#               'a',
#               'pentathlon'): defaultdict(int, {'consisting': 1.0}),
#              ('a', 'pentathlon', 'consisting'): defaultdict(int, {'of': 1.0}),
#              ('pentathlon', 'consisting', 'of'): defaultdict(int, {'a': 1.0}),
#              ('consisting', 'of', 'a'): defaultdict(int, {'jumping': 1.0}),
#              ('of', 'a', 'jumping'): defaultdict(int, {'event': 1.0}),
#              ('a', 'jumping', 'event'): defaultdict(int, {'discus': 1.0}),
#              ('jumping', 'event', 'discus'): defaultdict(int, {'and': 1.0}),
#              ('event', 'discus', 'and'): defaultdict(int, {'javelin': 1.0}),
#              ('discus', 'and', 'javelin'): defaultdict(int, {'throws': 1.0}),
#              ('and', 'javelin', 'throws'): defaultdict(int, {'a': 1.0}),
#              ('javelin', 'throws', 'a'): defaultdict(int, {'foot': 1.0}),
#              ('throws', 'a', 'foot'): defaultdict(int, {'race': 1.0}),
#              ('a', 'foot', 'race'): defaultdict(int, {'and': 1.0}),
#              ('foot', 'race', 'and'): defaultdict(int, {'wrestling': 1.0}),
#              ('race', 'and', 'wrestling'): defaultdict(int, {'boxing': 1.0}),
#              ('and',
#               'wrestling',
#               'boxing'): defaultdict(int, {'wrestling': 1.0}),
#              ('wrestling',
#               'boxing',
#               'wrestling'): defaultdict(int, {'pankration': 1.0}),
#              ('boxing',
#               'wrestling',
#               'pankration'): defaultdict(int, {'and': 1.0}),
#              ('wrestling',
#               'pankration',
#               'and'): defaultdict(int, {'equestrian': 1.0}),
#              ('pankration',
#               'and',
#               'equestrian'): defaultdict(int, {'events': 1.0}),
#              ('and', 'equestrian', 'events'): defaultdict(int, {'etkn': 1.0}),
#              ('equestrian', 'events', 'etkn'): defaultdict(int, {'stkn': 1.0}),
#              ('etkn', 'stkn', 'tradition'): defaultdict(int, {'has': 1.0}),
#              ('stkn', 'tradition', 'has'): defaultdict(int, {'it': 1.0}),
#              ('tradition', 'has', 'it'): defaultdict(int, {'that': 1.0}),
#              ('has', 'it', 'that'): defaultdict(int, {'coroebus': 1.0}),
#              ('it', 'that', 'coroebus'): defaultdict(int, {'a': 1.0}),
#              ('that', 'coroebus', 'a'): defaultdict(int, {'cook': 1.0}),
#              ('coroebus', 'a', 'cook'): defaultdict(int, {'from': 1.0}),
#              ('a', 'cook', 'from'): defaultdict(int, {'the': 1.0}),
#              ('cook', 'from', 'the'): defaultdict(int, {'city': 1.0}),
#              ('from', 'the', 'city'): defaultdict(int, {'of': 1.0}),
#              ('the', 'city', 'of'): defaultdict(int, {'elis': 1.0}),
#              ('city', 'of', 'elis'): defaultdict(int, {'was': 1.0}),
#              ('of', 'elis', 'was'): defaultdict(int, {'the': 1.0}),
#              ('elis', 'was', 'the'): defaultdict(int, {'first': 1.0}),
#              ('was', 'the', 'first'): defaultdict(int, {'olympic': 1.0}),
#              ('the', 'first', 'olympic'): defaultdict(int, {'champion': 1.0}),
#              ('first', 'olympic', 'champion'): defaultdict(int, {'etkn': 1.0}),
#              ('olympic', 'champion', 'etkn'): defaultdict(int, {'stkn': 1.0}),
#              ('champion', 'etkn', 'stkn'): defaultdict(int, {'the': 1.0}),
#              ('stkn', 'the', 'olympics'): defaultdict(int, {'were': 1.0}),
#              ('olympics',
#               'were',
#               'of'): defaultdict(int, {'fundamental': 1.0}),
#              ('were',
#               'of',
#               'fundamental'): defaultdict(int, {'religious': 1.0}),
#              ('of',
#               'fundamental',
#               'religious'): defaultdict(int, {'importance': 1.0}),
#              ('fundamental',
#               'religious',
#               'importance'): defaultdict(int, {'featuring': 1.0}),
#              ('religious',
#               'importance',
#               'featuring'): defaultdict(int, {'sporting': 1.0}),
#              ('importance',
#               'featuring',
#               'sporting'): defaultdict(int, {'events': 1.0}),
#              ('featuring',
#               'sporting',
#               'events'): defaultdict(int, {'alongside': 1.0}),
#              ('sporting',
#               'events',
#               'alongside'): defaultdict(int, {'ritual': 1.0}),
#              ('events',
#               'alongside',
#               'ritual'): defaultdict(int, {'sacrifices': 1.0}),
#              ('alongside',
#               'ritual',
#               'sacrifices'): defaultdict(int, {'honouring': 1.0}),
#              ('ritual',
#               'sacrifices',
#               'honouring'): defaultdict(int, {'both': 1.0}),
#              ('sacrifices',
#               'honouring',
#               'both'): defaultdict(int, {'zeus': 1.0}),
#              ('honouring', 'both', 'zeus'): defaultdict(int, {'whose': 1.0}),
#              ('both', 'zeus', 'whose'): defaultdict(int, {'famous': 1.0}),
#              ('zeus', 'whose', 'famous'): defaultdict(int, {'statue': 1.0}),
#              ('whose', 'famous', 'statue'): defaultdict(int, {'by': 1.0}),
#              ('famous', 'statue', 'by'): defaultdict(int, {'phidias': 1.0}),
#              ('statue', 'by', 'phidias'): defaultdict(int, {'stood': 1.0}),
#              ('by', 'phidias', 'stood'): defaultdict(int, {'in': 1.0}),
#              ('phidias', 'stood', 'in'): defaultdict(int, {'his': 1.0}),
#              ('stood', 'in', 'his'): defaultdict(int, {'temple': 1.0}),
#              ('in', 'his', 'temple'): defaultdict(int, {'at': 1.0}),
#              ('his', 'temple', 'at'): defaultdict(int, {'olympia': 1.0}),
#              ('temple', 'at', 'olympia'): defaultdict(int, {'and': 1.0}),
#              ('at', 'olympia', 'and'): defaultdict(int, {'pelops': 1.0}),
#              ('olympia', 'and', 'pelops'): defaultdict(int, {'divine': 1.0}),
#              ('and', 'pelops', 'divine'): defaultdict(int, {'hero': 1.0}),
#              ('pelops', 'divine', 'hero'): defaultdict(int, {'and': 1.0}),
#              ('divine', 'hero', 'and'): defaultdict(int, {'mythical': 1.0}),
#              ('hero', 'and', 'mythical'): defaultdict(int, {'king': 1.0}),
#              ('and', 'mythical', 'king'): defaultdict(int, {'of': 1.0}),
#              ('mythical', 'king', 'of'): defaultdict(int, {'olympia': 1.0}),
#              ('king', 'of', 'olympia'): defaultdict(int, {'etkn': 1.0}),
#              ('of', 'olympia', 'etkn'): defaultdict(int, {'stkn': 1.0}),
#              ('olympia', 'etkn', 'stkn'): defaultdict(int, {'pelops': 1.0}),
#              ('etkn', 'stkn', 'pelops'): defaultdict(int, {'was': 1.0}),
#              ('stkn', 'pelops', 'was'): defaultdict(int, {'famous': 1.0}),
#              ('pelops', 'was', 'famous'): defaultdict(int, {'for': 1.0}),
#              ('was', 'famous', 'for'): defaultdict(int, {'his': 1.0}),
#              ('famous', 'for', 'his'): defaultdict(int, {'chariot': 1.0}),
#              ('for', 'his', 'chariot'): defaultdict(int, {'race': 1.0}),
#              ('his', 'chariot', 'race'): defaultdict(int, {'with': 1.0}),
#              ('chariot', 'race', 'with'): defaultdict(int, {'king': 1.0}),
#              ('race', 'with', 'king'): defaultdict(int, {'oenomaus': 1.0}),
#              ('with', 'king', 'oenomaus'): defaultdict(int, {'of': 1.0}),
#              ('king', 'oenomaus', 'of'): defaultdict(int, {'pisatis': 1.0}),
#              ('oenomaus', 'of', 'pisatis'): defaultdict(int, {'etkn': 1.0}),
#              ('of', 'pisatis', 'etkn'): defaultdict(int, {'stkn': 1.0}),
#              ('pisatis', 'etkn', 'stkn'): defaultdict(int, {'the': 1.0}),
#              ('stkn', 'the', 'winners'): defaultdict(int, {'of': 1.0}),
#              ('winners', 'of', 'the'): defaultdict(int, {'events': 1.0}),
#              ('of', 'the', 'events'): defaultdict(int, {'were': 1.0}),
#              ('the', 'events', 'were'): defaultdict(int, {'admired': 1.0}),
#              ('events', 'were', 'admired'): defaultdict(int, {'and': 1.0}),
#              ('were',
#               'admired',
#               'and'): defaultdict(int, {'immortalised': 1.0}),
#              ('admired', 'and', 'immortalised'): defaultdict(int, {'in': 1.0}),
#              ('and', 'immortalised', 'in'): defaultdict(int, {'poems': 1.0}),
#              ('immortalised', 'in', 'poems'): defaultdict(int, {'and': 1.0}),
#              ('in', 'poems', 'and'): defaultdict(int, {'statues': 1.0}),
#              ('poems', 'and', 'statues'): defaultdict(int, {'etkn': 1.0}),
#              ('and', 'statues', 'etkn'): defaultdict(int, {'stkn': 1.0}),
#              ('statues', 'etkn', 'stkn'): defaultdict(int, {'the': 1.0}),
#              ('games', 'were', 'held'): defaultdict(int, {'every': 1.0}),
#              ('were', 'held', 'every'): defaultdict(int, {'four': 1.0}),
#              ('years', 'and', 'this'): defaultdict(int, {'period': 1.0}),
#              ('and', 'this', 'period'): defaultdict(int, {'known': 1.0}),
#              ('this', 'period', 'known'): defaultdict(int, {'as': 1.0}),
#              ('period', 'known', 'as'): defaultdict(int, {'an': 1.0}),
#              ('known', 'as', 'an'): defaultdict(int, {'olympiad': 1.0}),
#              ('as', 'an', 'olympiad'): defaultdict(int, {'was': 1.0}),
#              ('an', 'olympiad', 'was'): defaultdict(int, {'used': 1.0}),
#              ('olympiad', 'was', 'used'): defaultdict(int, {'by': 1.0}),
#              ('was', 'used', 'by'): defaultdict(int, {'greeks': 1.0}),
#              ('used', 'by', 'greeks'): defaultdict(int, {'as': 1.0}),
#              ('by', 'greeks', 'as'): defaultdict(int, {'one': 1.0}),
#              ('greeks', 'as', 'one'): defaultdict(int, {'of': 1.0}),
#              ('as', 'one', 'of'): defaultdict(int, {'their': 1.0}),
#              ('one', 'of', 'their'): defaultdict(int, {'units': 1.0}),
#              ('of', 'their', 'units'): defaultdict(int, {'of': 1.0}),
#              ('their', 'units', 'of'): defaultdict(int, {'time': 1.0}),
#              ('units', 'of', 'time'): defaultdict(int, {'measurement': 1.0}),
#              ('of', 'time', 'measurement'): defaultdict(int, {'etkn': 1.0}),
#              ('time', 'measurement', 'etkn'): defaultdict(int, {'stkn': 1.0}),
#              ('measurement', 'etkn', 'stkn'): defaultdict(int, {'the': 1.0}),
#              ('games', 'were', 'part'): defaultdict(int, {'of': 1.0}),
#              ('were', 'part', 'of'): defaultdict(int, {'a': 1.0}),
#              ('part', 'of', 'a'): defaultdict(int, {'cycle': 1.0}),
#              ('of', 'a', 'cycle'): defaultdict(int, {'known': 1.0}),
#              ('a', 'cycle', 'known'): defaultdict(int, {'as': 1.0}),
#              ('cycle', 'known', 'as'): defaultdict(int, {'the': 1.0}),
#              ('as', 'the', 'panhellenic'): defaultdict(int, {'games': 1.0}),
#              ('the', 'panhellenic', 'games'): defaultdict(int, {'which': 1.0}),
#              ('panhellenic',
#               'games',
#               'which'): defaultdict(int, {'included': 1.0}),
#              ('games', 'which', 'included'): defaultdict(int, {'the': 1.0}),
#              ('which', 'included', 'the'): defaultdict(int, {'pythian': 1.0}),
#              ('included', 'the', 'pythian'): defaultdict(int, {'games': 1.0}),
#              ('the', 'pythian', 'games'): defaultdict(int, {'the': 1.0}),
#              ('pythian', 'games', 'the'): defaultdict(int, {'nemean': 1.0}),
#              ('games', 'the', 'nemean'): defaultdict(int, {'games': 1.0}),
#              ('the', 'nemean', 'games'): defaultdict(int, {'and': 1.0}),
#              ('nemean', 'games', 'and'): defaultdict(int, {'the': 1.0}),
#              ('games', 'and', 'the'): defaultdict(int, {'isthmian': 1.0}),
#              ('and', 'the', 'isthmian'): defaultdict(int, {'games': 1.0}),
#              ('the', 'isthmian', 'games'): defaultdict(int, {'etkn': 1.0}),
#              ('isthmian', 'games', 'etkn'): defaultdict(int, {'stkn': 1.0}),
#              ('olympic', 'games', 'reached'): defaultdict(int, {'the': 1.0}),
#              ('games', 'reached', 'the'): defaultdict(int, {'height': 1.0}),
#              ('reached', 'the', 'height'): defaultdict(int, {'of': 1.0}),
#              ('the', 'height', 'of'): defaultdict(int, {'their': 1.0}),
#              ('height', 'of', 'their'): defaultdict(int, {'success': 1.0}),
#              ('of', 'their', 'success'): defaultdict(int, {'in': 1.0}),
#              ('their', 'success', 'in'): defaultdict(int, {'the': 1.0}),
#              ('success', 'in', 'the'): defaultdict(int, {'th': 1.0}),
#              ('in', 'the', 'th'): defaultdict(int, {'and': 1.0}),
#              ('th', 'and', 'th'): defaultdict(int, {'centuries': 1.0}),
#              ('and', 'th', 'centuries'): defaultdict(int, {'bc': 1.0}),
#              ('th', 'centuries', 'bc'): defaultdict(int, {'but': 1.0}),
#              ('centuries', 'bc', 'but'): defaultdict(int, {'then': 1.0}),
#              ('bc', 'but', 'then'): defaultdict(int, {'gradually': 1.0}),
#              ('but', 'then', 'gradually'): defaultdict(int, {'declined': 1.0}),
#              ('then', 'gradually', 'declined'): defaultdict(int, {'in': 1.0}),
#              ('gradually',
#               'declined',
#               'in'): defaultdict(int, {'importance': 1.0}),
#              ('declined', 'in', 'importance'): defaultdict(int, {'as': 1.0}),
#              ('in', 'importance', 'as'): defaultdict(int, {'the': 1.0}),
#              ('importance', 'as', 'the'): defaultdict(int, {'romans': 1.0}),
#              ('as', 'the', 'romans'): defaultdict(int, {'gained': 1.0}),
#              ('the', 'romans', 'gained'): defaultdict(int, {'power': 1.0}),
#              ('romans', 'gained', 'power'): defaultdict(int, {'and': 1.0}),
#              ('gained', 'power', 'and'): defaultdict(int, {'influence': 1.0}),
#              ...})

# %%
def fourgram_gen(input_text):
    
    starting_words = input_text.split(' ')
    sentence = list(starting_words)
    next_word = ''

    while next_word != 'etkn':
        w1, w2, w3 = sentence[-3], sentence[-2], sentence[-1]
        if (w1, w2, w3) in model_four:
            # calls the next word given on the probability of that word itself
            next_word = random.choices(list(model_four[(w1, w2, w3)].keys()), weights=model_four[(w1, w2, w3)].values())[0]
            sentence.append(next_word)
        else:
            break
            
        if len(sentence) < 30:
            next_word = ''
            
    return ' '.join(sentence)

# %% [markdown]
# ### Generating The Outputs

# %%
input_text = 'and'
generated_sentence = bigram_gen(input_text)
print(generated_sentence)
# Out:
# and bronze respectively etkn stkn pelops divine hero and chariot racing events etkn stkn competition was inspired by phidias stood in the world championships the sports that all greek latin stadium as an opportunity for his twelve labours he built the youth olympic flag and overseas territories are normally held in poems and bronze respectively etkn

# %%
input_text = 'the modern'
generated_sentence = trigram_gen(input_text)
print(generated_sentence)
# Out:
# the modern olympic games are considered the world foremost sports competition with more than teams representing sovereign states and territories participating by default the games according to the five continental games pan american african asian european and pacific and the world etkn

# %%
input_text = 'the modern olympic'
generated_sentence = fourgram_gen(input_text)
print(generated_sentence)
# Out:
# the modern olympic games or olympics are the leading international sporting events featuring summer and winter olympics combined in different sports and events etkn stkn tradition has it that coroebus a cook from the city of elis was the first olympic champion etkn

# %% [markdown]
# ### Reverse Generation

# %%
r_data = list(reversed(data))

# %% [markdown]
# ### Bigram

# %%
model_rbi = defaultdict(lambda: defaultdict(int))

# %%
n_gram = 2
for i in range(n_gram,len(r_data)+1):
    w1 = r_data[i-n_gram+0]
    w2 = r_data[i-n_gram+1]
    model_rbi[w1][w2] += 1

# %%
for w1 in model_rbi:
    total_count = float(sum(model_rbi[w1].values()))
    for w2 in model_rbi[w1]:
        model_rbi[w1][w2] /= total_count

# %%
model_rbi
# Out:
# defaultdict(<function __main__.<lambda>()>,
#             {'etkn': defaultdict(int,
#                          {'temples': 0.022222222222222223,
#                           'eliminated': 0.022222222222222223,
#                           'greece': 0.06666666666666667,
#                           'games': 0.17777777777777778,
#                           'measurement': 0.022222222222222223,
#                           'statues': 0.022222222222222223,
#                           'pisatis': 0.022222222222222223,
#                           'olympia': 0.022222222222222223,
#                           'champion': 0.022222222222222223,
#                           'events': 0.06666666666666667,
#                           'bc': 0.022222222222222223,
#                           'distance': 0.022222222222222223,
#                           'zeus': 0.044444444444444446,
#                           'years': 0.022222222222222223,
#                           'wars': 0.022222222222222223,
#                           'truce': 0.022222222222222223,
#                           'finished': 0.022222222222222223,
#                           'world': 0.022222222222222223,
#                           'fame': 0.022222222222222223,
#                           'terrorism': 0.022222222222222223,
#                           'teams': 0.022222222222222223,
#                           'respectively': 0.022222222222222223,
#                           'ceremonies': 0.022222222222222223,
#                           'charter': 0.022222222222222223,
#                           'pandemic': 0.022222222222222223,
#                           'advancements': 0.022222222222222223,
#                           'olympics': 0.022222222222222223,
#                           'authority': 0.022222222222222223,
#                           'in': 0.022222222222222223,
#                           'ad': 0.022222222222222223,
#                           'period': 0.022222222222222223,
#                           'records': 0.022222222222222223,
#                           'competitions': 0.022222222222222223}),
#              'temples': defaultdict(int, {'greek': 1.0}),
#              'greek': defaultdict(int, {'all': 0.5, 'ancient': 0.5}),
#              'all': defaultdict(int,
#                          {'of': 0.25,
#                           'that': 0.25,
#                           'games': 0.25,
#                           'encompasses': 0.25}),
#              'of': defaultdict(int,
#                          {'destruction': 0.02702702702702703,
#                           'height': 0.02702702702702703,
#                           'part': 0.02702702702702703,
#                           'units': 0.02702702702702703,
#                           'one': 0.05405405405405406,
#                           'winners': 0.05405405405405406,
#                           'oenomaus': 0.02702702702702703,
#                           'king': 0.02702702702702703,
#                           'were': 0.02702702702702703,
#                           'city': 0.02702702702702703,
#                           'consisting': 0.05405405405405406,
#                           'unit': 0.02702702702702703,
#                           'custom': 0.02702702702702703,
#                           'progenitors': 0.02702702702702703,
#                           'origin': 0.02702702702702703,
#                           'cessation': 0.02702702702702703,
#                           'kingdoms': 0.02702702702702703,
#                           'representatives': 0.02702702702702703,
#                           'sanctuary': 0.02702702702702703,
#                           'consists': 0.02702702702702703,
#                           'result': 0.02702702702702703,
#                           'cancellation': 0.02702702702702703,
#                           'commercialisation': 0.02702702702702703,
#                           'issue': 0.02702702702702703,
#                           'importance': 0.02702702702702703,
#                           'acceptance': 0.02702702702702703,
#                           'abuse': 0.02702702702702703,
#                           'variety': 0.05405405405405406,
#                           'creation': 0.02702702702702703,
#                           'some': 0.02702702702702703,
#                           'evolution': 0.02702702702702703,
#                           'body': 0.02702702702702703,
#                           'thousands': 0.02702702702702703}),
#              'destruction': defaultdict(int, {'the': 1.0}),
#              'the': defaultdict(int,
#                          {'ordered': 0.009009009009009009,
#                           'when': 0.018018018018018018,
#                           'ended': 0.009009009009009009,
#                           'as': 0.06306306306306306,
#                           'in': 0.036036036036036036,
#                           'reached': 0.009009009009009009,
#                           'stkn': 0.22522522522522523,
#                           'and': 0.04504504504504504,
#                           'games': 0.009009009009009009,
#                           'included': 0.009009009009009009,
#                           'of': 0.0990990990990991,
#                           'was': 0.009009009009009009,
#                           'from': 0.018018018018018018,
#                           'listing': 0.009009009009009009,
#                           'for': 0.018018018018018018,
#                           'built': 0.009009009009009009,
#                           'established': 0.009009009009009009,
#                           'called': 0.009009009009009009,
#                           'because': 0.009009009009009009,
#                           'until': 0.009009009009009009,
#                           'among': 0.009009009009009009,
#                           'during': 0.036036036036036036,
#                           'at': 0.036036036036036036,
#                           'to': 0.08108108108108109,
#                           'with': 0.018018018018018018,
#                           'years': 0.009009009009009009,
#                           'determines': 0.009009009009009009,
#                           'funds': 0.009009009009009009,
#                           'choosing': 0.009009009009009009,
#                           'body': 0.009009009009009009,
#                           'created': 0.009009009009009009,
#                           'prompted': 0.009009009009009009,
#                           'by': 0.018018018018018018,
#                           'endorses': 0.009009009009009009,
#                           'disabilities': 0.009009009009009009,
#                           'sports': 0.009009009009009009,
#                           'include': 0.009009009009009009,
#                           'is': 0.009009009009009009,
#                           'founded': 0.009009009009009009,
#                           'between': 0.009009009009009009,
#                           'championships': 0.009009009009009009,
#                           'default': 0.009009009009009009,
#                           'considered': 0.009009009009009009,
#                           'around': 0.009009009009009009,
#                           'are': 0.009009009009009009}),
#              'ordered': defaultdict(int, {'ii': 1.0}),
#              'ii': defaultdict(int, {'theodosius': 1.0}),
#              'theodosius': defaultdict(int,
#                          {'successor': 0.5, 'emperor': 0.5}),
#              'successor': defaultdict(int, {'his': 1.0}),
#              'his': defaultdict(int,
#                          {'when': 0.2,
#                           'for': 0.2,
#                           'in': 0.2,
#                           'completed': 0.2,
#                           'and': 0.2}),
#              'when': defaultdict(int,
#                          {'ad': 0.6666666666666666, 'to': 0.3333333333333333}),
#              'ad': defaultdict(int,
#                          {'is': 0.6666666666666666,
#                           'century': 0.3333333333333333}),
#              'is': defaultdict(int,
#                          {'cited': 0.1,
#                           'date': 0.1,
#                           'there': 0.1,
#                           'this': 0.1,
#                           'olympics': 0.2,
#                           'idea': 0.1,
#                           'nation': 0.1,
#                           'ioc': 0.2}),
#              'cited': defaultdict(int, {'commonly': 1.0}),
#              'commonly': defaultdict(int, {'date': 0.5, 'most': 0.5}),
#              'date': defaultdict(int,
#                          {'another': 0.3333333333333333,
#                           'held': 0.3333333333333333,
#                           'inception': 0.3333333333333333}),
#              'another': defaultdict(int, {'b': 1.0}),
#              'b': defaultdict(int, {'stkn': 1.0}),
#              'stkn': defaultdict(int, {'etkn': 1.0}),
#              'eliminated': defaultdict(int, {'be': 1.0}),
#              'be': defaultdict(int, {'practices': 0.5, 'to': 0.5}),
#              'practices': defaultdict(int, {'and': 1.0}),
#              'and': defaultdict(int,
#                          {'cults': 0.019230769230769232,
#                           'power': 0.019230769230769232,
#                           'th': 0.038461538461538464,
#                           'games': 0.038461538461538464,
#                           'years': 0.038461538461538464,
#                           'poems': 0.019230769230769232,
#                           'admired': 0.019230769230769232,
#                           'hero': 0.019230769230769232,
#                           'olympia': 0.019230769230769232,
#                           'pankration': 0.019230769230769232,
#                           'race': 0.019230769230769232,
#                           'discus': 0.019230769230769232,
#                           'steps': 0.019230769230769232,
#                           'olympic': 0.019230769230769232,
#                           'heracles': 0.019230769230769232,
#                           'mystery': 0.019230769230769232,
#                           'horse': 0.019230769230769232,
#                           'wrestling': 0.019230769230769232,
#                           'states': 0.038461538461538464,
#                           'religious': 0.019230769230769232,
#                           'city': 0.019230769230769232,
#                           'national': 0.019230769230769232,
#                           'olympics': 0.057692307692307696,
#                           'bribery': 0.019230769230769232,
#                           'challenges': 0.019230769230769232,
#                           'colonies': 0.019230769230769232,
#                           'silver': 0.019230769230769232,
#                           'second': 0.019230769230769232,
#                           'sports': 0.019230769230769232,
#                           'opening': 0.019230769230769232,
#                           'flag': 0.019230769230769232,
#                           'rituals': 0.019230769230769232,
#                           'organises': 0.019230769230769232,
#                           'nocs': 0.019230769230769232,
#                           'the': 0.038461538461538464,
#                           'sponsorship': 0.019230769230769232,
#                           'political': 0.019230769230769232,
#                           'deaflympics': 0.019230769230769232,
#                           'pacific': 0.019230769230769232,
#                           'european': 0.019230769230769232,
#                           'snow': 0.019230769230769232,
#                           'structure': 0.019230769230769232,
#                           'entities': 0.019230769230769232,
#                           'summer': 0.038461538461538464}),
#              'cults': defaultdict(int, {'pagan': 1.0}),
#              'pagan': defaultdict(int, {'all': 1.0}),
#              'that': defaultdict(int,
#                          {'decreed': 0.16666666666666666,
#                           'it': 0.16666666666666666,
#                           'continues': 0.16666666666666666,
#                           'written': 0.16666666666666666,
#                           'point': 0.16666666666666666,
#                           'sports': 0.16666666666666666}),
#              'decreed': defaultdict(int, {'i': 1.0}),
#              'i': defaultdict(int, {'theodosius': 1.0}),
#              'emperor': defaultdict(int, {'the': 1.0}),
#              'held': defaultdict(int,
#                          {'commonly': 0.16666666666666666,
#                           'were': 0.16666666666666666,
#                           'footrace': 0.16666666666666666,
#                           'festivals': 0.16666666666666666,
#                           'games': 0.16666666666666666,
#                           'normally': 0.16666666666666666}),
#              'most': defaultdict(int, {'the': 1.0}),
#              'ended': defaultdict(int, {'officially': 1.0}),
#              'officially': defaultdict(int, {'games': 1.0}),
#              'games': defaultdict(int,
#                          {'the': 0.3783783783783784,
#                           'olympic': 0.32432432432432434,
#                           'isthmian': 0.02702702702702703,
#                           'nemean': 0.02702702702702703,
#                           'pythian': 0.02702702702702703,
#                           'panhellenic': 0.02702702702702703,
#                           'ancient': 0.02702702702702703,
#                           'these': 0.02702702702702703,
#                           'each': 0.02702702702702703,
#                           'world': 0.02702702702702703,
#                           'continental': 0.02702702702702703,
#                           'paralympic': 0.02702702702702703,
#                           'modern': 0.02702702702702703}),
#              'to': defaultdict(int,
#                          {'as': 0.047619047619047616,
#                           'honour': 0.047619047619047616,
#                           'according': 0.09523809523809523,
#                           'olympia': 0.047619047619047616,
#                           'travelling': 0.047619047619047616,
#                           'themselves': 0.047619047619047616,
#                           'country': 0.047619047619047616,
#                           'chance': 0.047619047619047616,
#                           'allowed': 0.047619047619047616,
#                           'grown': 0.047619047619047616,
#                           'sports': 0.047619047619047616,
#                           'led': 0.047619047619047616,
#                           'coubertin': 0.047619047619047616,
#                           'ioc': 0.047619047619047616,
#                           'adapt': 0.047619047619047616,
#                           'needed': 0.047619047619047616,
#                           'aged': 0.047619047619047616,
#                           'changes': 0.047619047619047616,
#                           'leading': 0.047619047619047616,
#                           'bc': 0.047619047619047616}),
#              'as': defaultdict(int,
#                          {'consensus': 0.06666666666666667,
#                           'importance': 0.06666666666666667,
#                           'known': 0.2,
#                           'greeks': 0.06666666666666667,
#                           'stadium': 0.06666666666666667,
#                           'zeus': 0.06666666666666667,
#                           'such': 0.13333333333333333,
#                           'well': 0.06666666666666667,
#                           'torch': 0.06666666666666667,
#                           'stkn': 0.06666666666666667,
#                           'until': 0.06666666666666667,
#                           'amateurism': 0.06666666666666667}),
#              'consensus': defaultdict(int, {'scholarly': 1.0}),
#              'scholarly': defaultdict(int, {'no': 1.0}),
#              'no': defaultdict(int, {'is': 1.0}),
#              'there': defaultdict(int, {'while': 0.5, 'stkn': 0.5}),
#              'while': defaultdict(int, {'stkn': 1.0}),
#              'greece': defaultdict(int,
#                          {'in': 0.25, 'ancient': 0.25, 'olympia': 0.5}),
#              'in': defaultdict(int,
#                          {'influence': 0.045454545454545456,
#                           'declined': 0.045454545454545456,
#                           'success': 0.045454545454545456,
#                           'immortalised': 0.045454545454545456,
#                           'stood': 0.045454545454545456,
#                           'starting': 0.045454545454545456,
#                           'walked': 0.045454545454545456,
#                           'shrouded': 0.045454545454545456,
#                           'zeus': 0.045454545454545456,
#                           'finishers': 0.045454545454545456,
#                           'combined': 0.045454545454545456,
#                           'participation': 0.045454545454545456,
#                           'contested': 0.045454545454545456,
#                           'resulted': 0.045454545454545456,
#                           'involved': 0.045454545454545456,
#                           'athens': 0.045454545454545456,
#                           'games': 0.045454545454545456,
#                           'ioc': 0.045454545454545456,
#                           'held': 0.045454545454545456,
#                           'year': 0.045454545454545456,
#                           'participate': 0.045454545454545456,
#                           'competitions': 0.045454545454545456}),
#              'influence': defaultdict(int, {'and': 1.0}),
#              'power': defaultdict(int, {'gained': 1.0}),
#              'gained': defaultdict(int, {'romans': 1.0}),
#              'romans': defaultdict(int, {'the': 1.0}),
#              'importance': defaultdict(int,
#                          {'in': 0.3333333333333333,
#                           'religious': 0.3333333333333333,
#                           'growing': 0.3333333333333333}),
#              'declined': defaultdict(int, {'gradually': 1.0}),
#              'gradually': defaultdict(int, {'then': 1.0}),
#              'then': defaultdict(int, {'but': 1.0}),
#              'but': defaultdict(int, {'bc': 0.5, 'athletic': 0.5}),
#              'bc': defaultdict(int,
#                          {'centuries': 0.25,
#                           'in': 0.25,
#                           'is': 0.25,
#                           'century': 0.25}),
#              'centuries': defaultdict(int, {'th': 0.5, 'st': 0.5}),
#              'th': defaultdict(int, {'and': 0.2, 'the': 0.8}),
#              'success': defaultdict(int, {'their': 1.0}),
#              'their': defaultdict(int,
#                          {'of': 0.3333333333333333,
#                           'suspended': 0.16666666666666666,
#                           'field': 0.16666666666666666,
#                           'stkn': 0.16666666666666666,
#                           'maintains': 0.16666666666666666}),
#              'height': defaultdict(int, {'the': 1.0}),
#              'reached': defaultdict(int, {'games': 1.0}),
#              'olympic': defaultdict(int,
#                          {'the': 0.5555555555555556,
#                           'first': 0.037037037037037035,
#                           'games': 0.037037037037037035,
#                           'ancient': 0.07407407407407407,
#                           'receive': 0.037037037037037035,
#                           'several': 0.037037037037037035,
#                           'specific': 0.037037037037037035,
#                           'national': 0.037037037037037035,
#                           'youth': 0.037037037037037035,
#                           'winter': 0.037037037037037035,
#                           'international': 0.037037037037037035,
#                           'modern': 0.037037037037037035}),
#              'isthmian': defaultdict(int, {'the': 1.0}),
#              'nemean': defaultdict(int, {'the': 1.0}),
#              'pythian': defaultdict(int, {'the': 1.0}),
#              'included': defaultdict(int, {'which': 1.0}),
#              'which': defaultdict(int,
#                          {'games': 0.2,
#                           'stage': 0.2,
#                           'movement': 0.2,
#                           'in': 0.4}),
#              'panhellenic': defaultdict(int, {'the': 1.0}),
#              'known': defaultdict(int,
#                          {'cycle': 0.3333333333333333,
#                           'period': 0.3333333333333333,
#                           'was': 0.3333333333333333}),
#              'cycle': defaultdict(int, {'a': 1.0}),
#              'a': defaultdict(int,
#                          {'of': 0.23076923076923078,
#                           'coroebus': 0.07692307692307693,
#                           'throws': 0.07692307692307693,
#                           'events': 0.07692307692307693,
#                           'became': 0.07692307692307693,
#                           'distance': 0.07692307692307693,
#                           'in': 0.15384615384615385,
#                           'is': 0.07692307692307693,
#                           'as': 0.07692307692307693,
#                           'to': 0.07692307692307693}),
#              'part': defaultdict(int, {'were': 1.0}),
#              'were': defaultdict(int,
#                          {'games': 0.4,
#                           'events': 0.1,
#                           'olympics': 0.2,
#                           'they': 0.1,
#                           'who': 0.1,
#                           'states': 0.1}),
#              'measurement': defaultdict(int, {'time': 1.0}),
#              'time': defaultdict(int, {'of': 1.0}),
#              'units': defaultdict(int, {'their': 1.0}),
#              'one': defaultdict(int, {'as': 0.5, 'legend': 0.5}),
#              'greeks': defaultdict(int, {'by': 0.5, 'the': 0.5}),
#              'by': defaultdict(int,
#                          {'used': 0.14285714285714285,
#                           'statue': 0.14285714285714285,
#                           'protected': 0.14285714285714285,
#                           'envisioned': 0.14285714285714285,
#                           'rules': 0.14285714285714285,
#                           'inspired': 0.14285714285714285,
#                           'participating': 0.14285714285714285}),
#              'used': defaultdict(int, {'was': 1.0}),
#              'was': defaultdict(int,
#                          {'olympiad': 0.14285714285714285,
#                           'pelops': 0.14285714285714285,
#                           'elis': 0.14285714285714285,
#                           'it': 0.14285714285714285,
#                           'hostilities': 0.14285714285714285,
#                           'competition': 0.14285714285714285,
#                           'creation': 0.14285714285714285}),
#              'olympiad': defaultdict(int, {'an': 1.0}),
#              'an': defaultdict(int,
#                          {'as': 0.6666666666666666,
#                           'provide': 0.3333333333333333}),
#              'period': defaultdict(int, {'this': 0.5, 'year': 0.5}),
#              'this': defaultdict(int,
#                          {'and': 0.16666666666666666,
#                           'bc': 0.16666666666666666,
#                           'called': 0.16666666666666666,
#                           'stkn': 0.5}),
#              'years': defaultdict(int,
#                          {'four': 0.7142857142857143,
#                           'two': 0.2857142857142857}),
#              'four': defaultdict(int,
#                          {'every': 0.8333333333333334,
#                           'the': 0.16666666666666666}),
#              'every': defaultdict(int,
#                          {'held': 0.5,
#                           'them': 0.125,
#                           'stkn': 0.125,
#                           'nearly': 0.125,
#                           'olympics': 0.125}),
#              'statues': defaultdict(int, {'and': 1.0}),
#              'poems': defaultdict(int, {'in': 1.0}),
#              'immortalised': defaultdict(int, {'and': 1.0}),
#              'admired': defaultdict(int, {'were': 1.0}),
#              'events': defaultdict(int,
#                          {'the': 0.14285714285714285,
#                           'sporting': 0.2857142857142857,
#                           'equestrian': 0.14285714285714285,
#                           'running': 0.14285714285714285,
#                           'racing': 0.14285714285714285,
#                           'and': 0.14285714285714285}),
#              'winners': defaultdict(int, {'the': 1.0}),
#              'pisatis': defaultdict(int, {'of': 1.0}),
#              'oenomaus': defaultdict(int, {'king': 1.0}),
#              'king': defaultdict(int, {'with': 0.5, 'mythical': 0.5}),
#              'with': defaultdict(int,
#                          {'race': 0.2,
#                           'athletes': 0.4,
#                           'games': 0.2,
#                           'competition': 0.2}),
#              'race': defaultdict(int, {'chariot': 0.5, 'foot': 0.5}),
#              'chariot': defaultdict(int, {'his': 0.5, 'and': 0.5}),
#              'for': defaultdict(int,
#                          {'famous': 0.08333333333333333,
#                           'date': 0.08333333333333333,
#                           'line': 0.08333333333333333,
#                           'opportunity': 0.08333333333333333,
#                           'city': 0.08333333333333333,
#                           'responsible': 0.08333333333333333,
#                           'committees': 0.08333333333333333,
#                           'games': 0.3333333333333333,
#                           'substitute': 0.08333333333333333}),
#              'famous': defaultdict(int, {'was': 0.5, 'whose': 0.5}),
#              'pelops': defaultdict(int, {'stkn': 0.5, 'and': 0.5}),
#              'olympia': defaultdict(int,
#                          {'of': 0.16666666666666666,
#                           'at': 0.3333333333333333,
#                           'to': 0.16666666666666666,
#                           'in': 0.3333333333333333}),
#              'mythical': defaultdict(int, {'and': 1.0}),
#              'hero': defaultdict(int, {'divine': 1.0}),
#              'divine': defaultdict(int, {'pelops': 1.0}),
#              'at': defaultdict(int,
#                          {'temple': 0.16666666666666666,
#                           'found': 0.16666666666666666,
#                           'years': 0.16666666666666666,
#                           'competed': 0.16666666666666666,
#                           'contested': 0.16666666666666666,
#                           'participating': 0.16666666666666666}),
#              'temple': defaultdict(int, {'his': 1.0}),
#              'stood': defaultdict(int, {'phidias': 1.0}),
#              'phidias': defaultdict(int, {'by': 1.0}),
#              'statue': defaultdict(int, {'famous': 1.0}),
#              'whose': defaultdict(int, {'zeus': 1.0}),
#              'zeus': defaultdict(int,
#                          {'both': 0.2,
#                           'to': 0.2,
#                           'father': 0.2,
#                           'by': 0.2,
#                           'of': 0.2}),
#              'both': defaultdict(int, {'honouring': 1.0}),
#              'honouring': defaultdict(int, {'sacrifices': 1.0}),
#              'sacrifices': defaultdict(int, {'ritual': 1.0}),
#              'ritual': defaultdict(int, {'alongside': 1.0}),
#              'alongside': defaultdict(int, {'events': 1.0}),
#              'sporting': defaultdict(int,
#                          {'featuring': 0.5, 'international': 0.5}),
#              'featuring': defaultdict(int, {'importance': 0.5, 'events': 0.5}),
#              'religious': defaultdict(int,
#                          {'fundamental': 0.3333333333333333,
#                           'those': 0.3333333333333333,
#                           'were': 0.3333333333333333}),
#              'fundamental': defaultdict(int, {'of': 1.0}),
#              'olympics': defaultdict(int,
#                          {'the': 0.3333333333333333,
#                           'ancient': 0.08333333333333333,
#                           'winter': 0.16666666666666666,
#                           'summer': 0.08333333333333333,
#                           'and': 0.16666666666666666,
#                           'special': 0.08333333333333333,
#                           'or': 0.08333333333333333}),
#              'champion': defaultdict(int, {'olympic': 1.0}),
#              'first': defaultdict(int, {'the': 0.75, 'who': 0.25}),
#              'elis': defaultdict(int, {'of': 1.0}),
#              'city': defaultdict(int,
#                          {'the': 0.2,
#                           'participating': 0.2,
#                           'several': 0.2,
#                           'host': 0.4}),
#              'from': defaultdict(int,
#                          {'cook': 0.25,
#                           'away': 0.25,
#                           'greece': 0.25,
#                           'athletes': 0.25}),
#              'cook': defaultdict(int, {'a': 1.0}),
#              'coroebus': defaultdict(int, {'that': 1.0}),
#              'it': defaultdict(int,
#                          {'has': 0.3333333333333333,
#                           'legend': 0.3333333333333333,
#                           'stkn': 0.3333333333333333}),
#              'has': defaultdict(int,
#                          {'tradition': 0.16666666666666666,
#                           'it': 0.16666666666666666,
#                           'growth': 0.16666666666666666,
#                           'media': 0.16666666666666666,
#                           'ioc': 0.16666666666666666,
#                           'centuries': 0.16666666666666666}),
#              'tradition': defaultdict(int, {'stkn': 1.0}),
#              'equestrian': defaultdict(int, {'and': 1.0}),
#              'pankration': defaultdict(int, {'wrestling': 0.5, 'the': 0.5}),
#              'wrestling': defaultdict(int,
#                          {'boxing': 0.3333333333333333,
#                           'and': 0.3333333333333333,
#                           'as': 0.3333333333333333}),
#              'boxing': defaultdict(int, {'wrestling': 1.0}),
#              'foot': defaultdict(int, {'a': 1.0}),
#              'throws': defaultdict(int, {'javelin': 1.0}),
#              'javelin': defaultdict(int, {'and': 1.0}),
#              'discus': defaultdict(int, {'event': 1.0}),
#              'event': defaultdict(int, {'jumping': 0.5, 'each': 0.5}),
#              'jumping': defaultdict(int, {'a': 1.0}),
#              'consisting': defaultdict(int,
#                          {'pentathlon': 0.5, 'programme': 0.5}),
#              'pentathlon': defaultdict(int, {'a': 1.0}),
#              'running': defaultdict(int, {'featured': 1.0}),
#              'featured': defaultdict(int, {'games': 1.0}),
#              'ancient': defaultdict(int,
#                          {'the': 0.6666666666666666,
#                           'stadion': 0.16666666666666666,
#                           'of': 0.16666666666666666}),
#              'starting': defaultdict(int, {'years': 1.0}),
#              'footrace': defaultdict(int, {'a': 1.0}),
#              'listing': defaultdict(int, {'olympia': 1.0}),
#              'found': defaultdict(int, {'inscriptions': 1.0}),
#              'inscriptions': defaultdict(int, {'on': 1.0}),
#              'on': defaultdict(int, {'based': 1.0}),
#              'based': defaultdict(int, {'is': 1.0}),
#              'inception': defaultdict(int, {'accepted': 1.0}),
#              'accepted': defaultdict(int, {'widely': 1.0}),
#              'widely': defaultdict(int, {'most': 0.5, 'been': 0.5}),
#              'distance': defaultdict(int, {'of': 0.5, 'this': 0.5}),
#              'unit': defaultdict(int, {'a': 1.0}),
#              'became': defaultdict(int, {'later': 1.0}),
#              'later': defaultdict(int, {'which': 1.0}),
#              'stage': defaultdict(int, {'stadium': 1.0}),
#              'stadium': defaultdict(int, {'latin': 0.5, 'olympic': 0.5}),
#              'latin': defaultdict(int, {'greek': 1.0}),
#              'stadion': defaultdict(int, {'a': 1.0}),
#              'called': defaultdict(int, {'and': 0.5, 'first': 0.5}),
#              'steps': defaultdict(int, {'for': 1.0}),
#              'line': defaultdict(int, {'straight': 1.0}),
#              'straight': defaultdict(int, {'a': 1.0}),
#              'walked': defaultdict(int, {'he': 1.0}),
#              'he': defaultdict(int, {'completion': 0.5, 'labours': 0.5}),
#              'completion': defaultdict(int, {'its': 1.0}),
#              'its': defaultdict(int,
#                          {'following': 0.3333333333333333,
#                           'and': 0.3333333333333333,
#                           'defining': 0.3333333333333333}),
#              'following': defaultdict(int, {'stkn': 1.0}),
#              'honour': defaultdict(int, {'an': 1.0}),
#              'built': defaultdict(int, {'he': 1.0}),
#              'labours': defaultdict(int, {'twelve': 1.0}),
#              'twelve': defaultdict(int, {'his': 1.0}),
#              'completed': defaultdict(int, {'heracles': 1.0}),
#              'heracles': defaultdict(int,
#                          {'after': 0.3333333333333333,
#                           'was': 0.3333333333333333,
#                           'identifies': 0.3333333333333333}),
#              'after': defaultdict(int, {'that': 1.0}),
#              'continues': defaultdict(int, {'myth': 1.0}),
#              'myth': defaultdict(int, {'the': 0.5, 'modern': 0.5}),
#              'them': defaultdict(int, {'holding': 1.0}),
#              'holding': defaultdict(int, {'of': 1.0}),
#              'custom': defaultdict(int, {'the': 1.0}),
#              'established': defaultdict(int, {'and': 1.0}),
#              'who': defaultdict(int, {'heracles': 0.5, 'pilgrims': 0.5}),
#              'legend': defaultdict(int, {'to': 0.5, 'and': 0.5}),
#              'according': defaultdict(int, {'stkn': 0.5, 'games': 0.5}),
#              'progenitors': defaultdict(int, {'the': 1.0}),
#              'father': defaultdict(int, {'his': 1.0}),
#              'identifies': defaultdict(int, {'myths': 1.0}),
#              'myths': defaultdict(int, {'popular': 1.0}),
#              'popular': defaultdict(int, {'most': 1.0}),
#              'mystery': defaultdict(int, {'in': 1.0}),
#              'shrouded': defaultdict(int, {'is': 1.0}),
#              'origin': defaultdict(int, {'the': 1.0}),
#              'protected': defaultdict(int, {'were': 1.0}),
#              'they': defaultdict(int, {'because': 0.5, 'which': 0.5}),
#              'because': defaultdict(int, {'unmolested': 0.5, 'myth': 0.5}),
#              'unmolested': defaultdict(int, {'territories': 1.0}),
#              'territories': defaultdict(int,
#                          {'warring': 0.3333333333333333,
#                           'overseas': 0.3333333333333333,
#                           'and': 0.3333333333333333}),
#              'warring': defaultdict(int, {'through': 1.0}),
#              'through': defaultdict(int, {'pass': 1.0}),
#              'pass': defaultdict(int, {'to': 1.0}),
#              'travelling': defaultdict(int, {'were': 1.0}),
#              'pilgrims': defaultdict(int, {'religious': 1.0}),
#              'those': defaultdict(int, {'allow': 1.0}),
#              'allow': defaultdict(int, {'did': 1.0}),
#              'did': defaultdict(int, {'truce': 1.0}),
#              'truce': defaultdict(int, {'the': 0.5, 'or': 0.5}),
#              'wars': defaultdict(int, {'their': 0.5, 'world': 0.5}),
#              'suspended': defaultdict(int, {'never': 1.0}),
#              'never': defaultdict(int, {'greeks': 1.0}),
#              'modern': defaultdict(int,
#                          {'a': 0.3333333333333333,
#                           'first': 0.3333333333333333,
#                           'the': 0.3333333333333333}),
#              'idea': defaultdict(int, {'this': 1.0}),
#              'or': defaultdict(int, {'peace': 0.5, 'games': 0.5}),
#              'peace': defaultdict(int, {'olympic': 1.0}),
#              'hostilities': defaultdict(int, {'of': 1.0}),
#              'cessation': defaultdict(int, {'this': 1.0}),
#              'finished': defaultdict(int, {'were': 1.0}),
#              'until': defaultdict(int, {'postponed': 1.0}),
#              'postponed': defaultdict(int, {'were': 1.0}),
#              'states': defaultdict(int,
#                          {'city': 0.6666666666666666,
#                           'sovereign': 0.3333333333333333}),
#              'participating': defaultdict(int,
#                          {'the': 0.3333333333333333,
#                           'athletes': 0.3333333333333333,
#                           'territories': 0.3333333333333333}),
#              'among': defaultdict(int, {'conflicts': 0.5, 'was': 0.5}),
#              'conflicts': defaultdict(int, {'all': 1.0}),
#              'during': defaultdict(int,
#                          {'that': 0.25,
#                           'boycotts': 0.25,
#                           'movement': 0.25,
#                           'years': 0.25}),
#              'written': defaultdict(int, {'widely': 1.0}),
#              'been': defaultdict(int, {'has': 1.0}),
#              'racing': defaultdict(int, {'chariot': 1.0}),
#              'horse': defaultdict(int, {'pankration': 1.0}),
#              'such': defaultdict(int, {'sports': 0.5, 'symbols': 0.5}),
#              'sports': defaultdict(int,
#                          {'combat': 0.125,
#                           'different': 0.125,
#                           'the': 0.125,
#                           'international': 0.125,
#                           'for': 0.125,
#                           'ice': 0.125,
#                           'foremost': 0.125,
#                           'winter': 0.125}),
#              'combat': defaultdict(int, {'also': 1.0}),
#              'also': defaultdict(int,
#                          {'but': 0.25, 'games': 0.25, 'ioc': 0.5}),
#              'athletic': defaultdict(int, {'mainly': 0.5, 'and': 0.5}),
#              'mainly': defaultdict(int, {'featured': 1.0}),
#              'these': defaultdict(int, {'stkn': 0.5, 'of': 0.5}),
#              'kingdoms': defaultdict(int, {'and': 1.0}),
#              'several': defaultdict(int,
#                          {'of': 0.3333333333333333,
#                           'are': 0.3333333333333333,
#                           'in': 0.3333333333333333}),
#              'representatives': defaultdict(int, {'among': 1.0}),
#              'competition': defaultdict(int, {'stkn': 0.5, 'sports': 0.5}),
#              'sanctuary': defaultdict(int, {'the': 1.0}),
#              'festivals': defaultdict(int, {'athletic': 1.0}),
#              'world': defaultdict(int,
#                          {'the': 0.6666666666666666,
#                           'stkn': 0.16666666666666666,
#                           'any': 0.16666666666666666}),
#              'themselves': defaultdict(int, {'showcase': 1.0}),
#              'showcase': defaultdict(int, {'to': 1.0}),
#              'country': defaultdict(int, {'and': 1.0}),
#              'host': defaultdict(int, {'the': 1.0}),
#              'opportunity': defaultdict(int, {'an': 1.0}),
#              'provide': defaultdict(int, {'also': 0.5, 'exposure': 0.5}),
#              'fame': defaultdict(int, {'international': 1.0}),
#              'international': defaultdict(int,
#                          {'and': 0.25,
#                           'of': 0.25,
#                           'the': 0.25,
#                           'leading': 0.25}),
#              'national': defaultdict(int, {'attain': 0.5, 'ifs': 0.5}),
#              'attain': defaultdict(int, {'to': 1.0}),
#              'chance': defaultdict(int, {'the': 1.0}),
#              'athletes': defaultdict(int,
#                          {'provide': 0.16666666666666666,
#                           'over': 0.16666666666666666,
#                           'professional': 0.16666666666666666,
#                           'for': 0.3333333333333333,
#                           'of': 0.16666666666666666}),
#              'exposure': defaultdict(int, {'media': 1.0}),
#              'media': defaultdict(int, {'its': 0.5, 'mass': 0.5}),
#              'two': defaultdict(int, {'every': 1.0}),
#              'terrorism': defaultdict(int, {'and': 1.0}),
#              'bribery': defaultdict(int, {'doping': 1.0}),
#              'doping': defaultdict(int, {'boycotts': 1.0}),
#              'boycotts': defaultdict(int, {'including': 0.5, 'scale': 0.5}),
#              'including': defaultdict(int, {'controversies': 1.0}),
#              'controversies': defaultdict(int, {'and': 1.0}),
#              'challenges': defaultdict(int, {'numerous': 1.0}),
#              'numerous': defaultdict(int, {'created': 1.0}),
#              'created': defaultdict(int, {'has': 1.0}),
#              'growth': defaultdict(int, {'this': 1.0}),
#              'teams': defaultdict(int, {'own': 0.5, 'than': 0.5}),
#              'own': defaultdict(int, {'their': 1.0}),
#              'field': defaultdict(int, {'to': 1.0}),
#              'allowed': defaultdict(int, {'often': 1.0}),
#              'often': defaultdict(int, {'are': 1.0}),
#              'are': defaultdict(int,
#                          {'territories': 0.16666666666666666,
#                           'there': 0.16666666666666666,
#                           'that': 0.16666666666666666,
#                           'games': 0.3333333333333333,
#                           'olympics': 0.16666666666666666}),
#              'overseas': defaultdict(int, {'and': 1.0}),
#              'colonies': defaultdict(int, {'represented': 1.0}),
#              'represented': defaultdict(int, {'now': 1.0}),
#              'now': defaultdict(int, {'is': 1.0}),
#              'nation': defaultdict(int, {'every': 1.0}),
#              'nearly': defaultdict(int, {'that': 1.0}),
#              'point': defaultdict(int, {'the': 1.0}),
#              'grown': defaultdict(int, {'have': 1.0}),
#              'have': defaultdict(int, {'games': 0.5, 'since': 0.5}),
#              'respectively': defaultdict(int, {'bronze': 1.0}),
#              'bronze': defaultdict(int, {'and': 1.0}),
#              'silver': defaultdict(int, {'gold': 1.0}),
#              'gold': defaultdict(int, {'medals': 1.0}),
#              'medals': defaultdict(int, {'olympic': 1.0}),
#              'receive': defaultdict(int, {'event': 1.0}),
#              'each': defaultdict(int,
#                          {'in': 0.25, 'for': 0.5, 'however': 0.25}),
#              'finishers': defaultdict(int, {'place': 1.0}),
#              'place': defaultdict(int, {'third': 0.5, 'take': 0.5}),
#              'third': defaultdict(int, {'and': 1.0}),
#              'second': defaultdict(int, {'first': 1.0}),
#              'different': defaultdict(int, {'in': 1.0}),
#              'combined': defaultdict(int, {'olympics': 1.0}),
#              'winter': defaultdict(int, {'and': 0.75, 'the': 0.25}),
#              'summer': defaultdict(int,
#                          {'the': 0.6666666666666666,
#                           'featuring': 0.3333333333333333}),
#              'competed': defaultdict(int, {'athletes': 1.0}),
#              'over': defaultdict(int, {'stkn': 1.0}),
#              'ceremonies': defaultdict(int, {'closing': 1.0}),
#              'closing': defaultdict(int, {'and': 1.0}),
#              'opening': defaultdict(int, {'the': 1.0}),
#              'well': defaultdict(int, {'as': 1.0}),
#              'torch': defaultdict(int, {'and': 1.0}),
#              'flag': defaultdict(int, {'olympic': 1.0}),
#              'symbols': defaultdict(int, {'and': 1.0}),
#              'rituals': defaultdict(int, {'olympic': 1.0}),
#              'contested': defaultdict(int, {'be': 0.5, 'not': 0.5}),
#              'programme': defaultdict(int, {'olympic': 1.0}),
#              'determines': defaultdict(int, {'also': 1.0}),
#              'ioc': defaultdict(int,
#                          {'the': 0.8571428571428571,
#                           'committee': 0.14285714285714285}),
#              'charter': defaultdict(int, {'olympic': 1.0}),
#              'funds': defaultdict(int, {'and': 1.0}),
#              'organises': defaultdict(int, {'and': 1.0}),
#              'choosing': defaultdict(int, {'for': 1.0}),
#              'responsible': defaultdict(int, {'is': 1.0}),
#              'body': defaultdict(int, {'making': 0.5, 'governing': 0.5}),
#              'making': defaultdict(int, {'decision': 1.0}),
#              'decision': defaultdict(int, {'the': 1.0}),
#              'specific': defaultdict(int, {'each': 1.0}),
#              'committees': defaultdict(int,
#                          {'organising': 0.5, 'olympic': 0.5}),
#              'organising': defaultdict(int, {'and': 1.0}),
#              'nocs': defaultdict(int, {'committees': 1.0}),
#              'ifs': defaultdict(int, {'federations': 1.0}),
#              'federations': defaultdict(int, {'sports': 1.0}),
#              'consists': defaultdict(int, {'movement': 1.0}),
#              'movement': defaultdict(int, {'olympic': 1.0}),
#              'pandemic': defaultdict(int, {'covid': 1.0}),
#              'covid': defaultdict(int, {'the': 1.0}),
#              'result': defaultdict(int, {'a': 1.0}),
#              'participation': defaultdict(int, {'limited': 1.0}),
#              'limited': defaultdict(int, {'war': 1.0}),
#              'war': defaultdict(int, {'cold': 1.0}),
#              'cold': defaultdict(int, {'the': 1.0}),
#              'scale': defaultdict(int, {'large': 1.0}),
#              'large': defaultdict(int, {'olympics': 1.0}),
#              'cancellation': defaultdict(int, {'the': 1.0}),
#              'led': defaultdict(int, {'wars': 1.0}),
#              'commercialisation': defaultdict(int, {'general': 1.0}),
#              'general': defaultdict(int, {'and': 1.0}),
#              'sponsorship': defaultdict(int, {'corporate': 1.0}),
#              'corporate': defaultdict(int, {'of': 1.0}),
#              'issue': defaultdict(int, {'the': 1.0}),
#              'mass': defaultdict(int, {'of': 1.0}),
#              'growing': defaultdict(int, {'the': 1.0}),
#              'professional': defaultdict(int, {'of': 1.0}),
#              'acceptance': defaultdict(int, {'the': 1.0}),
#              'coubertin': defaultdict(int, {'by': 0.5, 'de': 0.5}),
#              'envisioned': defaultdict(int, {'as': 1.0}),
#              'amateurism': defaultdict(int, {'pure': 1.0}),
#              'pure': defaultdict(int, {'from': 1.0}),
#              'away': defaultdict(int, {'shift': 1.0}),
#              'shift': defaultdict(int, {'to': 1.0}),
#              'prompted': defaultdict(int, {'nations': 1.0}),
#              'nations': defaultdict(int, {'bloc': 1.0}),
#              'bloc': defaultdict(int, {'eastern': 1.0}),
#              'eastern': defaultdict(int, {'the': 1.0}),
#              'rules': defaultdict(int, {'amateur': 1.0}),
#              'amateur': defaultdict(int, {'of': 1.0}),
#              'abuse': defaultdict(int, {'the': 1.0}),
#              'advancements': defaultdict(int, {'technological': 1.0}),
#              'technological': defaultdict(int, {'and': 1.0}),
#              'political': defaultdict(int, {'economic': 1.0}),
#              'economic': defaultdict(int, {'of': 1.0}),
#              'variety': defaultdict(int, {'a': 1.0}),
#              'adapt': defaultdict(int, {'to': 1.0}),
#              'needed': defaultdict(int, {'has': 1.0}),
#              'special': defaultdict(int, {'the': 1.0}),
#              'deaflympics': defaultdict(int, {'the': 1.0}),
#              'endorses': defaultdict(int, {'also': 1.0}),
#              'not': defaultdict(int, {'are': 1.0}),
#              'pacific': defaultdict(int, {'and': 1.0}),
#              'european': defaultdict(int, {'asian': 1.0}),
#              'asian': defaultdict(int, {'african': 1.0}),
#              'african': defaultdict(int, {'american': 1.0}),
#              'american': defaultdict(int, {'pan': 1.0}),
#              'pan': defaultdict(int, {'games': 1.0}),
#              'continental': defaultdict(int, {'five': 1.0}),
#              'five': defaultdict(int, {'the': 1.0}),
#              'aged': defaultdict(int, {'athletes': 1.0}),
#              'youth': defaultdict(int, {'the': 1.0}),
#              'disabilities': defaultdict(int, {'with': 1.0}),
#              'paralympic': defaultdict(int, {'the': 1.0}),
#              'ice': defaultdict(int, {'and': 1.0}),
#              'snow': defaultdict(int, {'for': 1.0}),
#              'creation': defaultdict(int, {'the': 0.5, 'their': 0.5}),
#              'include': defaultdict(int, {'adjustments': 1.0}),
#              'adjustments': defaultdict(int, {'these': 1.0}),
#              'some': defaultdict(int, {'stkn': 1.0}),
#              'changes': defaultdict(int, {'several': 1.0}),
#              'resulted': defaultdict(int, {'has': 1.0}),
#              'st': defaultdict(int, {'and': 1.0}),
#              'evolution': defaultdict(int, {'the': 1.0}),
#              'authority': defaultdict(int, {'and': 1.0}),
#              'structure': defaultdict(int, {'its': 1.0}),
#              'defining': defaultdict(int, {'charter': 1.0}),
#              'involved': defaultdict(int, {'individuals': 1.0}),
#              'individuals': defaultdict(int, {'and': 1.0}),
#              'entities': defaultdict(int, {'all': 1.0}),
#              'encompasses': defaultdict(int, {'which': 1.0}),
#              'governing': defaultdict(int, {'the': 1.0}),
#              'athens': defaultdict(int, {'in': 1.0}),
#              'leading': defaultdict(int, {'in': 0.5, 'the': 0.5}),
#              'committee': defaultdict(int, {'olympic': 1.0}),
#              'founded': defaultdict(int, {'coubertin': 1.0}),
#              'de': defaultdict(int, {'pierre': 1.0}),
#              'pierre': defaultdict(int, {'baron': 1.0}),
#              'baron': defaultdict(int, {'stkn': 1.0}),
#              'century': defaultdict(int, {'th': 1.0}),
#              'inspired': defaultdict(int, {'was': 1.0}),
#              'year': defaultdict(int, {'four': 0.5, 'the': 0.5}),
#              'between': defaultdict(int, {'alternated': 1.0}),
#              'alternated': defaultdict(int, {'have': 1.0}),
#              'since': defaultdict(int, {'and': 1.0}),
#              'normally': defaultdict(int, {'are': 1.0}),
#              'records': defaultdict(int, {'own': 1.0}),
#              'maintains': defaultdict(int, {'usually': 1.0}),
#              'usually': defaultdict(int, {'class': 1.0}),
#              'class': defaultdict(int, {'each': 1.0}),
#              'however': defaultdict(int, {'place': 1.0}),
#              'take': defaultdict(int, {'they': 1.0}),
#              'championships': defaultdict(int, {'world': 1.0}),
#              'any': defaultdict(int, {'for': 1.0}),
#              'substitute': defaultdict(int, {'generally': 1.0}),
#              'generally': defaultdict(int, {'games': 1.0}),
#              'default': defaultdict(int, {'by': 1.0}),
#              'sovereign': defaultdict(int, {'representing': 1.0}),
#              'representing': defaultdict(int, {'teams': 1.0}),
#              'than': defaultdict(int, {'more': 1.0}),
#              'more': defaultdict(int, {'with': 1.0}),
#              'foremost': defaultdict(int, {'world': 1.0}),
#              'considered': defaultdict(int, {'are': 1.0}),
#              'competitions': defaultdict(int, {'of': 0.5, 'sports': 0.5}),
#              'participate': defaultdict(int, {'world': 1.0}),
#              'around': defaultdict(int, {'from': 1.0}),
#              'thousands': defaultdict(int, {'which': 1.0})})

# %%
def bigram_rgen(input_text):
    
    starting_words = input_text.split(' ')
    sentence = list(starting_words)
    next_word = ''

    while next_word != 'stkn':
        w1 = sentence[-1]
        if w1 in model_rbi:
            # calls the next word given on the probability of that word itself
            next_word = random.choices(list(model_rbi[w1].keys()), weights=model_rbi[w1].values())[0]
            sentence.append(next_word)
        else:
            break
        
        if len(sentence) < 30:
            next_word = ''

    return ' '.join(reversed(sentence))

# %%
input_text = 'the'
before = bigram_rgen(input_text)
print(before)
# Out:
# stkn this growth has been widely accepted inception date for any world participate in a pentathlon consisting of the deaflympics and events alongside ritual sacrifices honouring both zeus whose famous statue by coubertin to adapt to the greeks as the olympic games have grown to the first called the th centuries bc etkn stkn over athletes with disabilities the

# %%
input_text = 'the'
after = bigram_gen(input_text)
print(after)
# Out:
# the games were admired and closing ceremonies etkn stkn the olympic games or truce etkn stkn the youth olympic stadium as the host city for each class usually maintains their success in bc but also combat sports competitions etkn

# %%
final = before[:len(before)-4] + ' *' + input_text + '* ' + after[4:]
print(final)
# Out:
# stkn this growth has been widely accepted inception date for any world participate in a pentathlon consisting of the deaflympics and events alongside ritual sacrifices honouring both zeus whose famous statue by coubertin to adapt to the greeks as the olympic games have grown to the first called the th centuries bc etkn stkn over athletes with disabilities *the* games were admired and closing ceremonies etkn stkn the olympic games or truce etkn stkn the youth olympic stadium as the host city for each class usually maintains their success in bc but also combat sports competitions etkn

# %% [markdown]
# ### Trigram

# %%
model_rtri = defaultdict(lambda: defaultdict(lambda: 0))

# %%
n_gram = 3
for i in range(n_gram,len(r_data)+1):
    w1 = r_data[i-n_gram+0]
    w2 = r_data[i-n_gram+1]
    w3 = r_data[i-n_gram+2]
    model_rtri[(w1,w2)][w3] += 1

# %%
for w1_w2 in model_rtri:
    total_count = float(sum(model_rtri[w1_w2].values()))
    for w3 in model_rtri[w1_w2]:
        model_rtri[w1_w2][w3] /= total_count

# %%
model_rtri
# Out:
# defaultdict(<function __main__.<lambda>()>,
#             {('etkn',
#               'temples'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'greek': 1.0}),
#              ('temples',
#               'greek'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'all': 1.0}),
#              ('greek',
#               'all'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'of': 1.0}),
#              ('all',
#               'of'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'destruction': 1.0}),
#              ('of',
#               'destruction'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'the': 1.0}),
#              ('destruction',
#               'the'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'ordered': 1.0}),
#              ('the',
#               'ordered'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'ii': 1.0}),
#              ('ordered',
#               'ii'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'theodosius': 1.0}),
#              ('ii',
#               'theodosius'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'successor': 1.0}),
#              ('theodosius',
#               'successor'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'his': 1.0}),
#              ('successor',
#               'his'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'when': 1.0}),
#              ('his',
#               'when'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'ad': 1.0}),
#              ('when',
#               'ad'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'is': 1.0}),
#              ('ad',
#               'is'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'cited': 0.5, 'date': 0.5}),
#              ('is',
#               'cited'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'commonly': 1.0}),
#              ('cited',
#               'commonly'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'date': 1.0}),
#              ('commonly',
#               'date'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'another': 1.0}),
#              ('date',
#               'another'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'b': 1.0}),
#              ('another',
#               'b'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'stkn': 1.0}),
#              ('b',
#               'stkn'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'etkn': 1.0}),
#              ('stkn',
#               'etkn'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'eliminated': 0.022727272727272728,
#                           'greece': 0.06818181818181818,
#                           'games': 0.18181818181818182,
#                           'measurement': 0.022727272727272728,
#                           'statues': 0.022727272727272728,
#                           'pisatis': 0.022727272727272728,
#                           'olympia': 0.022727272727272728,
#                           'champion': 0.022727272727272728,
#                           'events': 0.06818181818181818,
#                           'bc': 0.022727272727272728,
#                           'distance': 0.022727272727272728,
#                           'zeus': 0.045454545454545456,
#                           'years': 0.022727272727272728,
#                           'wars': 0.022727272727272728,
#                           'truce': 0.022727272727272728,
#                           'finished': 0.022727272727272728,
#                           'world': 0.022727272727272728,
#                           'fame': 0.022727272727272728,
#                           'terrorism': 0.022727272727272728,
#                           'teams': 0.022727272727272728,
#                           'respectively': 0.022727272727272728,
#                           'ceremonies': 0.022727272727272728,
#                           'charter': 0.022727272727272728,
#                           'pandemic': 0.022727272727272728,
#                           'advancements': 0.022727272727272728,
#                           'olympics': 0.022727272727272728,
#                           'authority': 0.022727272727272728,
#                           'in': 0.022727272727272728,
#                           'ad': 0.022727272727272728,
#                           'period': 0.022727272727272728,
#                           'records': 0.022727272727272728,
#                           'competitions': 0.022727272727272728}),
#              ('etkn',
#               'eliminated'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'be': 1.0}),
#              ('eliminated',
#               'be'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'practices': 1.0}),
#              ('be',
#               'practices'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'and': 1.0}),
#              ('practices',
#               'and'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'cults': 1.0}),
#              ('and',
#               'cults'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'pagan': 1.0}),
#              ('cults',
#               'pagan'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'all': 1.0}),
#              ('pagan',
#               'all'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'that': 1.0}),
#              ('all',
#               'that'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'decreed': 1.0}),
#              ('that',
#               'decreed'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'i': 1.0}),
#              ('decreed',
#               'i'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'theodosius': 1.0}),
#              ('i',
#               'theodosius'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'emperor': 1.0}),
#              ('theodosius',
#               'emperor'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'the': 1.0}),
#              ('emperor',
#               'the'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'when': 1.0}),
#              ('the',
#               'when'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'ad': 0.5, 'to': 0.5}),
#              ('is',
#               'date'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'held': 1.0}),
#              ('date',
#               'held'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'commonly': 1.0}),
#              ('held',
#               'commonly'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'most': 1.0}),
#              ('commonly',
#               'most'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'the': 1.0}),
#              ('most',
#               'the'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'ended': 0.3333333333333333,
#                           'stkn': 0.3333333333333333,
#                           'of': 0.3333333333333333}),
#              ('the',
#               'ended'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'officially': 1.0}),
#              ('ended',
#               'officially'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'games': 1.0}),
#              ('officially',
#               'games'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'the': 1.0}),
#              ('games',
#               'the'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'when': 0.07142857142857142,
#                           'stkn': 0.2857142857142857,
#                           'called': 0.07142857142857142,
#                           'of': 0.14285714285714285,
#                           'until': 0.07142857142857142,
#                           'during': 0.07142857142857142,
#                           'at': 0.14285714285714285,
#                           'funds': 0.07142857142857142,
#                           'default': 0.07142857142857142}),
#              ('when',
#               'to'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'as': 1.0}),
#              ('to',
#               'as'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'consensus': 1.0}),
#              ('as',
#               'consensus'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'scholarly': 1.0}),
#              ('consensus',
#               'scholarly'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'no': 1.0}),
#              ('scholarly',
#               'no'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'is': 1.0}),
#              ('no',
#               'is'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'there': 1.0}),
#              ('is',
#               'there'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'while': 1.0}),
#              ('there',
#               'while'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'stkn': 1.0}),
#              ('while',
#               'stkn'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'etkn': 1.0}),
#              ('etkn',
#               'greece'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'in': 0.3333333333333333,
#                           'ancient': 0.3333333333333333,
#                           'olympia': 0.3333333333333333}),
#              ('greece',
#               'in'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'influence': 1.0}),
#              ('in',
#               'influence'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'and': 1.0}),
#              ('influence',
#               'and'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'power': 1.0}),
#              ('and',
#               'power'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'gained': 1.0}),
#              ('power',
#               'gained'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'romans': 1.0}),
#              ('gained',
#               'romans'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'the': 1.0}),
#              ('romans',
#               'the'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'as': 1.0}),
#              ('the',
#               'as'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'importance': 0.14285714285714285,
#                           'known': 0.2857142857142857,
#                           'zeus': 0.14285714285714285,
#                           'well': 0.14285714285714285,
#                           'such': 0.14285714285714285,
#                           'stkn': 0.14285714285714285}),
#              ('as',
#               'importance'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'in': 1.0}),
#              ('importance',
#               'in'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'declined': 1.0}),
#              ('in',
#               'declined'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'gradually': 1.0}),
#              ('declined',
#               'gradually'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'then': 1.0}),
#              ('gradually',
#               'then'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'but': 1.0}),
#              ('then',
#               'but'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'bc': 1.0}),
#              ('but',
#               'bc'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'centuries': 1.0}),
#              ('bc',
#               'centuries'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'th': 1.0}),
#              ('centuries',
#               'th'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'and': 1.0}),
#              ('th',
#               'and'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'th': 1.0}),
#              ('and',
#               'th'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'the': 1.0}),
#              ('th',
#               'the'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'in': 0.25,
#                           'during': 0.25,
#                           'to': 0.25,
#                           'from': 0.25}),
#              ('the',
#               'in'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'success': 0.25,
#                           'participation': 0.25,
#                           'contested': 0.25,
#                           'involved': 0.25}),
#              ('in',
#               'success'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'their': 1.0}),
#              ('success',
#               'their'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'of': 1.0}),
#              ('their',
#               'of'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'height': 0.5, 'one': 0.5}),
#              ('of',
#               'height'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'the': 1.0}),
#              ('height',
#               'the'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'reached': 1.0}),
#              ('the',
#               'reached'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'games': 1.0}),
#              ('reached',
#               'games'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'olympic': 1.0}),
#              ('games',
#               'olympic'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'the': 0.5,
#                           'ancient': 0.16666666666666666,
#                           'specific': 0.08333333333333333,
#                           'youth': 0.08333333333333333,
#                           'winter': 0.08333333333333333,
#                           'modern': 0.08333333333333333}),
#              ('olympic',
#               'the'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'stkn': 0.26666666666666666,
#                           'built': 0.06666666666666667,
#                           'as': 0.13333333333333333,
#                           'determines': 0.06666666666666667,
#                           'to': 0.13333333333333333,
#                           'in': 0.13333333333333333,
#                           'of': 0.13333333333333333,
#                           'with': 0.06666666666666667}),
#              ('the',
#               'stkn'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'etkn': 1.0}),
#              ('etkn',
#               'games'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'isthmian': 0.125, 'the': 0.5, 'olympic': 0.375}),
#              ('games',
#               'isthmian'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'the': 1.0}),
#              ('isthmian',
#               'the'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'and': 1.0}),
#              ('the',
#               'and'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'games': 0.2,
#                           'wrestling': 0.2,
#                           'olympics': 0.2,
#                           'deaflympics': 0.2,
#                           'pacific': 0.2}),
#              ('and',
#               'games'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'nemean': 0.5, 'each': 0.5}),
#              ('games',
#               'nemean'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'the': 1.0}),
#              ('nemean',
#               'the'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'games': 1.0}),
#              ('the',
#               'games'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'pythian': 1.0}),
#              ('games',
#               'pythian'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'the': 1.0}),
#              ('pythian',
#               'the'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'included': 1.0}),
#              ('the',
#               'included'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'which': 1.0}),
#              ('included',
#               'which'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'games': 1.0}),
#              ('which',
#               'games'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'panhellenic': 1.0}),
#              ('games',
#               'panhellenic'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'the': 1.0}),
#              ('panhellenic',
#               'the'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'as': 1.0}),
#              ('as',
#               'known'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'cycle': 0.3333333333333333,
#                           'period': 0.3333333333333333,
#                           'was': 0.3333333333333333}),
#              ('known',
#               'cycle'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'a': 1.0}),
#              ('cycle',
#               'a'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'of': 1.0}),
#              ('a',
#               'of'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'part': 0.3333333333333333,
#                           'consisting': 0.3333333333333333,
#                           'winners': 0.3333333333333333}),
#              ('of',
#               'part'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'were': 1.0}),
#              ('part',
#               'were'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'games': 1.0}),
#              ('were',
#               'games'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'the': 0.75, 'olympic': 0.25}),
#              ('etkn',
#               'measurement'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'time': 1.0}),
#              ('measurement',
#               'time'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'of': 1.0}),
#              ('time',
#               'of'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'units': 1.0}),
#              ('of',
#               'units'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'their': 1.0}),
#              ('units',
#               'their'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'of': 1.0}),
#              ('of',
#               'one'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'as': 0.5, 'legend': 0.5}),
#              ('one',
#               'as'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'greeks': 1.0}),
#              ('as',
#               'greeks'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'by': 1.0}),
#              ('greeks',
#               'by'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'used': 1.0}),
#              ('by',
#               'used'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'was': 1.0}),
#              ('used',
#               'was'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'olympiad': 1.0}),
#              ('was',
#               'olympiad'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'an': 1.0}),
#              ('olympiad',
#               'an'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'as': 1.0}),
#              ('an',
#               'as'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'known': 0.5, 'stadium': 0.5}),
#              ('known',
#               'period'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'this': 1.0}),
#              ('period',
#               'this'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'and': 1.0}),
#              ('this',
#               'and'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'years': 1.0}),
#              ('and',
#               'years'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'four': 1.0}),
#              ('years',
#               'four'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'every': 1.0}),
#              ('four',
#               'every'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'held': 0.8, 'them': 0.2}),
#              ('every',
#               'held'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'were': 0.25,
#                           'footrace': 0.25,
#                           'festivals': 0.25,
#                           'normally': 0.25}),
#              ('held',
#               'were'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'games': 1.0}),
#              ('etkn',
#               'statues'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'and': 1.0}),
#              ('statues',
#               'and'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'poems': 1.0}),
#              ('and',
#               'poems'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'in': 1.0}),
#              ('poems',
#               'in'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'immortalised': 1.0}),
#              ('in',
#               'immortalised'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'and': 1.0}),
#              ('immortalised',
#               'and'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'admired': 1.0}),
#              ('and',
#               'admired'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'were': 1.0}),
#              ('admired',
#               'were'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'events': 1.0}),
#              ('were',
#               'events'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'the': 1.0}),
#              ('events',
#               'the'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'of': 1.0}),
#              ('the',
#               'of'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'winners': 0.09090909090909091,
#                           'progenitors': 0.09090909090909091,
#                           'one': 0.09090909090909091,
#                           'origin': 0.09090909090909091,
#                           'consisting': 0.09090909090909091,
#                           'result': 0.09090909090909091,
#                           'cancellation': 0.09090909090909091,
#                           'commercialisation': 0.09090909090909091,
#                           'creation': 0.09090909090909091,
#                           'evolution': 0.09090909090909091,
#                           'body': 0.09090909090909091}),
#              ('of',
#               'winners'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'the': 1.0}),
#              ('winners',
#               'the'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'stkn': 0.5, 'listing': 0.5}),
#              ('etkn',
#               'pisatis'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'of': 1.0}),
#              ('pisatis',
#               'of'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'oenomaus': 1.0}),
#              ('of',
#               'oenomaus'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'king': 1.0}),
#              ('oenomaus',
#               'king'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'with': 1.0}),
#              ('king',
#               'with'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'race': 1.0}),
#              ('with',
#               'race'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'chariot': 1.0}),
#              ('race',
#               'chariot'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'his': 1.0}),
#              ('chariot',
#               'his'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'for': 1.0}),
#              ('his',
#               'for'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'famous': 1.0}),
#              ('for',
#               'famous'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'was': 1.0}),
#              ('famous',
#               'was'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'pelops': 1.0}),
#              ('was',
#               'pelops'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'stkn': 1.0}),
#              ('pelops',
#               'stkn'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'etkn': 1.0}),
#              ('etkn',
#               'olympia'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'of': 1.0}),
#              ('olympia',
#               'of'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'king': 1.0}),
#              ('of',
#               'king'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'mythical': 1.0}),
#              ('king',
#               'mythical'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'and': 1.0}),
#              ('mythical',
#               'and'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'hero': 1.0}),
#              ('and',
#               'hero'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'divine': 1.0}),
#              ('hero',
#               'divine'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'pelops': 1.0}),
#              ('divine',
#               'pelops'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'and': 1.0}),
#              ('pelops',
#               'and'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'olympia': 1.0}),
#              ('and',
#               'olympia'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'at': 1.0}),
#              ('olympia',
#               'at'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'temple': 0.5, 'found': 0.5}),
#              ('at',
#               'temple'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'his': 1.0}),
#              ('temple',
#               'his'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'in': 1.0}),
#              ('his',
#               'in'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'stood': 1.0}),
#              ('in',
#               'stood'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'phidias': 1.0}),
#              ('stood',
#               'phidias'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'by': 1.0}),
#              ('phidias',
#               'by'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'statue': 1.0}),
#              ('by',
#               'statue'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'famous': 1.0}),
#              ('statue',
#               'famous'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'whose': 1.0}),
#              ('famous',
#               'whose'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'zeus': 1.0}),
#              ('whose',
#               'zeus'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'both': 1.0}),
#              ('zeus',
#               'both'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'honouring': 1.0}),
#              ('both',
#               'honouring'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'sacrifices': 1.0}),
#              ('honouring',
#               'sacrifices'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'ritual': 1.0}),
#              ('sacrifices',
#               'ritual'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'alongside': 1.0}),
#              ('ritual',
#               'alongside'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'events': 1.0}),
#              ('alongside',
#               'events'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'sporting': 1.0}),
#              ('events',
#               'sporting'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'featuring': 0.5, 'international': 0.5}),
#              ('sporting',
#               'featuring'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'importance': 1.0}),
#              ('featuring',
#               'importance'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'religious': 1.0}),
#              ('importance',
#               'religious'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'fundamental': 1.0}),
#              ('religious',
#               'fundamental'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'of': 1.0}),
#              ('fundamental',
#               'of'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'were': 1.0}),
#              ('of',
#               'were'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'olympics': 1.0}),
#              ('were',
#               'olympics'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'the': 1.0}),
#              ('olympics',
#               'the'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'stkn': 0.25,
#                           'of': 0.25,
#                           'years': 0.25,
#                           'and': 0.25}),
#              ('etkn',
#               'champion'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'olympic': 1.0}),
#              ('champion',
#               'olympic'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'first': 1.0}),
#              ('olympic',
#               'first'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'the': 1.0}),
#              ('first',
#               'the'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'was': 0.3333333333333333,
#                           'stkn': 0.3333333333333333,
#                           'to': 0.3333333333333333}),
#              ('the',
#               'was'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'elis': 1.0}),
#              ('was',
#               'elis'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'of': 1.0}),
#              ('elis',
#               'of'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'city': 1.0}),
#              ('of',
#               'city'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'the': 1.0}),
#              ('city',
#               'the'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'from': 1.0}),
#              ('the',
#               'from'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'cook': 0.5, 'greece': 0.5}),
#              ('from',
#               'cook'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'a': 1.0}),
#              ('cook',
#               'a'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'coroebus': 1.0}),
#              ('a',
#               'coroebus'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'that': 1.0}),
#              ('coroebus',
#               'that'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'it': 1.0}),
#              ('that',
#               'it'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'has': 1.0}),
#              ('it',
#               'has'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'tradition': 1.0}),
#              ('has',
#               'tradition'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'stkn': 1.0}),
#              ('tradition',
#               'stkn'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'etkn': 1.0}),
#              ('etkn',
#               'events'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'equestrian': 0.3333333333333333,
#                           'racing': 0.3333333333333333,
#                           'and': 0.3333333333333333}),
#              ('events',
#               'equestrian'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'and': 1.0}),
#              ('equestrian',
#               'and'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'pankration': 1.0}),
#              ('and',
#               'pankration'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'wrestling': 1.0}),
#              ('pankration',
#               'wrestling'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'boxing': 1.0}),
#              ('wrestling',
#               'boxing'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'wrestling': 1.0}),
#              ('boxing',
#               'wrestling'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'and': 1.0}),
#              ('wrestling',
#               'and'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'race': 1.0}),
#              ('and',
#               'race'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'foot': 1.0}),
#              ('race',
#               'foot'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'a': 1.0}),
#              ('foot',
#               'a'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'throws': 1.0}),
#              ('a',
#               'throws'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'javelin': 1.0}),
#              ('throws',
#               'javelin'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'and': 1.0}),
#              ('javelin',
#               'and'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'discus': 1.0}),
#              ('and',
#               'discus'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'event': 1.0}),
#              ('discus',
#               'event'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'jumping': 1.0}),
#              ('event',
#               'jumping'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'a': 1.0}),
#              ('jumping',
#               'a'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'of': 1.0}),
#              ('of',
#               'consisting'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'pentathlon': 0.5, 'programme': 0.5}),
#              ('consisting',
#               'pentathlon'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'a': 1.0}),
#              ('pentathlon',
#               'a'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'events': 1.0}),
#              ('a',
#               'events'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'running': 1.0}),
#              ('events',
#               'running'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'featured': 1.0}),
#              ('running',
#               'featured'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'games': 1.0}),
#              ('featured',
#               'games'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'ancient': 0.5, 'these': 0.5}),
#              ('games',
#               'ancient'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'the': 1.0}),
#              ('ancient',
#               'the'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'stkn': 0.5, 'for': 0.25, 'by': 0.25}),
#              ('etkn',
#               'bc'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'in': 1.0}),
#              ('bc',
#               'in'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'starting': 1.0}),
#              ('in',
#               'starting'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'years': 1.0}),
#              ('starting',
#               'years'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'four': 1.0}),
#              ('held',
#               'footrace'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'a': 1.0}),
#              ('footrace',
#               'a'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'of': 1.0}),
#              ('the',
#               'listing'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'olympia': 1.0}),
#              ('listing',
#               'olympia'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'at': 1.0}),
#              ('at',
#               'found'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'inscriptions': 1.0}),
#              ('found',
#               'inscriptions'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'on': 1.0}),
#              ('inscriptions',
#               'on'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'based': 1.0}),
#              ('on',
#               'based'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'is': 1.0}),
#              ('based',
#               'is'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'this': 1.0}),
#              ('is',
#               'this'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'bc': 1.0}),
#              ('this',
#               'bc'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'is': 1.0}),
#              ('bc',
#               'is'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'olympics': 1.0}),
#              ('is',
#               'olympics'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'ancient': 0.5, 'the': 0.5}),
#              ('olympics',
#               'ancient'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'the': 1.0}),
#              ('the',
#               'for'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'date': 0.5, 'opportunity': 0.5}),
#              ('for',
#               'date'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'inception': 1.0}),
#              ('date',
#               'inception'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'accepted': 1.0}),
#              ('inception',
#               'accepted'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'widely': 1.0}),
#              ('accepted',
#               'widely'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'most': 1.0}),
#              ('widely',
#               'most'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'the': 1.0}),
#              ('etkn',
#               'distance'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'of': 1.0}),
#              ('distance',
#               'of'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'unit': 1.0}),
#              ('of',
#               'unit'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'a': 1.0}),
#              ('unit',
#               'a'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'became': 1.0}),
#              ('a',
#               'became'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'later': 1.0}),
#              ('became',
#               'later'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'which': 1.0}),
#              ('later',
#               'which'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'stage': 1.0}),
#              ('which',
#               'stage'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'stadium': 1.0}),
#              ('stage',
#               'stadium'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'latin': 1.0}),
#              ('stadium',
#               'latin'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'greek': 1.0}),
#              ('latin',
#               'greek'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'ancient': 1.0}),
#              ('greek',
#               'ancient'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'stadion': 1.0}),
#              ('ancient',
#               'stadion'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'a': 1.0}),
#              ('stadion',
#               'a'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'distance': 1.0}),
#              ('a',
#               'distance'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'this': 1.0}),
#              ('distance',
#               'this'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'called': 1.0}),
#              ('this',
#               'called'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'and': 1.0}),
#              ('called',
#               'and'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'steps': 1.0}),
#              ('and',
#               'steps'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'for': 1.0}),
#              ('steps',
#               'for'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'line': 1.0}),
#              ('for',
#               'line'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
# ...
#                          {'first': 1.0}),
#              ('modern',
#               'first'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'the': 1.0}),
#              ('to',
#               'leading'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'in': 1.0}),
#              ('leading',
#               'in'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'ioc': 1.0}),
#              ('in',
#               'ioc'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'committee': 1.0}),
#              ('ioc',
#               'committee'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'olympic': 1.0}),
#              ('committee',
#               'olympic'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'international': 1.0}),
#              ('olympic',
#               'international'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'the': 1.0}),
#              ('international',
#               'the'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'founded': 1.0}),
#              ('the',
#               'founded'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'coubertin': 1.0}),
#              ('founded',
#               'coubertin'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'de': 1.0}),
#              ('coubertin',
#               'de'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'pierre': 1.0}),
#              ('de',
#               'pierre'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'baron': 1.0}),
#              ('pierre',
#               'baron'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'stkn': 1.0}),
#              ('baron',
#               'stkn'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'etkn': 1.0}),
#              ('etkn',
#               'ad'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'century': 1.0}),
#              ('ad',
#               'century'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'th': 1.0}),
#              ('century',
#               'th'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'the': 1.0}),
#              ('to',
#               'bc'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'century': 1.0}),
#              ('bc',
#               'century'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'th': 1.0}),
#              ('from',
#               'greece'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'olympia': 1.0}),
#              ('in',
#               'held'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'games': 1.0}),
#              ('held',
#               'games'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'olympic': 1.0}),
#              ('by',
#               'inspired'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'was': 1.0}),
#              ('inspired',
#               'was'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'creation': 1.0}),
#              ('was',
#               'creation'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'their': 1.0}),
#              ('creation',
#               'their'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'stkn': 1.0}),
#              ('their',
#               'stkn'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'etkn': 1.0}),
#              ('etkn',
#               'period'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'year': 1.0}),
#              ('period',
#               'year'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'four': 1.0}),
#              ('year',
#               'four'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'the': 1.0}),
#              ('four',
#               'the'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'during': 1.0}),
#              ('during',
#               'years'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'two': 1.0}),
#              ('every',
#               'olympics'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'winter': 1.0}),
#              ('and',
#               'summer'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'the': 0.5, 'featuring': 0.5}),
#              ('the',
#               'between'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'alternated': 1.0}),
#              ('between',
#               'alternated'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'have': 1.0}),
#              ('alternated',
#               'have'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'since': 1.0}),
#              ('have',
#               'since'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'and': 1.0}),
#              ('since',
#               'and'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'years': 1.0}),
#              ('held',
#               'normally'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'are': 1.0}),
#              ('normally',
#               'are'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'games': 1.0}),
#              ('are',
#               'games'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'olympic': 1.0}),
#              ('etkn',
#               'records'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'own': 1.0}),
#              ('records',
#               'own'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'their': 1.0}),
#              ('their',
#               'maintains'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'usually': 1.0}),
#              ('maintains',
#               'usually'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'class': 1.0}),
#              ('usually',
#               'class'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'each': 1.0}),
#              ('class',
#               'each'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'however': 1.0}),
#              ('each',
#               'however'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'place': 1.0}),
#              ('however',
#               'place'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'take': 1.0}),
#              ('place',
#               'take'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'they': 1.0}),
#              ('take',
#               'they'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'which': 1.0}),
#              ('they',
#               'which'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'in': 1.0}),
#              ('which',
#               'in'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'year': 0.5, 'competitions': 0.5}),
#              ('in',
#               'year'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'the': 1.0}),
#              ('year',
#               'the'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'championships': 1.0}),
#              ('the',
#               'championships'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'world': 1.0}),
#              ('championships',
#               'world'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'any': 1.0}),
#              ('world',
#               'any'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'for': 1.0}),
#              ('any',
#               'for'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'substitute': 1.0}),
#              ('for',
#               'substitute'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'generally': 1.0}),
#              ('substitute',
#               'generally'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'games': 1.0}),
#              ('generally',
#               'games'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'the': 1.0}),
#              ('the',
#               'default'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'by': 1.0}),
#              ('default',
#               'by'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'participating': 1.0}),
#              ('by',
#               'participating'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'territories': 1.0}),
#              ('participating',
#               'territories'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'and': 1.0}),
#              ('territories',
#               'and'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'states': 1.0}),
#              ('states',
#               'sovereign'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'representing': 1.0}),
#              ('sovereign',
#               'representing'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'teams': 1.0}),
#              ('representing',
#               'teams'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'than': 1.0}),
#              ('teams',
#               'than'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'more': 1.0}),
#              ('than',
#               'more'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'with': 1.0}),
#              ('more',
#               'with'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'competition': 1.0}),
#              ('with',
#               'competition'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'sports': 1.0}),
#              ('competition',
#               'sports'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'foremost': 1.0}),
#              ('sports',
#               'foremost'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'world': 1.0}),
#              ('foremost',
#               'world'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'the': 1.0}),
#              ('the',
#               'considered'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'are': 1.0}),
#              ('considered',
#               'are'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'games': 1.0}),
#              ('etkn',
#               'competitions'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'of': 1.0}),
#              ('competitions',
#               'of'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'variety': 1.0}),
#              ('in',
#               'participate'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'world': 1.0}),
#              ('participate',
#               'world'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'the': 1.0}),
#              ('the',
#               'around'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'from': 1.0}),
#              ('around',
#               'from'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'athletes': 1.0}),
#              ('from',
#               'athletes'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'of': 1.0}),
#              ('athletes',
#               'of'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'thousands': 1.0}),
#              ('of',
#               'thousands'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'which': 1.0}),
#              ('thousands',
#               'which'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'in': 1.0}),
#              ('in',
#               'competitions'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'sports': 1.0}),
#              ('competitions',
#               'sports'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'winter': 1.0}),
#              ('sports',
#               'winter'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'and': 1.0}),
#              ('summer',
#               'featuring'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'events': 1.0}),
#              ('featuring',
#               'events'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'sporting': 1.0}),
#              ('sporting',
#               'international'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'leading': 1.0}),
#              ('international',
#               'leading'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'the': 1.0}),
#              ('leading',
#               'the'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'are': 1.0}),
#              ('the',
#               'are'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'olympics': 1.0}),
#              ('are',
#               'olympics'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'or': 1.0}),
#              ('olympics',
#               'or'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'games': 1.0}),
#              ('or',
#               'games'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'olympic': 1.0}),
#              ('olympic',
#               'modern'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'the': 1.0}),
#              ('modern',
#               'the'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'stkn': 1.0})})

# %%
def trigram_rgen(input_text):
    
    starting_words = input_text.split(' ')
    sentence = list(starting_words)
    next_word = ''
    
    while next_word != 'stkn':
        w1, w2 = sentence[-2], sentence[-1]
        if (w1, w2) in model_rtri:
            # calls the next word given on the probability of that word itself
            next_word = random.choices(list(model_rtri[(w1, w2)].keys()), weights=model_rtri[(w1, w2)].values())[0]
            sentence.append(next_word)
        else:
            break
        
        if len(sentence) < 30:
            next_word = ''
            
    return ' '.join(reversed(sentence))

# %%
input_text = 'games the'
before = trigram_rgen(input_text)
print(before)
# Out:
# stkn the olympics were of fundamental religious importance featuring sporting events alongside ritual sacrifices honouring both zeus whose famous statue by phidias stood in his temple at olympia and pelops divine hero and mythical king of olympia etkn stkn over athletes competed at the games

# %%
input_text = 'the games'
after = trigram_gen(input_text)
print(after)
# Out:
# the games generally substitute for any world championships the year in which they take place however each class usually maintains their own records etkn stkn the growing importance of mass media has created the issue of corporate sponsorship and general commercialisation of the and olympics large scale boycotts during the games olympic and established the custom of holding them every four years starting in bc etkn

# %%
final = before[:len(before)-10] + ' *' + input_text + '* ' + after[10:]
print(final)
# Out:
# stkn the olympics were of fundamental religious importance featuring sporting events alongside ritual sacrifices honouring both zeus whose famous statue by phidias stood in his temple at olympia and pelops divine hero and mythical king of olympia etkn stkn over athletes competed at *the games* generally substitute for any world championships the year in which they take place however each class usually maintains their own records etkn stkn the growing importance of mass media has created the issue of corporate sponsorship and general commercialisation of the and olympics large scale boycotts during the games olympic and established the custom of holding them every four years starting in bc etkn

# %% [markdown]
# # Thank You For Listening
